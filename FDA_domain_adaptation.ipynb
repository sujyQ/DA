# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
import os.path
import sys
from PIL import Image
import cv2
import glob
import torch.utils.data as data
import imageio as m
import torch.autograd as autograd
from imageio import imread as imread
import imageio

# %%
import random
import torchvision.transforms.functional as tf
from PIL import Image, ImageOps

class Compose(object) :
    def __init__(self, augmentations) :
        self.augmentations = augmentations
        self.PIL2Numpy = False

    def __call__(self, img, mask) :
        if isinstance(img, np.ndarray) :
            img = Image.fromarray(img, mode = "RGB")
            mask = Image.fromarray(mask, mode = "L")
            # print('in __call__' , mask)

            self.PIL2Numpy = True

            for a in self.augmentations :
                img, mask = a(img, mask)
                # print('in for : ', mask)

            if self.PIL2Numpy :
                img, mask = np.array(img, np.float64), np.array(mask, dtype = np.uint8)
                # print('after if : ', mask)
            
            return img, mask

class RandomHorizontalFlip(object) :
    def __init__(self, p) :
        self.p = p

    def __call__(self, img, mask) :
        if random.random() < self.p :
            return (img.transpose(Image.FLIP_LEFT_RIGHT), mask.transpose(Image.FLIP_LEFT_RIGHT))

        return img, mask

class RandomRotate(object) :
    def __init__(self, degree) :
        self.degree = degree

    def __call__(self, img, mask) :
        rotate_degree = random.random()*2*self.degree - self.degree

        return (
            tf.affine(img, translate=(0,0), scale=1.0, angle=rotate_degree, resample=Image.BILINEAR, 
                     fillcolor=(0,0,0), shear=0.0 ,) ,
            tf.affine(mask, translate=(0,0), scale=1.0, angle=rotate_degree, resample=Image.NEAREST, 
                      fillcolor=11, shear=0.0, ),
        )

class Resize(object) :
    def __init__(self, size = (512, 1024)) :
        self.size = size
    
    def __call__(self, img, mask) :
        w, h = img.size
        th, tw = self.size

        if w == tw and h == th :
            return img, mask

        return (img.resize((tw,th),Image.BILINEAR), mask.resize((tw, th), Image.NEAREST))


class RandomCrop(object) :
    def __init__(self, size = (128, 128)) :
        self.size = size

    def __call__(self, img, mask) :
        w, h = img.size
        th, tw = self.size

        if w == tw and h == th :
            return img, mask

        x1 = random.randint(0, w-tw)
        y1 = random.randint(0, h-th)

        return (img.crop((x1, y1, x1+tw, y1+th)), mask.crop((x1, y1, x1+tw, y1+th)))

# %%
#from https://github.com/mcordts/cityscapesScripts/blob/878f1d05b1676c669d977a91831ea800482e36c4/cityscapesscripts/helpers/labels.py
from collections import namedtuple
cityscapesLabel = namedtuple( 'Label' , [ 'name'        ,  'id'          , 'trainId'     ,  'category'    ,'categoryId'  , 'hasInstances',  'ignoreInEval',  'color', ] )

cityscapes_labels = [
    #       name                     id    trainId   category            catId     hasInstances   ignoreInEval   color
    cityscapesLabel(  'unlabeled'            ,  0 ,      19 , 'void'            , 0       , False        , True         , (  0,  0,  0) ),
    cityscapesLabel(  'ego vehicle'          ,  1 ,      19 , 'void'            , 0       , False        , True         , (  0,  0,  0) ),          #블랙박스가 있는 1인칭 시점의 차량
    cityscapesLabel(  'rectification border' ,  2 ,      19 , 'void'            , 0       , False        , True         , (  0,  0,  0) ),
    cityscapesLabel(  'out of roi'           ,  3 ,      19 , 'void'            , 0       , False        , True         , (  0,  0,  0) ),
    cityscapesLabel(  'static'               ,  4 ,      19 , 'void'            , 0       , False        , True         , (  0,  0,  0) ),
    cityscapesLabel(  'dynamic'              ,  5 ,      19 , 'void'            , 0       , False        , True         , (111, 74,  0) ),
    cityscapesLabel(  'ground'               ,  6 ,      19 , 'void'            , 0       , False        , True         , ( 81,  0, 81) ),
    cityscapesLabel(  'road'                 ,  7 ,        0 , 'flat'            , 1       , False        , False        , (128, 64,128) ),
    cityscapesLabel(  'sidewalk'             ,  8 ,        1 , 'flat'            , 1       , False        , False        , (244, 35,232) ),
    cityscapesLabel(  'parking'              ,  9 ,      19 , 'flat'            , 1       , False        , True         , (250,170,160) ),
    cityscapesLabel(  'rail track'           , 10 ,      19 , 'flat'            , 1       , False        , True         , (230,150,140) ),
    cityscapesLabel(  'building'             , 11 ,        2 , 'construction'    , 2       , False        , False        , ( 70, 70, 70) ),
    cityscapesLabel(  'wall'                 , 12 ,        3 , 'construction'    , 2       , False        , False        , (102,102,156) ),
    cityscapesLabel(  'fence'                , 13 ,        4 , 'construction'    , 2       , False        , False        , (190,153,153) ),
    cityscapesLabel(  'guard rail'           , 14 ,      19 , 'construction'    , 2       , False        , True         , (180,165,180) ),
    cityscapesLabel(  'bridge'               , 15 ,      19 , 'construction'    , 2       , False        , True         , (150,100,100) ),
    cityscapesLabel(  'tunnel'               , 16 ,      19 , 'construction'    , 2       , False        , True         , (150,120, 90) ),
    cityscapesLabel(  'pole'                 , 17 ,        5 , 'object'          , 3       , False        , False        , (153,153,153) ),
    cityscapesLabel(  'polegroup'            , 18 ,      19 , 'object'          , 3       , False        , True         , (153,153,153) ),
    cityscapesLabel(  'traffic light'        , 19 ,        6 , 'object'          , 3       , False        , False        , (250,170, 30) ),
    cityscapesLabel(  'traffic sign'         , 20 ,        7 , 'object'          , 3       , False        , False        , (220,220,  0) ),
    cityscapesLabel(  'vegetation'           , 21 ,        8 , 'nature'          , 4       , False        , False        , (107,142, 35) ),
    cityscapesLabel(  'terrain'              , 22 ,        9 , 'nature'          , 4       , False        , False        , (152,251,152) ),
    cityscapesLabel(  'sky'                  , 23 ,       10 , 'sky'             , 5       , False        , False        , ( 70,130,180) ),
    cityscapesLabel(  'person'               , 24 ,       11 , 'human'           , 6       , True         , False        , (220, 20, 60) ),
    cityscapesLabel(  'rider'                , 25 ,       12 , 'human'           , 6       , True         , False        , (255,  0,  0) ),
    cityscapesLabel(  'car'                  , 26 ,       13 , 'vehicle'         , 7       , True         , False        , (  0,  0,142) ),
    cityscapesLabel(  'truck'                , 27 ,       14 , 'vehicle'         , 7       , True         , False        , (  0,  0, 70) ),
    cityscapesLabel(  'bus'                  , 28 ,       15 , 'vehicle'         , 7       , True         , False        , (  0, 60,100) ),
    cityscapesLabel(  'caravan'              , 29 ,      19 , 'vehicle'         , 7       , True         , True         , (  0,  0, 90) ),
    cityscapesLabel(  'trailer'              , 30 ,      19 , 'vehicle'         , 7       , True         , True         , (  0,  0,110) ),
    cityscapesLabel(  'train'                , 31 ,       16 , 'vehicle'         , 7       , True         , False        , (  0, 80,100) ),
    cityscapesLabel(  'motorcycle'           , 32 ,       17 , 'vehicle'         , 7       , True         , False        , (  0,  0,230) ),
    cityscapesLabel(  'bicycle'              , 33 ,       18 , 'vehicle'         , 7       , True         , False        , (119, 11, 32) ),
    cityscapesLabel(  'license plate'        , -1 ,       19 , 'vehicle'         , 7       , False        , True         , (  0,  0,142) ),
]

# %%
synthiaLabel = namedtuple( 'Label' , [ 'name'        ,  'id'          , 'trainId'  ,] )

synhia_labels = [
    #               name                     id    trainId 
    synthiaLabel(  'void'                  ,  0 ,      19 ),
    synthiaLabel(  'sky'                   ,  1 ,       10 ),
    synthiaLabel(  'building'              ,  2 ,        2 ),
    synthiaLabel(  'road'                  ,  3 ,        0 ),
    synthiaLabel(  'sidewalk'              ,  4 ,        1 ),
    synthiaLabel(  'fence'                 ,  5 ,        4 ),
    synthiaLabel(  'vegetation'            ,  6 ,        8 ),
    synthiaLabel(  'pole'                  ,  7 ,        5 ),
    synthiaLabel(  'car'                   ,  8 ,       13 ),
    synthiaLabel(  'traffic sign'          ,  9 ,        7 ),
    synthiaLabel(  'pedestrian'            , 10 ,       11 ),
    synthiaLabel(  'bicycle'               , 11 ,       18 ),
    synthiaLabel(  'motorcycle'            , 12 ,       17 ),
    synthiaLabel(  'parking slot'          , 13 ,      19 ),
    synthiaLabel(  'road work'             , 14 ,      19 ),
    synthiaLabel(  'traffic light'         , 15 ,        6 ),
    synthiaLabel(  'terrain'               , 16 ,        9 ),
    synthiaLabel(  'rider'                 , 17 ,       12 ),
    synthiaLabel(  'truck'                 , 18 ,       14 ),
    synthiaLabel(  'bus'                   , 19 ,       15 ),
    synthiaLabel(  'train'                 , 20 ,       16 ),
    synthiaLabel(  'wall'                  , 21 ,        3 ),
    synthiaLabel(  'lanemarking'           , 22 ,      19 ),
]

# %%
CITYSCAPES = 'gdrive/My Drive/Colab Notebooks/dataset/cityscape'

class Cityscape(data.Dataset) :         #1024*2048
    def __init__(self, root, mode = 'train') :
        self.root = root
        self.images = []
        self.targets = []
        self.img_dir = 'train' if mode is 'train' else 'val'
        self.imgs_dir = os.path.join(self.root, 'leftImg8bit', self.img_dir)
        self.targets_dir = os.path.join(self.root, 'gtFine', self.img_dir )

        for city in os.listdir(self.imgs_dir) :
            img_dir = os.path.join(self.imgs_dir, city)
            target_dir = os.path.join(self.targets_dir, city)

            for img in os.listdir(img_dir) :
                self.images.append(os.path.join(img_dir, img))
                target_name = img.split('_leftImg8bit')[0]+'_gtFine_labelIds.png'
                self.targets.append(os.path.join(target_dir, target_name))
        # print(self.images)
        # print(self.targets)

        if mode is 'train' :
            self.augmentation = Compose([ Resize(), RandomRotate(15), RandomCrop((480, 768)), RandomHorizontalFlip(p=0.5)])

        else :
            self.augmentation = Compose([Resize(), RandomCrop((480, 768))])
        
    def __getitem__(self, index) :
        img_path = self.images[index]
        target_path = self.targets[index]

        img = imread(img_path)
        img = np.array(img, dtype=np.uint8)
        
        lbl = imread(target_path)
        lbl = np.array(lbl, dtype=np.int8)
        # print(lbl)
        lbl = self.mapId(lbl)
        # print(lbl)
        if self.augmentation is not None :
            img, lbl = self.augmentation(img, lbl)
        img, lbl = self.transform(img, lbl)
        target = {'segmentation' : lbl, 'classification' : 0}
        return img, target

    def mapId(self, lbl) :
        id2trainId = {label.id : label.trainId for label in cityscapes_labels}
        id2trainId_map = np.vectorize(id2trainId.get)

        label_img = id2trainId_map(lbl)
        label_img = label_img.astype(np.uint8)

        return label_img

    def transform(self, img, lbl) :
        img = img[:, :, ::-1]
        img = img.astype(np.float64)
        img = img.astype(float)/255.0

        img = img.transpose(2,0,1)

        img = torch.from_numpy(img).float()
        lbl = torch.from_numpy(lbl).long()

        return img, lbl
    
    def __len__(self) :
        return len(self.images)

cityscape_trainSet = Cityscape(root = CITYSCAPES, mode = 'train')
cityscape_trainLoader = data.DataLoader( cityscape_trainSet, batch_size = 1, shuffle = True, num_workers=0)

cityscape_testSet = Cityscape(root = CITYSCAPES, mode = 'test')
cityscape_testLoader = data.DataLoader( cityscape_testSet,  batch_size = 1, shuffle = False, num_workers=0)

# %%
SYNTHIA = 'gdrive/My Drive/Colab Notebooks/dataset/synthia'
imageio.plugins.freeimage.download()

class Synthia(data.Dataset) :           #760*1280
    def __init__(self, root, mode='train') :
        self.root = root
        self.images = []
        self.targets = []
        self.mode = mode
        self.img_dir = os.path.join(root, mode, 'image')
        self.target_dir = os.path.join(root, mode, 'target')
        for img in os.listdir(self.img_dir) :
            self.images.append(os.path.join(self.img_dir, img))
            self.targets.append(os.path.join(self.target_dir, img))
        # print(self.targets)
        if self.mode is 'train' :
            self.augmentation = Compose([ Resize(), RandomRotate(15), RandomCrop((480, 768)), RandomHorizontalFlip(p=0.5)])
        else :
            self.augmentation = self.augmentation = Compose([Resize(), RandomCrop((480, 768))])

    def __getitem__(self, index) :
        img_path = self.images[index]
        target_path = self.targets[index]

        img = imread(img_path)
        img = np.array(img, dtype=np.uint8)
        
        lbl = imread(target_path, format = 'PNG-FI')
        lbl = np.array(lbl, dtype=np.uint8)[:, :, 0]
        lbl = self.mapId(lbl)
        # print(lbl)

        if self.augmentation is not None :
            img, lbl = self.augmentation(img, lbl)
        img, lbl = self.transform(img, lbl)
        target = {'segmentation' : lbl, 'classification' : 1}
        return img, target

    def mapId(self, lbl) :
        id2trainId = {label.id : label.trainId for label in synhia_labels}
        id2trainId_map = np.vectorize(id2trainId.get)

        label_img = id2trainId_map(lbl)
        label_img = label_img.astype(np.uint8)

        return label_img

    def transform(self, img, lbl) :
        img = img[:, :, ::-1]
        img = img.astype(np.float64)
        img = img.astype(float)/255.0

        img = img.transpose(2,0,1)

        img = torch.from_numpy(img).float()
        lbl = torch.from_numpy(lbl).long()

        return img, lbl
    
    def __len__(self) :
        return len(self.images)

synthia_trainSet = Synthia(root = SYNTHIA, mode = 'train')
synthia_trainLoader = data.DataLoader( synthia_trainSet, batch_size = 1, shuffle = True, num_workers=0)

synthia_testSet = Synthia(root = SYNTHIA, mode = 'test')
synthia_testLoader = data.DataLoader( synthia_testSet,  batch_size = 1, shuffle = False, num_workers=0)
# Out:
# Imageio: 'libfreeimage-3.16.0-linux64.so' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/freeimage/libfreeimage-3.16.0-linux64.so (4.6 MB)
# 4830080/4830080 bytes (100.0%)
#   Done
# File saved as /root/.imageio/freeimage/libfreeimage-3.16.0-linux64.so.

# %%
class AverageMeter(object) :
    """computes and stores the average and curent value"""
    def __init__(self) :
        self.reset()

    def reset(self) :
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1) :
        self.val = val
        self.sum += val*n
        self.count += n
        self.avg = self.sum//self.count

def intersectionAndUnion(output, target, K, ignore_idx = 19) :

    output = output.max(1, keepdim=False)[1]
    output[target == ignore_idx] = ignore_idx

    intersection = output[output == target]
    area_intersection, _ = np.histogram(intersection, bins = np.arange(K+1))
    area_output, _ = np.histogram(output, bins=np.arange(K+1))
    area_target, _ = np.histogram(target, bins=np.arange(K+1))
    area_union = area_output + area_target - area_intersection
    return area_intersection, area_union, area_target

# %%
class _ASPP(nn.Module) :
    def __init__(self, in_plane, out_plane, kernel_size, padding, dilation) :
        super(_ASPP, self).__init__()
        self.atrous_conv = nn.Conv2d(in_channels=in_plane, out_channels=out_plane, kernel_size=kernel_size, stride=1, padding=padding, dilation=dilation)
        self.bn = nn.BatchNorm2d(out_plane)
        self.relu = nn.ReLU()

    def forward(self, x) :
        x = self.atrous_conv(x)
        x = self.bn(x)

        return self.relu(x)

class ASPP(nn.Module) :
    def __init__(self) :
        super(ASPP, self).__init__()
        dilation = [1, 6, 12, 18]
        in_plane=512
        out_plane=256

        self.aspp1 = _ASPP(in_plane=in_plane, out_plane=out_plane, kernel_size=1, padding=0, dilation=dilation[0])
        self.aspp2 = _ASPP(in_plane=in_plane, out_plane=out_plane, kernel_size=3, padding=dilation[1], dilation=dilation[1])
        self.aspp3 = _ASPP(in_plane=in_plane, out_plane=out_plane, kernel_size=3, padding=dilation[2], dilation=dilation[2])
        self.aspp4 = _ASPP(in_plane=in_plane, out_plane=out_plane, kernel_size=3, padding=dilation[3], dilation=dilation[3])
        self.gap = nn.Sequential( nn.AvgPool2d(kernel_size=4),
                                 nn.BatchNorm2d(in_plane),
                                 nn.ReLU() ,
                                 nn.Conv2d(in_channels=in_plane, out_channels=out_plane, kernel_size=1),
                                 nn.BatchNorm2d(out_plane),
                                 nn.ReLU() ,
                                 nn.UpsamplingBilinear2d( scale_factor=4) )
        
        self.conv = nn.Sequential ( nn.Conv2d(in_channels=1280, out_channels=256, kernel_size=1),
                                   nn.BatchNorm2d(out_plane),
                                   nn.ReLU())
        
    def forward(self, x) :
        # print('aspp')
        x1 = self.aspp1(x)
        # print(x1.size())
        x2 = self.aspp2(x)
        # print(x2.size())
        x3 = self.aspp3(x)
        # print(x3.size())
        x4 = self.aspp4(x)
        # print(x4.size())
        x5 = self.gap(x)
        # print(x5.size())
        # print('end')
        x = torch.cat( (x1, x2, x3, x4, x5), dim=1)
        x = self.conv(x)

        return x

# %%
origin = models.resnet18(pretrained=False, progress=True)

class EncoderModule(nn.Module) :
    def __init__(self) :
        super(EncoderModule, self).__init__()
        child_list = list(origin.children())
        self.layer0 = nn.Sequential(
            *child_list[:4]
        )
        self.layer1 = nn.Sequential(
            *child_list[4]
        )
        self.layer2 = nn.Sequential(
            *child_list[5]
        )

        self.layer3 = self._custom_layer(child_list[6], 128, 256, 3, [1,1], [1,2], [1,2])

        self.layer4 = self._custom_layer(child_list[7], 256, 512, 3, [1,1], [2,4], [2,4])
        self.aspp = ASPP()

    def _custom_layer(self, origin_layer, inplanes, outplanes, kernel_size, strides, dilation, padding, downsampling = None) :
        origin_layer[0].conv1 = nn.Conv2d(in_channels=inplanes, out_channels=outplanes, kernel_size=kernel_size, stride=strides[0],
                                    padding=padding[0], dilation=dilation[0], bias=False)
        origin_layer[0].conv2 = nn.Conv2d(in_channels=outplanes, out_channels=outplanes, kernel_size=kernel_size, stride=strides[0],
                                    padding=padding[0], dilation=dilation[0], bias=False)
        origin_layer[0].downsample = nn.Sequential(
            nn.Conv2d(in_channels=inplanes, out_channels=outplanes, kernel_size=1, bias=False),
            nn.BatchNorm2d(num_features=outplanes)
        )
        origin_layer[1].conv1 = nn.Conv2d(in_channels=outplanes, out_channels=outplanes, kernel_size=kernel_size, stride=strides[1],
                                    padding=padding[1], dilation=dilation[1], bias=False)
        origin_layer[1].conv2 = nn.Conv2d(in_channels=outplanes, out_channels=outplanes, kernel_size=kernel_size, stride=strides[1],
                                    padding=padding[1], dilation=dilation[1], bias=False)
        
        return nn.Sequential(*origin_layer)

    def forward(self, x) :
        # print(x.size())
        x = self.layer0(x)
        # print(x.size())
        x = self.layer1(x)
        identity = x
        # print(x.size())
        x = self.layer2(x)
        # print(x.size())
        x = self.layer3(x)
        # print(x.size())
        x = self.layer4(x)
        # print(x.size())
        x = self.aspp(x)
        # print(x.size())
        
        return x, identity

# %%
class DomainClassifier(nn.Module) :
    def __init__(self) :
        super(DomainClassifier, self).__init__()
        self.conv = nn.Conv2d(in_channels=256, out_channels = 64, kernel_size=1)
        self.fc = nn.Linear(64*60*96, 2)

    def forward(self, x) :
        x = self.conv(x)
        # print(x.size())
        x = x.view(x.size(0), -1)
        x = self.fc(x)

        return x

# %%
class DecoderModule(nn.Module) :
    def __init__(self) :
        super(DecoderModule, self).__init__()
        self.upsampling = nn.UpsamplingBilinear2d(scale_factor=2)
        
        self.beforeConcat = nn.Sequential( nn.Conv2d(in_channels=64, out_channels=48, kernel_size=1),
                                       nn.BatchNorm2d(48),
                                       nn.ReLU())
                                       
        self.decoder = nn.Sequential( nn.Conv2d(in_channels=304, out_channels=256, kernel_size=3, padding=1),
                                     nn.BatchNorm2d(256),
                                     nn.ReLU(),
                                     nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
                                     nn.BatchNorm2d(256),
                                     nn.ReLU(),
                                     nn.Conv2d(in_channels=256, out_channels=19, kernel_size=1),
                                     nn.UpsamplingBilinear2d(scale_factor=4))

    def forward(self, x, _x) :
        _x = self.beforeConcat(_x)
        x = self.upsampling(x)
        x = torch.cat( (_x, x), dim=1)
        x = self.decoder(x)
        return x

# %%
def FDA(src_img, tgt_img, beta=0.001) :
    src_img, tgt_img = src_img.numpy(), tgt_img.numpy()
    
    f_src, f_tgt = np.fft.fft2(src_img, axes=(1,2)), np.fft.fft2(tgt_img, axes=(1,2))
    
    src_amp, tgt_amp = np.abs(f_src), np.abs(f_tgt)
    src_phase, tgt_phase = np.angle(f_src), np.angle(f_tgt)

    src_amp /= np.max(src_amp)
    tgt_amp /= np.max(tgt_amp)

    src_amp, tgt_amp = np.fft.fftshift(src_amp, axes=(1,2)), np.fft.fftshift(tgt_amp, axes=(1,2))
    
    _, h, w = src_amp.shape
    ch, cw = np.floor(h/2.0).astype(int), np.floor(w/2.0).astype(int)
    
    Mbeta = np.zeros(src_amp.shape, dtype=np.int64)
    Mbeta[:, ch-int(beta*ch):ch+int(beta*ch), cw-int(beta*cw):cw+int(beta*cw)] = 1
    
    fda_amp = Mbeta*tgt_amp + (1-Mbeta)*(src_amp)
    fda_phase = src_phase
    
    fda_amp = np.fft.ifftshift(fda_amp, axes=(-2,-1))
    
    res = fda_amp*np.exp(1j*fda_phase)
    res = np.fft.ifft2(res, axes=(-2,-1)).real

    res_img = np.clip(res/np.max(res), 0, 1)
        
    return torch.from_numpy(res_img)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# def trainDA(epoch) :
#     encoder = EncoderModule()
#     domain_cls = DomainClassifier()
#     decoder = DecoderModule()

#     optimizer_encoder = optim.Adam(encoder.parameters(), lr = 0.00001)

#     optimizer_seg = optim.SGD(list(encoder.parameters())+list(decoder.parameters()), lr = 0.1, weight_decay = 0.0001, momentum = 0.9)
#     criterion_seg = nn.CrossEntropyLoss(ignore_index=19, reduction='mean')

#     optimizer_cls = optim.Adam(domain_cls.parameters(), lr = 0.00001)

#     intersection_meter = AverageMeter()
#     union_meter = AverageMeter()
#     target_meter = AverageMeter()

#     domain_cls.train()
#     encoder.train()
#     decoder.train()

#     correct = 0

#     synthia_trainLoader_iter = iter(synthia_trainLoader)
#     cityscape_trainLoader_iter = iter(cityscape_trainLoader)

#     conf = 0.
#     cls = 0.
#     for i in range(75300, epoch):

#         if i > 0 :
#             encoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_encoder_fda.pth"))
#             domain_cls.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_domain_cls_fda.pth"))
#             # decoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_decoder.pth"))

#         try :
#             src_data, src_target = next(synthia_trainLoader_iter)
#         except StopIteration :
#             synthia_trainLoader_iter = iter(synthia_trainLoader)
#             src_data, src_target = next(synthia_trainLoader_iter)

#         try :
#             tgt_data, tgt_target = next(cityscape_trainLoader_iter)
#         except StopIteration :
#             cityscape_trainLoader_iter = iter(cityscape_trainLoader)
#             tgt_data, tgt_target = next(cityscape_trainLoader_iter)

#         src_cls_target = src_target['classification']
#         src_seg_target = src_target['segmentation']
#         tgt_cls_target = tgt_target['classification']

#         src_data = FDA(src_data[0], tgt_data[0], 0.09)
#         src_data = src_data.unsqueeze(0).float()

#         if torch.cuda.is_available() :
#             criterion_seg = criterion_seg.cuda()
#             encoder = encoder.cuda()
#             domain_cls = domain_cls.cuda()
#             decoder = decoder.cuda()

#         src_data, src_cls_target, src_seg_target = src_data.to(device), src_cls_target.to(device), src_seg_target.to(device)
#         tgt_data, tgt_cls_target = tgt_data.to(device), tgt_cls_target.to(device)

#         optimizer_cls.zero_grad()
#         optimizer_encoder.zero_grad()
#         optimizer_seg.zero_grad()

#         # segmentation : encoder & decoder

#         # src_feature, src_l1 = encoder(src_data)
#         # tgt_feature, _ = encoder(tgt_data)

#         # src_seg = decoder(src_feature, src_l1)

#         # src_seg_loss = criterion_seg(src_seg, src_seg_target)
#         # src_seg_loss.backward(retain_graph=True)
#         # optimizer_seg.step()

#         # intersection, union, segmentation_target = intersectionAndUnion(output=src_seg.cpu(), target=src_seg_target.cpu(), K=19, ignore_idx=19)
#         # intersection_meter.update(intersection), union_meter.update(union), target_meter.update(segmentation_target)
#         # accuracy = sum(intersection_meter.val) / (sum(target_meter.val) + 1e-10)

#         # classification_loss : fc only
#         src_feature, _ = encoder(src_data)
#         tgt_feature, _ = encoder(tgt_data)
#         src_cls = domain_cls(src_feature.detach())
#         tgt_cls = domain_cls(tgt_feature.detach())
#         src_cls_loss = F.cross_entropy(src_cls, src_cls_target)
#         tgt_cls_loss = F.cross_entropy(tgt_cls, tgt_cls_target)
#         cls_loss = (src_cls_loss + tgt_cls_loss)/2.0
#         cls_loss.backward()
#         optimizer_cls.step()

#         # confusion loss : encoder

#         src_feature, _ = encoder(src_data)
#         tgt_feature, _ = encoder(tgt_data)

#         output_src_domain_cls = domain_cls(src_feature.detach())
#         output_src_domain_cls = F.softmax(output_src_domain_cls, dim=1)

#         output_tgt_domain_cls = domain_cls(tgt_feature.detach())
#         output_tgt_domain_cls = F.softmax(output_tgt_domain_cls, dim = 1)

#         uni_distribution = torch.FloatTensor(output_src_domain_cls.size()).uniform_(0, 1)
#         if torch.cuda.is_available() :
#             uni_distribution = uni_distribution.cuda()
#         conf_src_loss = -0.5 * ( torch.sum(uni_distribution * torch.log(output_src_domain_cls)))/float(output_src_domain_cls.size(0))
#         conf_tgt_loss = -0.5 * (torch.sum(uni_distribution * torch.log(output_tgt_domain_cls))) / float(output_tgt_domain_cls.size(0))
#         conf_loss = 0.5 * (conf_src_loss + conf_tgt_loss)
#         conf_loss.backward()
#         optimizer_encoder.step()

#         ####correct 값 추가해야함
#         conf += conf_loss.data
#         cls += cls_loss.data

#         if i % 100 == 0 :
#             # print('Train Epoch : {} [{}/{} ({:.0f}%)]\tConfusion Loss : {:.6f}\tClassification Loss : {:.6f}\tAccuracy : {:.6f}'.format(
#             #         epoch, batch_idx * len(src_data), len(synthia_trainLoader.dataset),
#             #         100.*batch_idx / len(synthia_trainLoader), conf_loss.data, cls_loss.data, accuracy))

#             print('Train DA Epoch[{}/{} ({:.0f}%)]\tConfusion Loss : {:.6f}\tClassification Loss : {:.6f}'.format(
#                     i, epoch, 100.*i/epoch, conf/100., cls/100.))
#             conf = 0.
#             cls = 0.
#         # iou_class = intersection_meter.sum / (union_meter.sum + 1e-10)
#         # accuracy_class = intersection_meter.sum / (target_meter.sum + 1e-10)
#         # mIOU = np.mean(iou_class)
#         # mAcc = np.mean(accuracy_class)
#         # allAcc = sum(intersection_meter.sum) / (sum(target_meter.sum) + 1e-10)

#         # print('Train Epoch : {} mIOU : {:.6f} | mACC : {:.6f}% | ACC : {:.6f}%' .format(epoch, mIOU, mAcc, allAcc))

#         torch.save(encoder.cpu().state_dict(), "gdrive/My Drive/Colab Notebooks/uda_encoder_fda.pth")
#         torch.save(domain_cls.cpu().state_dict(), "gdrive/My Drive/Colab Notebooks/uda_domain_cls_fda.pth")
#         # torch.save(decoder.cpu().state_dict(), "gdrive/My Drive/Colab Notebooks/uda_decoder.pth")

# trainDA(103400)

# ############################LOSS 저장#############################################
# Out:
# Train DA Epoch[75300/103400 (73%)]	Confusion Loss : 0.037078	Classification Loss : 0.000000
# Train DA Epoch[75400/103400 (73%)]	Confusion Loss : 3.890313	Classification Loss : 0.002296
# Train DA Epoch[75500/103400 (73%)]	Confusion Loss : 4.078654	Classification Loss : 0.002412
# Train DA Epoch[75600/103400 (73%)]	Confusion Loss : 4.001075	Classification Loss : 0.000058
# Train DA Epoch[75700/103400 (73%)]	Confusion Loss : 4.076292	Classification Loss : 0.000098
# Train DA Epoch[75800/103400 (73%)]	Confusion Loss : 3.942179	Classification Loss : 0.000020
# Train DA Epoch[75900/103400 (73%)]	Confusion Loss : 3.768422	Classification Loss : 0.000023
# Train DA Epoch[76000/103400 (74%)]	Confusion Loss : 4.142313	Classification Loss : 0.000116
# Train DA Epoch[76100/103400 (74%)]	Confusion Loss : 4.060883	Classification Loss : 0.000315
# Train DA Epoch[76200/103400 (74%)]	Confusion Loss : 4.110698	Classification Loss : 0.000094
# Train DA Epoch[76300/103400 (74%)]	Confusion Loss : 3.798740	Classification Loss : 0.000293
# Train DA Epoch[76400/103400 (74%)]	Confusion Loss : 3.973249	Classification Loss : 0.000199
# Train DA Epoch[76500/103400 (74%)]	Confusion Loss : 4.234142	Classification Loss : 0.000038
# Train DA Epoch[76600/103400 (74%)]	Confusion Loss : 4.274173	Classification Loss : 0.000041
# Train DA Epoch[76700/103400 (74%)]	Confusion Loss : 3.904923	Classification Loss : 0.000072
# Train DA Epoch[76800/103400 (74%)]	Confusion Loss : 3.991071	Classification Loss : 0.000269
# Train DA Epoch[76900/103400 (74%)]	Confusion Loss : 4.134539	Classification Loss : 0.000078
# Train DA Epoch[77000/103400 (74%)]	Confusion Loss : 3.882306	Classification Loss : 0.000298
# Train DA Epoch[77100/103400 (75%)]	Confusion Loss : 3.861475	Classification Loss : 0.000114
# Train DA Epoch[77200/103400 (75%)]	Confusion Loss : 3.954519	Classification Loss : 0.000205
# Train DA Epoch[77300/103400 (75%)]	Confusion Loss : 3.945161	Classification Loss : 0.000082
# Train DA Epoch[77400/103400 (75%)]	Confusion Loss : 3.679878	Classification Loss : 0.000045
# Train DA Epoch[77500/103400 (75%)]	Confusion Loss : 4.227120	Classification Loss : 0.000117
# Train DA Epoch[77600/103400 (75%)]	Confusion Loss : 4.102548	Classification Loss : 0.000070
# Train DA Epoch[77700/103400 (75%)]	Confusion Loss : 4.002518	Classification Loss : 0.000061
# Train DA Epoch[77800/103400 (75%)]	Confusion Loss : 3.965570	Classification Loss : 0.000179
# Train DA Epoch[77900/103400 (75%)]	Confusion Loss : 4.166535	Classification Loss : 0.000069
# Train DA Epoch[78000/103400 (75%)]	Confusion Loss : 3.865413	Classification Loss : 0.000255
# Train DA Epoch[78100/103400 (76%)]	Confusion Loss : 3.740813	Classification Loss : 0.000110
# Train DA Epoch[78200/103400 (76%)]	Confusion Loss : 4.171448	Classification Loss : 0.000034
# Train DA Epoch[78300/103400 (76%)]	Confusion Loss : 4.225796	Classification Loss : 0.000060
# Train DA Epoch[78400/103400 (76%)]	Confusion Loss : 3.659701	Classification Loss : 0.000348
# Train DA Epoch[81600/103400 (79%)]	Confusion Loss : 4.023128	Classification Loss : 0.000016
# Train DA Epoch[81700/103400 (79%)]	Confusion Loss : 4.190906	Classification Loss : 0.000125
# Train DA Epoch[81800/103400 (79%)]	Confusion Loss : 4.455865	Classification Loss : 0.002747
# Train DA Epoch[81900/103400 (79%)]	Confusion Loss : 3.907525	Classification Loss : 0.000078
# Train DA Epoch[82000/103400 (79%)]	Confusion Loss : 3.996288	Classification Loss : 0.000153
# Train DA Epoch[82100/103400 (79%)]	Confusion Loss : 3.951916	Classification Loss : 0.000041
# Train DA Epoch[82200/103400 (79%)]	Confusion Loss : 4.014352	Classification Loss : 0.006311
# Train DA Epoch[82300/103400 (80%)]	Confusion Loss : 3.886697	Classification Loss : 0.000785
# Train DA Epoch[82400/103400 (80%)]	Confusion Loss : 3.710322	Classification Loss : 0.000059
# Train DA Epoch[82500/103400 (80%)]	Confusion Loss : 4.327002	Classification Loss : 0.000019
# Train DA Epoch[82600/103400 (80%)]	Confusion Loss : 3.707040	Classification Loss : 0.020516
# Train DA Epoch[82700/103400 (80%)]	Confusion Loss : 3.590016	Classification Loss : 0.000398
# Train DA Epoch[82800/103400 (80%)]	Confusion Loss : 3.987425	Classification Loss : 0.000059
# Train DA Epoch[82900/103400 (80%)]	Confusion Loss : 4.054420	Classification Loss : 0.000159
# Train DA Epoch[83000/103400 (80%)]	Confusion Loss : 3.735008	Classification Loss : 0.000047
# Train DA Epoch[83100/103400 (80%)]	Confusion Loss : 3.885281	Classification Loss : 0.000597
# Train DA Epoch[83200/103400 (80%)]	Confusion Loss : 3.765659	Classification Loss : 0.000472
# Train DA Epoch[83300/103400 (81%)]	Confusion Loss : 3.777553	Classification Loss : 0.000151
# Train DA Epoch[83400/103400 (81%)]	Confusion Loss : 3.649916	Classification Loss : 0.000022
# Train DA Epoch[83500/103400 (81%)]	Confusion Loss : 3.918488	Classification Loss : 0.001058
# Train DA Epoch[83600/103400 (81%)]	Confusion Loss : 3.646652	Classification Loss : 0.001564
# Train DA Epoch[83700/103400 (81%)]	Confusion Loss : 4.088213	Classification Loss : 0.000073
# Train DA Epoch[83800/103400 (81%)]	Confusion Loss : 3.752014	Classification Loss : 0.000751
# Train DA Epoch[83900/103400 (81%)]	Confusion Loss : 3.816653	Classification Loss : 0.000117
# Train DA Epoch[84000/103400 (81%)]	Confusion Loss : 3.683505	Classification Loss : 0.000055
# Train DA Epoch[84100/103400 (81%)]	Confusion Loss : 4.029666	Classification Loss : 0.000098
# Train DA Epoch[84200/103400 (81%)]	Confusion Loss : 3.781151	Classification Loss : 0.000106
# Train DA Epoch[84300/103400 (82%)]	Confusion Loss : 4.060799	Classification Loss : 0.000314
# Train DA Epoch[84400/103400 (82%)]	Confusion Loss : 4.102225	Classification Loss : 0.000092
# Train DA Epoch[84500/103400 (82%)]	Confusion Loss : 4.198364	Classification Loss : 0.000017
# Train DA Epoch[84600/103400 (82%)]	Confusion Loss : 4.116310	Classification Loss : 0.000071
# Train DA Epoch[84700/103400 (82%)]	Confusion Loss : 3.903682	Classification Loss : 0.000042
# Train DA Epoch[87900/103400 (85%)]	Confusion Loss : 4.080721	Classification Loss : 0.000102
# Train DA Epoch[88000/103400 (85%)]	Confusion Loss : 3.906825	Classification Loss : 0.000575
# Train DA Epoch[88100/103400 (85%)]	Confusion Loss : 4.076163	Classification Loss : 0.000307
# Train DA Epoch[88200/103400 (85%)]	Confusion Loss : 3.782068	Classification Loss : 0.000084
# Train DA Epoch[88300/103400 (85%)]	Confusion Loss : 3.986145	Classification Loss : 0.000035
# Train DA Epoch[88400/103400 (85%)]	Confusion Loss : 4.292400	Classification Loss : 0.000044
# Train DA Epoch[88500/103400 (86%)]	Confusion Loss : 4.102559	Classification Loss : 0.000794
# Train DA Epoch[88600/103400 (86%)]	Confusion Loss : 3.946579	Classification Loss : 0.000097
# Train DA Epoch[88700/103400 (86%)]	Confusion Loss : 4.020513	Classification Loss : 0.000558
# Train DA Epoch[88800/103400 (86%)]	Confusion Loss : 3.937525	Classification Loss : 0.000038
# Train DA Epoch[88900/103400 (86%)]	Confusion Loss : 3.789652	Classification Loss : 0.000067
# Train DA Epoch[89000/103400 (86%)]	Confusion Loss : 4.133047	Classification Loss : 0.000086
# Train DA Epoch[89100/103400 (86%)]	Confusion Loss : 4.070638	Classification Loss : 0.000076
# Train DA Epoch[89200/103400 (86%)]	Confusion Loss : 4.259250	Classification Loss : 0.000574
# Train DA Epoch[89300/103400 (86%)]	Confusion Loss : 3.829868	Classification Loss : 0.000441
# Train DA Epoch[89400/103400 (86%)]	Confusion Loss : 4.331425	Classification Loss : 0.000026
# Train DA Epoch[89500/103400 (87%)]	Confusion Loss : 3.895915	Classification Loss : 0.000040
# Train DA Epoch[89600/103400 (87%)]	Confusion Loss : 3.927163	Classification Loss : 0.000015
# Train DA Epoch[89700/103400 (87%)]	Confusion Loss : 3.938079	Classification Loss : 0.000036
# Train DA Epoch[89800/103400 (87%)]	Confusion Loss : 4.076708	Classification Loss : 0.000313
# Train DA Epoch[89900/103400 (87%)]	Confusion Loss : 4.329944	Classification Loss : 0.000052
# Train DA Epoch[90000/103400 (87%)]	Confusion Loss : 4.139843	Classification Loss : 0.000017
# Train DA Epoch[90100/103400 (87%)]	Confusion Loss : 4.230251	Classification Loss : 0.000080
# Train DA Epoch[90200/103400 (87%)]	Confusion Loss : 4.144913	Classification Loss : 0.000446
# Train DA Epoch[90300/103400 (87%)]	Confusion Loss : 4.047853	Classification Loss : 0.000082
# Train DA Epoch[90400/103400 (87%)]	Confusion Loss : 3.991405	Classification Loss : 0.000078
# Train DA Epoch[90500/103400 (88%)]	Confusion Loss : 4.068548	Classification Loss : 0.000222
# Train DA Epoch[90600/103400 (88%)]	Confusion Loss : 3.914544	Classification Loss : 0.000013
# Train DA Epoch[90700/103400 (88%)]	Confusion Loss : 3.948187	Classification Loss : 0.000034
# Train DA Epoch[90800/103400 (88%)]	Confusion Loss : 4.108505	Classification Loss : 0.000062
# Train DA Epoch[90900/103400 (88%)]	Confusion Loss : 3.710227	Classification Loss : 0.001476
# Train DA Epoch[100400/103400 (97%)]	Confusion Loss : 4.307356	Classification Loss : 0.003393
# Train DA Epoch[100500/103400 (97%)]	Confusion Loss : 4.335460	Classification Loss : 0.000033
# Train DA Epoch[100600/103400 (97%)]	Confusion Loss : 4.242664	Classification Loss : 0.000025
# Train DA Epoch[100700/103400 (97%)]	Confusion Loss : 4.325219	Classification Loss : 0.000027
# Train DA Epoch[100800/103400 (97%)]	Confusion Loss : 4.356740	Classification Loss : 0.000076
# Train DA Epoch[100900/103400 (98%)]	Confusion Loss : 4.794979	Classification Loss : 0.000013
# Train DA Epoch[101000/103400 (98%)]	Confusion Loss : 4.593147	Classification Loss : 0.000155
# Train DA Epoch[101100/103400 (98%)]	Confusion Loss : 4.403006	Classification Loss : 0.000020
# Train DA Epoch[101200/103400 (98%)]	Confusion Loss : 4.463212	Classification Loss : 0.000125
# Train DA Epoch[101300/103400 (98%)]	Confusion Loss : 4.253223	Classification Loss : 0.000734
# Train DA Epoch[101400/103400 (98%)]	Confusion Loss : 4.175388	Classification Loss : 0.000079
# Train DA Epoch[101500/103400 (98%)]	Confusion Loss : 4.228192	Classification Loss : 0.000050
# Train DA Epoch[101600/103400 (98%)]	Confusion Loss : 4.399173	Classification Loss : 0.000034
# Train DA Epoch[101700/103400 (98%)]	Confusion Loss : 4.138845	Classification Loss : 0.000026
# Train DA Epoch[101800/103400 (98%)]	Confusion Loss : 4.257620	Classification Loss : 0.000129
# Train DA Epoch[101900/103400 (99%)]	Confusion Loss : 4.358804	Classification Loss : 0.000289
# Train DA Epoch[102000/103400 (99%)]	Confusion Loss : 4.139609	Classification Loss : 0.000067
# Train DA Epoch[102100/103400 (99%)]	Confusion Loss : 3.924468	Classification Loss : 0.000015
# Train DA Epoch[102200/103400 (99%)]	Confusion Loss : 4.290104	Classification Loss : 0.000507
# Train DA Epoch[102300/103400 (99%)]	Confusion Loss : 4.431871	Classification Loss : 0.000003
# Train DA Epoch[102400/103400 (99%)]	Confusion Loss : 4.552053	Classification Loss : 0.000087
# Train DA Epoch[102500/103400 (99%)]	Confusion Loss : 4.403359	Classification Loss : 0.000039
# Train DA Epoch[102600/103400 (99%)]	Confusion Loss : 4.215674	Classification Loss : 0.000017
# Train DA Epoch[102700/103400 (99%)]	Confusion Loss : 4.642478	Classification Loss : 0.000167
# Train DA Epoch[102800/103400 (99%)]	Confusion Loss : 3.938000	Classification Loss : 0.000036
# Train DA Epoch[102900/103400 (100%)]	Confusion Loss : 4.278487	Classification Loss : 0.000214
# Train DA Epoch[103000/103400 (100%)]	Confusion Loss : 4.320099	Classification Loss : 0.000050
# Train DA Epoch[103100/103400 (100%)]	Confusion Loss : 4.314571	Classification Loss : 0.000041
# Train DA Epoch[103200/103400 (100%)]	Confusion Loss : 4.491563	Classification Loss : 0.000040
# Train DA Epoch[103300/103400 (100%)]	Confusion Loss : 3.988146	Classification Loss : 0.000074

# %%
def trainSEG(start, max_epoch) :
    encoder = EncoderModule()
    decoder = DecoderModule()

    srcData_iter = iter(synthia_trainLoader)
    tgtData_iter = iter(cityscape_trainLoader)

    seg_optim = optim.SGD(list(encoder.parameters())+list(decoder.parameters()), lr=0.1, weight_decay=0.001, momentum=0.9)
    criterion_seg = nn.CrossEntropyLoss(ignore_index=19, reduction='mean')
    
    encoder.train()
    decoder.train()
    
    intersection_meter = AverageMeter()
    union_meter = AverageMeter()
    target_meter = AverageMeter()
    
    
    # encoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_encoder.pth"))
    
    for epoch in range(start, max_epoch) :
        
        if epoch>0 :
            encoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_encoder_fda_seg.pth"))
            decoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_decoder_fda_seg.pth"))
        
        if torch.cuda.is_available() :
            encoder = encoder.to(device)
            decoder = decoder.to(device)

        seg_optim.zero_grad()
        
        #get data and label
        try :
            src_data, src_label = next(srcData_iter)
        except StopIteration :
            srcData_iter = iter(synthia_trainLoader)
            src_data, src_label = next(srcData_iter)

        try :
            tgt_data, tgt_label = next(tgtData_iter)
        except StopIteration :
            tgtData_iter = iter(cityscape_trainLoader)
            tgt_data, tgt_label = next(tgtData_iter)
            
        src_seg_label = src_label['segmentation']
        
        src_data = FDA(src_data[0], tgt_data[0], 0.09)
        src_data = src_data.unsqueeze(0).float()

        #to GPU
        if torch.cuda.is_available() :
            src_data, src_seg_label = src_data.cuda(), src_seg_label.cuda()

        #train segmentation
        src_feature, shortcut = encoder(src_data)
        result = decoder(src_feature, shortcut)
        
        loss_seg = criterion_seg(result, src_seg_label)
        loss_seg.backward(retain_graph=True)
        seg_optim.step()
        
        intersection, union, segmentation_target = intersectionAndUnion(output=result.cpu(), target=src_seg_label.cpu(), K=19, ignore_idx=19)
        intersection_meter.update(intersection), union_meter.update(union), target_meter.update(segmentation_target)
        accuracy = sum(intersection_meter.val) / (sum(target_meter.val) + 1e-10)
        
        #print and reset iou score
        if epoch % 100 == 0 :
            iou_class = intersection_meter.sum / (union_meter.sum + 1e-10)
            accuracy_class = intersection_meter.sum / (target_meter.sum + 1e-10)
            mIOU = np.mean(iou_class)
            mAcc = np.mean(accuracy_class)
            allAcc = sum(intersection_meter.sum) / (sum(target_meter.sum) + 1e-10)
            
            print('Train Epoch : {} mIOU : {:.6f} | mACC : {:.6f}% | ACC : {:.6f}%' .format(epoch, mIOU, mAcc, allAcc))
            
            intersection_meter.reset()
            union_meter.reset()
            target_meter.reset()

        torch.save(encoder.cpu().state_dict(), "gdrive/My Drive/Colab Notebooks/uda_encoder_fda_seg.pth")
        torch.save(decoder.cpu().state_dict(), "gdrive/My Drive/Colab Notebooks/uda_decoder_fda_seg.pth")        

trainSEG(128100, 150000)
# Out:
# Train Epoch : 128100 mIOU : 0.202136 | mACC : 0.286952% | ACC : 0.620633%
# Train Epoch : 128200 mIOU : 0.215855 | mACC : 0.270555% | ACC : 0.643154%
# Train Epoch : 128300 mIOU : 0.199514 | mACC : 0.252171% | ACC : 0.621723%
# Train Epoch : 128400 mIOU : 0.210214 | mACC : 0.263120% | ACC : 0.643615%
# Train Epoch : 128500 mIOU : 0.200234 | mACC : 0.253148% | ACC : 0.611460%
# Train Epoch : 128600 mIOU : 0.201650 | mACC : 0.256468% | ACC : 0.613471%
# Train Epoch : 128700 mIOU : 0.203854 | mACC : 0.258130% | ACC : 0.615303%
# Train Epoch : 128800 mIOU : 0.196764 | mACC : 0.250727% | ACC : 0.611858%
# Train Epoch : 128900 mIOU : 0.202617 | mACC : 0.255752% | ACC : 0.627975%
# Train Epoch : 149000 mIOU : 0.196654 | mACC : 0.248755% | ACC : 0.613198%
# Train Epoch : 149100 mIOU : 0.211874 | mACC : 0.263589% | ACC : 0.646821%
# Train Epoch : 149200 mIOU : 0.206795 | mACC : 0.259863% | ACC : 0.645113%
# Train Epoch : 149300 mIOU : 0.217087 | mACC : 0.270295% | ACC : 0.653228%
# Train Epoch : 149400 mIOU : 0.205920 | mACC : 0.256690% | ACC : 0.646842%
# Train Epoch : 149500 mIOU : 0.196128 | mACC : 0.247828% | ACC : 0.608868%
# Train Epoch : 149600 mIOU : 0.199766 | mACC : 0.255026% | ACC : 0.604000%
# Train Epoch : 149700 mIOU : 0.202562 | mACC : 0.255336% | ACC : 0.643194%
# Train Epoch : 149800 mIOU : 0.198991 | mACC : 0.251729% | ACC : 0.611284%
# Train Epoch : 149900 mIOU : 0.210888 | mACC : 0.264460% | ACC : 0.640558%

# %%
srcData_iter = iter(synthia_testLoader)

encoder = EncoderModule()
domain_cls = DomainClassifier()
decoder = DecoderModule()

encoder.eval()
domain_cls.eval()
decoder.eval()

correct = torch.FloatTensor([0])
wrong = torch.FloatTensor([0])
total = torch.FloatTensor([0])

for i in range(1343) :        #1343

    if torch.cuda.is_available() :
        encoder = encoder.cuda()
        domain_cls = domain_cls.cuda()
        decoder = decoder.cuda()

    encoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_encoder_fda_once.pth"))
    domain_cls.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_domain_cls_once.pth"))

    src_data, src_label = next(srcData_iter)
    src_cls_label = src_label['classification']

    if torch.cuda.is_available() :
        src_data, src_cls_label = src_data.cuda(), src_cls_label.cuda()

    src_feature, _ = encoder(src_data)
    output = domain_cls(src_feature.detach())

    values,idx = output.max(dim=1)
    correct += torch.sum(src_cls_label==idx).float().cpu().data
    wrong += torch.sum(src_cls_label!=idx).float().cpu().data
#     print('values : ', values.data, 'output : ', idx.data, 'idx : ', src_cls_label.data)
    
    total += src_cls_label.cpu().size(0)
    print(i, '/', str(1343), 'correct : ', correct.data, 'wrong : ', wrong.data, 'total : ', total.data)
    
print("Test Data Accuracy: {}%".format(100*(correct/total).numpy()))
# Out:
# 0 / 1343 correct :  tensor([1.]) wrong :  tensor([0.]) total :  tensor([1.])
# 1 / 1343 correct :  tensor([2.]) wrong :  tensor([0.]) total :  tensor([2.])
# 2 / 1343 correct :  tensor([3.]) wrong :  tensor([0.]) total :  tensor([3.])
# 3 / 1343 correct :  tensor([4.]) wrong :  tensor([0.]) total :  tensor([4.])
# 4 / 1343 correct :  tensor([5.]) wrong :  tensor([0.]) total :  tensor([5.])
# 5 / 1343 correct :  tensor([6.]) wrong :  tensor([0.]) total :  tensor([6.])
# 6 / 1343 correct :  tensor([7.]) wrong :  tensor([0.]) total :  tensor([7.])
# 7 / 1343 correct :  tensor([8.]) wrong :  tensor([0.]) total :  tensor([8.])
# 8 / 1343 correct :  tensor([9.]) wrong :  tensor([0.]) total :  tensor([9.])
# 9 / 1343 correct :  tensor([10.]) wrong :  tensor([0.]) total :  tensor([10.])
# 10 / 1343 correct :  tensor([11.]) wrong :  tensor([0.]) total :  tensor([11.])
# 11 / 1343 correct :  tensor([12.]) wrong :  tensor([0.]) total :  tensor([12.])
# 12 / 1343 correct :  tensor([13.]) wrong :  tensor([0.]) total :  tensor([13.])
# 13 / 1343 correct :  tensor([14.]) wrong :  tensor([0.]) total :  tensor([14.])
# 14 / 1343 correct :  tensor([15.]) wrong :  tensor([0.]) total :  tensor([15.])
# 15 / 1343 correct :  tensor([16.]) wrong :  tensor([0.]) total :  tensor([16.])
# 16 / 1343 correct :  tensor([17.]) wrong :  tensor([0.]) total :  tensor([17.])
# 17 / 1343 correct :  tensor([18.]) wrong :  tensor([0.]) total :  tensor([18.])
# 18 / 1343 correct :  tensor([19.]) wrong :  tensor([0.]) total :  tensor([19.])
# 19 / 1343 correct :  tensor([20.]) wrong :  tensor([0.]) total :  tensor([20.])
# 20 / 1343 correct :  tensor([20.]) wrong :  tensor([1.]) total :  tensor([21.])
# 21 / 1343 correct :  tensor([21.]) wrong :  tensor([1.]) total :  tensor([22.])
# 22 / 1343 correct :  tensor([22.]) wrong :  tensor([1.]) total :  tensor([23.])
# 23 / 1343 correct :  tensor([23.]) wrong :  tensor([1.]) total :  tensor([24.])
# 24 / 1343 correct :  tensor([24.]) wrong :  tensor([1.]) total :  tensor([25.])
# 25 / 1343 correct :  tensor([25.]) wrong :  tensor([1.]) total :  tensor([26.])
# 26 / 1343 correct :  tensor([26.]) wrong :  tensor([1.]) total :  tensor([27.])
# 27 / 1343 correct :  tensor([27.]) wrong :  tensor([1.]) total :  tensor([28.])
# 28 / 1343 correct :  tensor([28.]) wrong :  tensor([1.]) total :  tensor([29.])
# 29 / 1343 correct :  tensor([29.]) wrong :  tensor([1.]) total :  tensor([30.])
# 30 / 1343 correct :  tensor([30.]) wrong :  tensor([1.]) total :  tensor([31.])
# 31 / 1343 correct :  tensor([31.]) wrong :  tensor([1.]) total :  tensor([32.])
# 32 / 1343 correct :  tensor([32.]) wrong :  tensor([1.]) total :  tensor([33.])
# 33 / 1343 correct :  tensor([33.]) wrong :  tensor([1.]) total :  tensor([34.])
# 34 / 1343 correct :  tensor([34.]) wrong :  tensor([1.]) total :  tensor([35.])
# 35 / 1343 correct :  tensor([35.]) wrong :  tensor([1.]) total :  tensor([36.])
# 36 / 1343 correct :  tensor([36.]) wrong :  tensor([1.]) total :  tensor([37.])
# 37 / 1343 correct :  tensor([37.]) wrong :  tensor([1.]) total :  tensor([38.])
# 38 / 1343 correct :  tensor([38.]) wrong :  tensor([1.]) total :  tensor([39.])
# 39 / 1343 correct :  tensor([39.]) wrong :  tensor([1.]) total :  tensor([40.])
# 40 / 1343 correct :  tensor([40.]) wrong :  tensor([1.]) total :  tensor([41.])
# 41 / 1343 correct :  tensor([41.]) wrong :  tensor([1.]) total :  tensor([42.])
# 42 / 1343 correct :  tensor([42.]) wrong :  tensor([1.]) total :  tensor([43.])
# 43 / 1343 correct :  tensor([43.]) wrong :  tensor([1.]) total :  tensor([44.])
# 44 / 1343 correct :  tensor([44.]) wrong :  tensor([1.]) total :  tensor([45.])
# 45 / 1343 correct :  tensor([45.]) wrong :  tensor([1.]) total :  tensor([46.])
# 46 / 1343 correct :  tensor([46.]) wrong :  tensor([1.]) total :  tensor([47.])
# 47 / 1343 correct :  tensor([47.]) wrong :  tensor([1.]) total :  tensor([48.])
# 48 / 1343 correct :  tensor([48.]) wrong :  tensor([1.]) total :  tensor([49.])
# 49 / 1343 correct :  tensor([49.]) wrong :  tensor([1.]) total :  tensor([50.])
# 50 / 1343 correct :  tensor([50.]) wrong :  tensor([1.]) total :  tensor([51.])
# 51 / 1343 correct :  tensor([50.]) wrong :  tensor([2.]) total :  tensor([52.])
# 52 / 1343 correct :  tensor([51.]) wrong :  tensor([2.]) total :  tensor([53.])
# 53 / 1343 correct :  tensor([52.]) wrong :  tensor([2.]) total :  tensor([54.])
# 54 / 1343 correct :  tensor([53.]) wrong :  tensor([2.]) total :  tensor([55.])
# 55 / 1343 correct :  tensor([54.]) wrong :  tensor([2.]) total :  tensor([56.])
# 56 / 1343 correct :  tensor([55.]) wrong :  tensor([2.]) total :  tensor([57.])
# 57 / 1343 correct :  tensor([56.]) wrong :  tensor([2.]) total :  tensor([58.])
# 58 / 1343 correct :  tensor([57.]) wrong :  tensor([2.]) total :  tensor([59.])
# 59 / 1343 correct :  tensor([58.]) wrong :  tensor([2.]) total :  tensor([60.])
# 60 / 1343 correct :  tensor([59.]) wrong :  tensor([2.]) total :  tensor([61.])
# 61 / 1343 correct :  tensor([60.]) wrong :  tensor([2.]) total :  tensor([62.])
# 62 / 1343 correct :  tensor([61.]) wrong :  tensor([2.]) total :  tensor([63.])
# 63 / 1343 correct :  tensor([62.]) wrong :  tensor([2.]) total :  tensor([64.])
# 64 / 1343 correct :  tensor([63.]) wrong :  tensor([2.]) total :  tensor([65.])
# 65 / 1343 correct :  tensor([64.]) wrong :  tensor([2.]) total :  tensor([66.])
# 66 / 1343 correct :  tensor([65.]) wrong :  tensor([2.]) total :  tensor([67.])
# 67 / 1343 correct :  tensor([66.]) wrong :  tensor([2.]) total :  tensor([68.])
# 68 / 1343 correct :  tensor([67.]) wrong :  tensor([2.]) total :  tensor([69.])
# 69 / 1343 correct :  tensor([68.]) wrong :  tensor([2.]) total :  tensor([70.])
# 70 / 1343 correct :  tensor([69.]) wrong :  tensor([2.]) total :  tensor([71.])
# 71 / 1343 correct :  tensor([70.]) wrong :  tensor([2.]) total :  tensor([72.])
# 72 / 1343 correct :  tensor([71.]) wrong :  tensor([2.]) total :  tensor([73.])
# 73 / 1343 correct :  tensor([72.]) wrong :  tensor([2.]) total :  tensor([74.])
# 74 / 1343 correct :  tensor([73.]) wrong :  tensor([2.]) total :  tensor([75.])
# 75 / 1343 correct :  tensor([74.]) wrong :  tensor([2.]) total :  tensor([76.])
# 76 / 1343 correct :  tensor([75.]) wrong :  tensor([2.]) total :  tensor([77.])
# 77 / 1343 correct :  tensor([76.]) wrong :  tensor([2.]) total :  tensor([78.])
# 78 / 1343 correct :  tensor([77.]) wrong :  tensor([2.]) total :  tensor([79.])
# 79 / 1343 correct :  tensor([78.]) wrong :  tensor([2.]) total :  tensor([80.])
# 80 / 1343 correct :  tensor([79.]) wrong :  tensor([2.]) total :  tensor([81.])
# 81 / 1343 correct :  tensor([80.]) wrong :  tensor([2.]) total :  tensor([82.])
# 82 / 1343 correct :  tensor([81.]) wrong :  tensor([2.]) total :  tensor([83.])
# 83 / 1343 correct :  tensor([82.]) wrong :  tensor([2.]) total :  tensor([84.])
# 84 / 1343 correct :  tensor([83.]) wrong :  tensor([2.]) total :  tensor([85.])
# 85 / 1343 correct :  tensor([83.]) wrong :  tensor([3.]) total :  tensor([86.])
# 86 / 1343 correct :  tensor([84.]) wrong :  tensor([3.]) total :  tensor([87.])
# 87 / 1343 correct :  tensor([85.]) wrong :  tensor([3.]) total :  tensor([88.])
# 88 / 1343 correct :  tensor([86.]) wrong :  tensor([3.]) total :  tensor([89.])
# 89 / 1343 correct :  tensor([87.]) wrong :  tensor([3.]) total :  tensor([90.])
# 90 / 1343 correct :  tensor([88.]) wrong :  tensor([3.]) total :  tensor([91.])
# 91 / 1343 correct :  tensor([89.]) wrong :  tensor([3.]) total :  tensor([92.])
# 92 / 1343 correct :  tensor([90.]) wrong :  tensor([3.]) total :  tensor([93.])
# 93 / 1343 correct :  tensor([91.]) wrong :  tensor([3.]) total :  tensor([94.])
# 94 / 1343 correct :  tensor([92.]) wrong :  tensor([3.]) total :  tensor([95.])
# 95 / 1343 correct :  tensor([93.]) wrong :  tensor([3.]) total :  tensor([96.])
# 96 / 1343 correct :  tensor([94.]) wrong :  tensor([3.]) total :  tensor([97.])
# 97 / 1343 correct :  tensor([95.]) wrong :  tensor([3.]) total :  tensor([98.])
# 98 / 1343 correct :  tensor([96.]) wrong :  tensor([3.]) total :  tensor([99.])
# 99 / 1343 correct :  tensor([97.]) wrong :  tensor([3.]) total :  tensor([100.])
# 100 / 1343 correct :  tensor([98.]) wrong :  tensor([3.]) total :  tensor([101.])
# 101 / 1343 correct :  tensor([99.]) wrong :  tensor([3.]) total :  tensor([102.])
# 102 / 1343 correct :  tensor([100.]) wrong :  tensor([3.]) total :  tensor([103.])
# 103 / 1343 correct :  tensor([101.]) wrong :  tensor([3.]) total :  tensor([104.])
# 104 / 1343 correct :  tensor([102.]) wrong :  tensor([3.]) total :  tensor([105.])
# 105 / 1343 correct :  tensor([103.]) wrong :  tensor([3.]) total :  tensor([106.])
# 106 / 1343 correct :  tensor([104.]) wrong :  tensor([3.]) total :  tensor([107.])
# 107 / 1343 correct :  tensor([105.]) wrong :  tensor([3.]) total :  tensor([108.])
# 108 / 1343 correct :  tensor([106.]) wrong :  tensor([3.]) total :  tensor([109.])
# 109 / 1343 correct :  tensor([107.]) wrong :  tensor([3.]) total :  tensor([110.])
# 110 / 1343 correct :  tensor([108.]) wrong :  tensor([3.]) total :  tensor([111.])
# 111 / 1343 correct :  tensor([109.]) wrong :  tensor([3.]) total :  tensor([112.])
# 112 / 1343 correct :  tensor([110.]) wrong :  tensor([3.]) total :  tensor([113.])
# 113 / 1343 correct :  tensor([110.]) wrong :  tensor([4.]) total :  tensor([114.])
# 114 / 1343 correct :  tensor([111.]) wrong :  tensor([4.]) total :  tensor([115.])
# 115 / 1343 correct :  tensor([112.]) wrong :  tensor([4.]) total :  tensor([116.])
# 116 / 1343 correct :  tensor([113.]) wrong :  tensor([4.]) total :  tensor([117.])
# 117 / 1343 correct :  tensor([114.]) wrong :  tensor([4.]) total :  tensor([118.])
# 118 / 1343 correct :  tensor([115.]) wrong :  tensor([4.]) total :  tensor([119.])
# 119 / 1343 correct :  tensor([116.]) wrong :  tensor([4.]) total :  tensor([120.])
# 120 / 1343 correct :  tensor([117.]) wrong :  tensor([4.]) total :  tensor([121.])
# 121 / 1343 correct :  tensor([118.]) wrong :  tensor([4.]) total :  tensor([122.])
# 122 / 1343 correct :  tensor([119.]) wrong :  tensor([4.]) total :  tensor([123.])
# 123 / 1343 correct :  tensor([120.]) wrong :  tensor([4.]) total :  tensor([124.])
# 124 / 1343 correct :  tensor([121.]) wrong :  tensor([4.]) total :  tensor([125.])
# 125 / 1343 correct :  tensor([122.]) wrong :  tensor([4.]) total :  tensor([126.])
# 126 / 1343 correct :  tensor([123.]) wrong :  tensor([4.]) total :  tensor([127.])
# 127 / 1343 correct :  tensor([124.]) wrong :  tensor([4.]) total :  tensor([128.])
# 128 / 1343 correct :  tensor([125.]) wrong :  tensor([4.]) total :  tensor([129.])
# 129 / 1343 correct :  tensor([126.]) wrong :  tensor([4.]) total :  tensor([130.])
# 130 / 1343 correct :  tensor([127.]) wrong :  tensor([4.]) total :  tensor([131.])
# 131 / 1343 correct :  tensor([128.]) wrong :  tensor([4.]) total :  tensor([132.])
# 132 / 1343 correct :  tensor([129.]) wrong :  tensor([4.]) total :  tensor([133.])
# 133 / 1343 correct :  tensor([130.]) wrong :  tensor([4.]) total :  tensor([134.])
# 134 / 1343 correct :  tensor([131.]) wrong :  tensor([4.]) total :  tensor([135.])
# 135 / 1343 correct :  tensor([132.]) wrong :  tensor([4.]) total :  tensor([136.])
# 136 / 1343 correct :  tensor([133.]) wrong :  tensor([4.]) total :  tensor([137.])
# 137 / 1343 correct :  tensor([134.]) wrong :  tensor([4.]) total :  tensor([138.])
# 138 / 1343 correct :  tensor([135.]) wrong :  tensor([4.]) total :  tensor([139.])
# 139 / 1343 correct :  tensor([136.]) wrong :  tensor([4.]) total :  tensor([140.])
# 140 / 1343 correct :  tensor([137.]) wrong :  tensor([4.]) total :  tensor([141.])
# 141 / 1343 correct :  tensor([138.]) wrong :  tensor([4.]) total :  tensor([142.])
# 142 / 1343 correct :  tensor([139.]) wrong :  tensor([4.]) total :  tensor([143.])
# 143 / 1343 correct :  tensor([140.]) wrong :  tensor([4.]) total :  tensor([144.])
# 144 / 1343 correct :  tensor([141.]) wrong :  tensor([4.]) total :  tensor([145.])
# 145 / 1343 correct :  tensor([142.]) wrong :  tensor([4.]) total :  tensor([146.])
# 146 / 1343 correct :  tensor([143.]) wrong :  tensor([4.]) total :  tensor([147.])
# 147 / 1343 correct :  tensor([144.]) wrong :  tensor([4.]) total :  tensor([148.])
# 148 / 1343 correct :  tensor([145.]) wrong :  tensor([4.]) total :  tensor([149.])
# 149 / 1343 correct :  tensor([146.]) wrong :  tensor([4.]) total :  tensor([150.])
# 150 / 1343 correct :  tensor([147.]) wrong :  tensor([4.]) total :  tensor([151.])
# 151 / 1343 correct :  tensor([148.]) wrong :  tensor([4.]) total :  tensor([152.])
# 152 / 1343 correct :  tensor([149.]) wrong :  tensor([4.]) total :  tensor([153.])
# 153 / 1343 correct :  tensor([150.]) wrong :  tensor([4.]) total :  tensor([154.])
# 154 / 1343 correct :  tensor([151.]) wrong :  tensor([4.]) total :  tensor([155.])
# 155 / 1343 correct :  tensor([152.]) wrong :  tensor([4.]) total :  tensor([156.])
# 156 / 1343 correct :  tensor([153.]) wrong :  tensor([4.]) total :  tensor([157.])
# 157 / 1343 correct :  tensor([154.]) wrong :  tensor([4.]) total :  tensor([158.])
# 158 / 1343 correct :  tensor([155.]) wrong :  tensor([4.]) total :  tensor([159.])
# 159 / 1343 correct :  tensor([156.]) wrong :  tensor([4.]) total :  tensor([160.])
# 160 / 1343 correct :  tensor([157.]) wrong :  tensor([4.]) total :  tensor([161.])
# 161 / 1343 correct :  tensor([158.]) wrong :  tensor([4.]) total :  tensor([162.])
# 162 / 1343 correct :  tensor([159.]) wrong :  tensor([4.]) total :  tensor([163.])
# 163 / 1343 correct :  tensor([160.]) wrong :  tensor([4.]) total :  tensor([164.])
# 164 / 1343 correct :  tensor([161.]) wrong :  tensor([4.]) total :  tensor([165.])
# 165 / 1343 correct :  tensor([162.]) wrong :  tensor([4.]) total :  tensor([166.])
# 166 / 1343 correct :  tensor([163.]) wrong :  tensor([4.]) total :  tensor([167.])
# 167 / 1343 correct :  tensor([164.]) wrong :  tensor([4.]) total :  tensor([168.])
# 168 / 1343 correct :  tensor([165.]) wrong :  tensor([4.]) total :  tensor([169.])
# 169 / 1343 correct :  tensor([166.]) wrong :  tensor([4.]) total :  tensor([170.])
# 170 / 1343 correct :  tensor([167.]) wrong :  tensor([4.]) total :  tensor([171.])
# 171 / 1343 correct :  tensor([168.]) wrong :  tensor([4.]) total :  tensor([172.])
# 172 / 1343 correct :  tensor([169.]) wrong :  tensor([4.]) total :  tensor([173.])
# 173 / 1343 correct :  tensor([170.]) wrong :  tensor([4.]) total :  tensor([174.])
# 174 / 1343 correct :  tensor([171.]) wrong :  tensor([4.]) total :  tensor([175.])
# 175 / 1343 correct :  tensor([172.]) wrong :  tensor([4.]) total :  tensor([176.])
# 176 / 1343 correct :  tensor([173.]) wrong :  tensor([4.]) total :  tensor([177.])
# 177 / 1343 correct :  tensor([174.]) wrong :  tensor([4.]) total :  tensor([178.])
# 178 / 1343 correct :  tensor([175.]) wrong :  tensor([4.]) total :  tensor([179.])
# 179 / 1343 correct :  tensor([176.]) wrong :  tensor([4.]) total :  tensor([180.])
# 180 / 1343 correct :  tensor([177.]) wrong :  tensor([4.]) total :  tensor([181.])
# 181 / 1343 correct :  tensor([178.]) wrong :  tensor([4.]) total :  tensor([182.])
# 182 / 1343 correct :  tensor([179.]) wrong :  tensor([4.]) total :  tensor([183.])
# 183 / 1343 correct :  tensor([180.]) wrong :  tensor([4.]) total :  tensor([184.])
# 184 / 1343 correct :  tensor([181.]) wrong :  tensor([4.]) total :  tensor([185.])
# 185 / 1343 correct :  tensor([182.]) wrong :  tensor([4.]) total :  tensor([186.])
# 186 / 1343 correct :  tensor([183.]) wrong :  tensor([4.]) total :  tensor([187.])
# 187 / 1343 correct :  tensor([184.]) wrong :  tensor([4.]) total :  tensor([188.])
# 188 / 1343 correct :  tensor([185.]) wrong :  tensor([4.]) total :  tensor([189.])
# 189 / 1343 correct :  tensor([186.]) wrong :  tensor([4.]) total :  tensor([190.])
# 190 / 1343 correct :  tensor([187.]) wrong :  tensor([4.]) total :  tensor([191.])
# 191 / 1343 correct :  tensor([188.]) wrong :  tensor([4.]) total :  tensor([192.])
# 192 / 1343 correct :  tensor([189.]) wrong :  tensor([4.]) total :  tensor([193.])
# 193 / 1343 correct :  tensor([190.]) wrong :  tensor([4.]) total :  tensor([194.])
# 194 / 1343 correct :  tensor([191.]) wrong :  tensor([4.]) total :  tensor([195.])
# 195 / 1343 correct :  tensor([192.]) wrong :  tensor([4.]) total :  tensor([196.])
# 196 / 1343 correct :  tensor([193.]) wrong :  tensor([4.]) total :  tensor([197.])
# 197 / 1343 correct :  tensor([194.]) wrong :  tensor([4.]) total :  tensor([198.])
# 198 / 1343 correct :  tensor([195.]) wrong :  tensor([4.]) total :  tensor([199.])
# 199 / 1343 correct :  tensor([196.]) wrong :  tensor([4.]) total :  tensor([200.])
# 200 / 1343 correct :  tensor([197.]) wrong :  tensor([4.]) total :  tensor([201.])
# 201 / 1343 correct :  tensor([198.]) wrong :  tensor([4.]) total :  tensor([202.])
# 202 / 1343 correct :  tensor([199.]) wrong :  tensor([4.]) total :  tensor([203.])
# 203 / 1343 correct :  tensor([200.]) wrong :  tensor([4.]) total :  tensor([204.])
# 204 / 1343 correct :  tensor([201.]) wrong :  tensor([4.]) total :  tensor([205.])
# 205 / 1343 correct :  tensor([202.]) wrong :  tensor([4.]) total :  tensor([206.])
# 206 / 1343 correct :  tensor([203.]) wrong :  tensor([4.]) total :  tensor([207.])
# 207 / 1343 correct :  tensor([204.]) wrong :  tensor([4.]) total :  tensor([208.])
# 208 / 1343 correct :  tensor([205.]) wrong :  tensor([4.]) total :  tensor([209.])
# 209 / 1343 correct :  tensor([206.]) wrong :  tensor([4.]) total :  tensor([210.])
# 210 / 1343 correct :  tensor([207.]) wrong :  tensor([4.]) total :  tensor([211.])
# 211 / 1343 correct :  tensor([208.]) wrong :  tensor([4.]) total :  tensor([212.])
# 212 / 1343 correct :  tensor([209.]) wrong :  tensor([4.]) total :  tensor([213.])
# 213 / 1343 correct :  tensor([210.]) wrong :  tensor([4.]) total :  tensor([214.])
# 214 / 1343 correct :  tensor([211.]) wrong :  tensor([4.]) total :  tensor([215.])
# 215 / 1343 correct :  tensor([212.]) wrong :  tensor([4.]) total :  tensor([216.])
# 216 / 1343 correct :  tensor([213.]) wrong :  tensor([4.]) total :  tensor([217.])
# 217 / 1343 correct :  tensor([213.]) wrong :  tensor([5.]) total :  tensor([218.])
# 218 / 1343 correct :  tensor([214.]) wrong :  tensor([5.]) total :  tensor([219.])
# 219 / 1343 correct :  tensor([215.]) wrong :  tensor([5.]) total :  tensor([220.])
# 220 / 1343 correct :  tensor([216.]) wrong :  tensor([5.]) total :  tensor([221.])
# 221 / 1343 correct :  tensor([217.]) wrong :  tensor([5.]) total :  tensor([222.])
# 222 / 1343 correct :  tensor([218.]) wrong :  tensor([5.]) total :  tensor([223.])
# 223 / 1343 correct :  tensor([219.]) wrong :  tensor([5.]) total :  tensor([224.])
# 224 / 1343 correct :  tensor([220.]) wrong :  tensor([5.]) total :  tensor([225.])
# 225 / 1343 correct :  tensor([221.]) wrong :  tensor([5.]) total :  tensor([226.])
# 226 / 1343 correct :  tensor([222.]) wrong :  tensor([5.]) total :  tensor([227.])
# 227 / 1343 correct :  tensor([223.]) wrong :  tensor([5.]) total :  tensor([228.])
# 228 / 1343 correct :  tensor([224.]) wrong :  tensor([5.]) total :  tensor([229.])
# 229 / 1343 correct :  tensor([225.]) wrong :  tensor([5.]) total :  tensor([230.])
# 230 / 1343 correct :  tensor([226.]) wrong :  tensor([5.]) total :  tensor([231.])
# 231 / 1343 correct :  tensor([227.]) wrong :  tensor([5.]) total :  tensor([232.])
# 232 / 1343 correct :  tensor([228.]) wrong :  tensor([5.]) total :  tensor([233.])
# 233 / 1343 correct :  tensor([229.]) wrong :  tensor([5.]) total :  tensor([234.])
# 234 / 1343 correct :  tensor([230.]) wrong :  tensor([5.]) total :  tensor([235.])
# 235 / 1343 correct :  tensor([231.]) wrong :  tensor([5.]) total :  tensor([236.])
# 236 / 1343 correct :  tensor([232.]) wrong :  tensor([5.]) total :  tensor([237.])
# 237 / 1343 correct :  tensor([233.]) wrong :  tensor([5.]) total :  tensor([238.])
# 238 / 1343 correct :  tensor([234.]) wrong :  tensor([5.]) total :  tensor([239.])
# 239 / 1343 correct :  tensor([235.]) wrong :  tensor([5.]) total :  tensor([240.])
# 240 / 1343 correct :  tensor([236.]) wrong :  tensor([5.]) total :  tensor([241.])
# 241 / 1343 correct :  tensor([237.]) wrong :  tensor([5.]) total :  tensor([242.])
# 242 / 1343 correct :  tensor([238.]) wrong :  tensor([5.]) total :  tensor([243.])
# 243 / 1343 correct :  tensor([239.]) wrong :  tensor([5.]) total :  tensor([244.])
# 244 / 1343 correct :  tensor([240.]) wrong :  tensor([5.]) total :  tensor([245.])
# 245 / 1343 correct :  tensor([241.]) wrong :  tensor([5.]) total :  tensor([246.])
# 246 / 1343 correct :  tensor([241.]) wrong :  tensor([6.]) total :  tensor([247.])
# 247 / 1343 correct :  tensor([241.]) wrong :  tensor([7.]) total :  tensor([248.])
# 248 / 1343 correct :  tensor([242.]) wrong :  tensor([7.]) total :  tensor([249.])
# 249 / 1343 correct :  tensor([243.]) wrong :  tensor([7.]) total :  tensor([250.])
# 250 / 1343 correct :  tensor([244.]) wrong :  tensor([7.]) total :  tensor([251.])
# 251 / 1343 correct :  tensor([245.]) wrong :  tensor([7.]) total :  tensor([252.])
# 252 / 1343 correct :  tensor([246.]) wrong :  tensor([7.]) total :  tensor([253.])
# 253 / 1343 correct :  tensor([247.]) wrong :  tensor([7.]) total :  tensor([254.])
# 254 / 1343 correct :  tensor([248.]) wrong :  tensor([7.]) total :  tensor([255.])
# 255 / 1343 correct :  tensor([248.]) wrong :  tensor([8.]) total :  tensor([256.])
# 256 / 1343 correct :  tensor([249.]) wrong :  tensor([8.]) total :  tensor([257.])
# 257 / 1343 correct :  tensor([250.]) wrong :  tensor([8.]) total :  tensor([258.])
# 258 / 1343 correct :  tensor([251.]) wrong :  tensor([8.]) total :  tensor([259.])
# 259 / 1343 correct :  tensor([252.]) wrong :  tensor([8.]) total :  tensor([260.])
# 260 / 1343 correct :  tensor([253.]) wrong :  tensor([8.]) total :  tensor([261.])
# 261 / 1343 correct :  tensor([254.]) wrong :  tensor([8.]) total :  tensor([262.])
# 262 / 1343 correct :  tensor([255.]) wrong :  tensor([8.]) total :  tensor([263.])
# 263 / 1343 correct :  tensor([256.]) wrong :  tensor([8.]) total :  tensor([264.])
# 264 / 1343 correct :  tensor([257.]) wrong :  tensor([8.]) total :  tensor([265.])
# 265 / 1343 correct :  tensor([258.]) wrong :  tensor([8.]) total :  tensor([266.])
# 266 / 1343 correct :  tensor([259.]) wrong :  tensor([8.]) total :  tensor([267.])
# 267 / 1343 correct :  tensor([260.]) wrong :  tensor([8.]) total :  tensor([268.])
# 268 / 1343 correct :  tensor([261.]) wrong :  tensor([8.]) total :  tensor([269.])
# 269 / 1343 correct :  tensor([262.]) wrong :  tensor([8.]) total :  tensor([270.])
# 270 / 1343 correct :  tensor([263.]) wrong :  tensor([8.]) total :  tensor([271.])
# 271 / 1343 correct :  tensor([264.]) wrong :  tensor([8.]) total :  tensor([272.])
# 272 / 1343 correct :  tensor([265.]) wrong :  tensor([8.]) total :  tensor([273.])
# 273 / 1343 correct :  tensor([266.]) wrong :  tensor([8.]) total :  tensor([274.])
# 274 / 1343 correct :  tensor([267.]) wrong :  tensor([8.]) total :  tensor([275.])
# 275 / 1343 correct :  tensor([268.]) wrong :  tensor([8.]) total :  tensor([276.])
# 276 / 1343 correct :  tensor([269.]) wrong :  tensor([8.]) total :  tensor([277.])
# 277 / 1343 correct :  tensor([270.]) wrong :  tensor([8.]) total :  tensor([278.])
# 278 / 1343 correct :  tensor([271.]) wrong :  tensor([8.]) total :  tensor([279.])
# 279 / 1343 correct :  tensor([272.]) wrong :  tensor([8.]) total :  tensor([280.])
# 280 / 1343 correct :  tensor([273.]) wrong :  tensor([8.]) total :  tensor([281.])
# 281 / 1343 correct :  tensor([274.]) wrong :  tensor([8.]) total :  tensor([282.])
# 282 / 1343 correct :  tensor([275.]) wrong :  tensor([8.]) total :  tensor([283.])
# 283 / 1343 correct :  tensor([276.]) wrong :  tensor([8.]) total :  tensor([284.])
# 284 / 1343 correct :  tensor([277.]) wrong :  tensor([8.]) total :  tensor([285.])
# 285 / 1343 correct :  tensor([278.]) wrong :  tensor([8.]) total :  tensor([286.])
# 286 / 1343 correct :  tensor([279.]) wrong :  tensor([8.]) total :  tensor([287.])
# 287 / 1343 correct :  tensor([280.]) wrong :  tensor([8.]) total :  tensor([288.])
# 288 / 1343 correct :  tensor([281.]) wrong :  tensor([8.]) total :  tensor([289.])
# 289 / 1343 correct :  tensor([282.]) wrong :  tensor([8.]) total :  tensor([290.])
# 290 / 1343 correct :  tensor([283.]) wrong :  tensor([8.]) total :  tensor([291.])
# 291 / 1343 correct :  tensor([284.]) wrong :  tensor([8.]) total :  tensor([292.])
# 292 / 1343 correct :  tensor([285.]) wrong :  tensor([8.]) total :  tensor([293.])
# 293 / 1343 correct :  tensor([286.]) wrong :  tensor([8.]) total :  tensor([294.])
# 294 / 1343 correct :  tensor([287.]) wrong :  tensor([8.]) total :  tensor([295.])
# 295 / 1343 correct :  tensor([288.]) wrong :  tensor([8.]) total :  tensor([296.])
# 296 / 1343 correct :  tensor([289.]) wrong :  tensor([8.]) total :  tensor([297.])
# 297 / 1343 correct :  tensor([290.]) wrong :  tensor([8.]) total :  tensor([298.])
# 298 / 1343 correct :  tensor([291.]) wrong :  tensor([8.]) total :  tensor([299.])
# 299 / 1343 correct :  tensor([292.]) wrong :  tensor([8.]) total :  tensor([300.])
# 300 / 1343 correct :  tensor([293.]) wrong :  tensor([8.]) total :  tensor([301.])
# 301 / 1343 correct :  tensor([294.]) wrong :  tensor([8.]) total :  tensor([302.])
# 302 / 1343 correct :  tensor([295.]) wrong :  tensor([8.]) total :  tensor([303.])
# 303 / 1343 correct :  tensor([296.]) wrong :  tensor([8.]) total :  tensor([304.])
# 304 / 1343 correct :  tensor([297.]) wrong :  tensor([8.]) total :  tensor([305.])
# 305 / 1343 correct :  tensor([298.]) wrong :  tensor([8.]) total :  tensor([306.])
# 306 / 1343 correct :  tensor([299.]) wrong :  tensor([8.]) total :  tensor([307.])
# 307 / 1343 correct :  tensor([300.]) wrong :  tensor([8.]) total :  tensor([308.])
# 308 / 1343 correct :  tensor([301.]) wrong :  tensor([8.]) total :  tensor([309.])
# 309 / 1343 correct :  tensor([302.]) wrong :  tensor([8.]) total :  tensor([310.])
# 310 / 1343 correct :  tensor([303.]) wrong :  tensor([8.]) total :  tensor([311.])
# 311 / 1343 correct :  tensor([304.]) wrong :  tensor([8.]) total :  tensor([312.])
# 312 / 1343 correct :  tensor([304.]) wrong :  tensor([9.]) total :  tensor([313.])
# 313 / 1343 correct :  tensor([305.]) wrong :  tensor([9.]) total :  tensor([314.])
# 314 / 1343 correct :  tensor([306.]) wrong :  tensor([9.]) total :  tensor([315.])
# 315 / 1343 correct :  tensor([307.]) wrong :  tensor([9.]) total :  tensor([316.])
# 316 / 1343 correct :  tensor([308.]) wrong :  tensor([9.]) total :  tensor([317.])
# 317 / 1343 correct :  tensor([309.]) wrong :  tensor([9.]) total :  tensor([318.])
# 318 / 1343 correct :  tensor([310.]) wrong :  tensor([9.]) total :  tensor([319.])
# 319 / 1343 correct :  tensor([311.]) wrong :  tensor([9.]) total :  tensor([320.])
# 320 / 1343 correct :  tensor([312.]) wrong :  tensor([9.]) total :  tensor([321.])
# 321 / 1343 correct :  tensor([313.]) wrong :  tensor([9.]) total :  tensor([322.])
# 322 / 1343 correct :  tensor([314.]) wrong :  tensor([9.]) total :  tensor([323.])
# 323 / 1343 correct :  tensor([315.]) wrong :  tensor([9.]) total :  tensor([324.])
# 324 / 1343 correct :  tensor([316.]) wrong :  tensor([9.]) total :  tensor([325.])
# 325 / 1343 correct :  tensor([317.]) wrong :  tensor([9.]) total :  tensor([326.])
# 326 / 1343 correct :  tensor([318.]) wrong :  tensor([9.]) total :  tensor([327.])
# 327 / 1343 correct :  tensor([318.]) wrong :  tensor([10.]) total :  tensor([328.])
# 328 / 1343 correct :  tensor([319.]) wrong :  tensor([10.]) total :  tensor([329.])
# 329 / 1343 correct :  tensor([320.]) wrong :  tensor([10.]) total :  tensor([330.])
# 330 / 1343 correct :  tensor([321.]) wrong :  tensor([10.]) total :  tensor([331.])
# 331 / 1343 correct :  tensor([321.]) wrong :  tensor([11.]) total :  tensor([332.])
# 332 / 1343 correct :  tensor([322.]) wrong :  tensor([11.]) total :  tensor([333.])
# 333 / 1343 correct :  tensor([323.]) wrong :  tensor([11.]) total :  tensor([334.])
# 334 / 1343 correct :  tensor([324.]) wrong :  tensor([11.]) total :  tensor([335.])
# 335 / 1343 correct :  tensor([325.]) wrong :  tensor([11.]) total :  tensor([336.])
# 336 / 1343 correct :  tensor([326.]) wrong :  tensor([11.]) total :  tensor([337.])
# 337 / 1343 correct :  tensor([327.]) wrong :  tensor([11.]) total :  tensor([338.])
# 338 / 1343 correct :  tensor([328.]) wrong :  tensor([11.]) total :  tensor([339.])
# 339 / 1343 correct :  tensor([329.]) wrong :  tensor([11.]) total :  tensor([340.])
# 340 / 1343 correct :  tensor([330.]) wrong :  tensor([11.]) total :  tensor([341.])
# 341 / 1343 correct :  tensor([331.]) wrong :  tensor([11.]) total :  tensor([342.])
# 342 / 1343 correct :  tensor([332.]) wrong :  tensor([11.]) total :  tensor([343.])
# 343 / 1343 correct :  tensor([333.]) wrong :  tensor([11.]) total :  tensor([344.])
# 344 / 1343 correct :  tensor([334.]) wrong :  tensor([11.]) total :  tensor([345.])
# 345 / 1343 correct :  tensor([335.]) wrong :  tensor([11.]) total :  tensor([346.])
# 346 / 1343 correct :  tensor([336.]) wrong :  tensor([11.]) total :  tensor([347.])
# 347 / 1343 correct :  tensor([337.]) wrong :  tensor([11.]) total :  tensor([348.])
# 348 / 1343 correct :  tensor([338.]) wrong :  tensor([11.]) total :  tensor([349.])
# 349 / 1343 correct :  tensor([339.]) wrong :  tensor([11.]) total :  tensor([350.])
# 350 / 1343 correct :  tensor([340.]) wrong :  tensor([11.]) total :  tensor([351.])
# 351 / 1343 correct :  tensor([341.]) wrong :  tensor([11.]) total :  tensor([352.])
# 352 / 1343 correct :  tensor([342.]) wrong :  tensor([11.]) total :  tensor([353.])
# 353 / 1343 correct :  tensor([343.]) wrong :  tensor([11.]) total :  tensor([354.])
# 354 / 1343 correct :  tensor([344.]) wrong :  tensor([11.]) total :  tensor([355.])
# 355 / 1343 correct :  tensor([345.]) wrong :  tensor([11.]) total :  tensor([356.])
# 356 / 1343 correct :  tensor([346.]) wrong :  tensor([11.]) total :  tensor([357.])
# 357 / 1343 correct :  tensor([347.]) wrong :  tensor([11.]) total :  tensor([358.])
# 358 / 1343 correct :  tensor([348.]) wrong :  tensor([11.]) total :  tensor([359.])
# 359 / 1343 correct :  tensor([349.]) wrong :  tensor([11.]) total :  tensor([360.])
# 360 / 1343 correct :  tensor([350.]) wrong :  tensor([11.]) total :  tensor([361.])
# 361 / 1343 correct :  tensor([351.]) wrong :  tensor([11.]) total :  tensor([362.])
# 362 / 1343 correct :  tensor([352.]) wrong :  tensor([11.]) total :  tensor([363.])
# 363 / 1343 correct :  tensor([353.]) wrong :  tensor([11.]) total :  tensor([364.])
# 364 / 1343 correct :  tensor([353.]) wrong :  tensor([12.]) total :  tensor([365.])
# 365 / 1343 correct :  tensor([354.]) wrong :  tensor([12.]) total :  tensor([366.])
# 366 / 1343 correct :  tensor([355.]) wrong :  tensor([12.]) total :  tensor([367.])
# 367 / 1343 correct :  tensor([356.]) wrong :  tensor([12.]) total :  tensor([368.])
# 368 / 1343 correct :  tensor([357.]) wrong :  tensor([12.]) total :  tensor([369.])
# 369 / 1343 correct :  tensor([358.]) wrong :  tensor([12.]) total :  tensor([370.])
# 370 / 1343 correct :  tensor([359.]) wrong :  tensor([12.]) total :  tensor([371.])
# 371 / 1343 correct :  tensor([360.]) wrong :  tensor([12.]) total :  tensor([372.])
# 372 / 1343 correct :  tensor([361.]) wrong :  tensor([12.]) total :  tensor([373.])
# 373 / 1343 correct :  tensor([362.]) wrong :  tensor([12.]) total :  tensor([374.])
# 374 / 1343 correct :  tensor([363.]) wrong :  tensor([12.]) total :  tensor([375.])
# 375 / 1343 correct :  tensor([364.]) wrong :  tensor([12.]) total :  tensor([376.])
# 376 / 1343 correct :  tensor([365.]) wrong :  tensor([12.]) total :  tensor([377.])
# 377 / 1343 correct :  tensor([366.]) wrong :  tensor([12.]) total :  tensor([378.])
# 378 / 1343 correct :  tensor([367.]) wrong :  tensor([12.]) total :  tensor([379.])
# 379 / 1343 correct :  tensor([368.]) wrong :  tensor([12.]) total :  tensor([380.])
# 380 / 1343 correct :  tensor([369.]) wrong :  tensor([12.]) total :  tensor([381.])
# 381 / 1343 correct :  tensor([370.]) wrong :  tensor([12.]) total :  tensor([382.])
# 382 / 1343 correct :  tensor([371.]) wrong :  tensor([12.]) total :  tensor([383.])
# 383 / 1343 correct :  tensor([372.]) wrong :  tensor([12.]) total :  tensor([384.])
# 384 / 1343 correct :  tensor([373.]) wrong :  tensor([12.]) total :  tensor([385.])
# 385 / 1343 correct :  tensor([374.]) wrong :  tensor([12.]) total :  tensor([386.])
# 386 / 1343 correct :  tensor([375.]) wrong :  tensor([12.]) total :  tensor([387.])
# 387 / 1343 correct :  tensor([375.]) wrong :  tensor([13.]) total :  tensor([388.])
# 388 / 1343 correct :  tensor([376.]) wrong :  tensor([13.]) total :  tensor([389.])
# 389 / 1343 correct :  tensor([377.]) wrong :  tensor([13.]) total :  tensor([390.])
# 390 / 1343 correct :  tensor([378.]) wrong :  tensor([13.]) total :  tensor([391.])
# 391 / 1343 correct :  tensor([379.]) wrong :  tensor([13.]) total :  tensor([392.])
# 392 / 1343 correct :  tensor([379.]) wrong :  tensor([14.]) total :  tensor([393.])
# 393 / 1343 correct :  tensor([380.]) wrong :  tensor([14.]) total :  tensor([394.])
# 394 / 1343 correct :  tensor([380.]) wrong :  tensor([15.]) total :  tensor([395.])
# 395 / 1343 correct :  tensor([381.]) wrong :  tensor([15.]) total :  tensor([396.])
# 396 / 1343 correct :  tensor([382.]) wrong :  tensor([15.]) total :  tensor([397.])
# 397 / 1343 correct :  tensor([383.]) wrong :  tensor([15.]) total :  tensor([398.])
# 398 / 1343 correct :  tensor([384.]) wrong :  tensor([15.]) total :  tensor([399.])
# 399 / 1343 correct :  tensor([385.]) wrong :  tensor([15.]) total :  tensor([400.])
# 400 / 1343 correct :  tensor([386.]) wrong :  tensor([15.]) total :  tensor([401.])
# 401 / 1343 correct :  tensor([387.]) wrong :  tensor([15.]) total :  tensor([402.])
# 402 / 1343 correct :  tensor([388.]) wrong :  tensor([15.]) total :  tensor([403.])
# 403 / 1343 correct :  tensor([389.]) wrong :  tensor([15.]) total :  tensor([404.])
# 404 / 1343 correct :  tensor([390.]) wrong :  tensor([15.]) total :  tensor([405.])
# 405 / 1343 correct :  tensor([391.]) wrong :  tensor([15.]) total :  tensor([406.])
# 406 / 1343 correct :  tensor([392.]) wrong :  tensor([15.]) total :  tensor([407.])
# 407 / 1343 correct :  tensor([393.]) wrong :  tensor([15.]) total :  tensor([408.])
# 408 / 1343 correct :  tensor([393.]) wrong :  tensor([16.]) total :  tensor([409.])
# 409 / 1343 correct :  tensor([394.]) wrong :  tensor([16.]) total :  tensor([410.])
# 410 / 1343 correct :  tensor([395.]) wrong :  tensor([16.]) total :  tensor([411.])
# 411 / 1343 correct :  tensor([395.]) wrong :  tensor([17.]) total :  tensor([412.])
# 412 / 1343 correct :  tensor([396.]) wrong :  tensor([17.]) total :  tensor([413.])
# 413 / 1343 correct :  tensor([397.]) wrong :  tensor([17.]) total :  tensor([414.])
# 414 / 1343 correct :  tensor([398.]) wrong :  tensor([17.]) total :  tensor([415.])
# 415 / 1343 correct :  tensor([399.]) wrong :  tensor([17.]) total :  tensor([416.])
# 416 / 1343 correct :  tensor([400.]) wrong :  tensor([17.]) total :  tensor([417.])
# 417 / 1343 correct :  tensor([401.]) wrong :  tensor([17.]) total :  tensor([418.])
# 418 / 1343 correct :  tensor([402.]) wrong :  tensor([17.]) total :  tensor([419.])
# 419 / 1343 correct :  tensor([403.]) wrong :  tensor([17.]) total :  tensor([420.])
# 420 / 1343 correct :  tensor([404.]) wrong :  tensor([17.]) total :  tensor([421.])
# 421 / 1343 correct :  tensor([405.]) wrong :  tensor([17.]) total :  tensor([422.])
# 422 / 1343 correct :  tensor([406.]) wrong :  tensor([17.]) total :  tensor([423.])
# 423 / 1343 correct :  tensor([407.]) wrong :  tensor([17.]) total :  tensor([424.])
# 424 / 1343 correct :  tensor([408.]) wrong :  tensor([17.]) total :  tensor([425.])
# 425 / 1343 correct :  tensor([408.]) wrong :  tensor([18.]) total :  tensor([426.])
# 426 / 1343 correct :  tensor([409.]) wrong :  tensor([18.]) total :  tensor([427.])
# 427 / 1343 correct :  tensor([410.]) wrong :  tensor([18.]) total :  tensor([428.])
# 428 / 1343 correct :  tensor([411.]) wrong :  tensor([18.]) total :  tensor([429.])
# 429 / 1343 correct :  tensor([412.]) wrong :  tensor([18.]) total :  tensor([430.])
# 430 / 1343 correct :  tensor([413.]) wrong :  tensor([18.]) total :  tensor([431.])
# 431 / 1343 correct :  tensor([414.]) wrong :  tensor([18.]) total :  tensor([432.])
# 432 / 1343 correct :  tensor([415.]) wrong :  tensor([18.]) total :  tensor([433.])
# 433 / 1343 correct :  tensor([416.]) wrong :  tensor([18.]) total :  tensor([434.])
# 434 / 1343 correct :  tensor([417.]) wrong :  tensor([18.]) total :  tensor([435.])
# 435 / 1343 correct :  tensor([418.]) wrong :  tensor([18.]) total :  tensor([436.])
# 436 / 1343 correct :  tensor([419.]) wrong :  tensor([18.]) total :  tensor([437.])
# 437 / 1343 correct :  tensor([420.]) wrong :  tensor([18.]) total :  tensor([438.])
# 438 / 1343 correct :  tensor([421.]) wrong :  tensor([18.]) total :  tensor([439.])
# 439 / 1343 correct :  tensor([422.]) wrong :  tensor([18.]) total :  tensor([440.])
# 440 / 1343 correct :  tensor([423.]) wrong :  tensor([18.]) total :  tensor([441.])
# 441 / 1343 correct :  tensor([423.]) wrong :  tensor([19.]) total :  tensor([442.])
# 442 / 1343 correct :  tensor([424.]) wrong :  tensor([19.]) total :  tensor([443.])
# 443 / 1343 correct :  tensor([425.]) wrong :  tensor([19.]) total :  tensor([444.])
# 444 / 1343 correct :  tensor([425.]) wrong :  tensor([20.]) total :  tensor([445.])
# 445 / 1343 correct :  tensor([426.]) wrong :  tensor([20.]) total :  tensor([446.])
# 446 / 1343 correct :  tensor([427.]) wrong :  tensor([20.]) total :  tensor([447.])
# 447 / 1343 correct :  tensor([428.]) wrong :  tensor([20.]) total :  tensor([448.])
# 448 / 1343 correct :  tensor([429.]) wrong :  tensor([20.]) total :  tensor([449.])
# 449 / 1343 correct :  tensor([430.]) wrong :  tensor([20.]) total :  tensor([450.])
# 450 / 1343 correct :  tensor([431.]) wrong :  tensor([20.]) total :  tensor([451.])
# 451 / 1343 correct :  tensor([432.]) wrong :  tensor([20.]) total :  tensor([452.])
# 452 / 1343 correct :  tensor([433.]) wrong :  tensor([20.]) total :  tensor([453.])
# 453 / 1343 correct :  tensor([434.]) wrong :  tensor([20.]) total :  tensor([454.])
# 454 / 1343 correct :  tensor([435.]) wrong :  tensor([20.]) total :  tensor([455.])
# 455 / 1343 correct :  tensor([436.]) wrong :  tensor([20.]) total :  tensor([456.])
# 456 / 1343 correct :  tensor([437.]) wrong :  tensor([20.]) total :  tensor([457.])
# 457 / 1343 correct :  tensor([438.]) wrong :  tensor([20.]) total :  tensor([458.])
# 458 / 1343 correct :  tensor([439.]) wrong :  tensor([20.]) total :  tensor([459.])
# 459 / 1343 correct :  tensor([440.]) wrong :  tensor([20.]) total :  tensor([460.])
# 460 / 1343 correct :  tensor([441.]) wrong :  tensor([20.]) total :  tensor([461.])
# 461 / 1343 correct :  tensor([442.]) wrong :  tensor([20.]) total :  tensor([462.])
# 462 / 1343 correct :  tensor([443.]) wrong :  tensor([20.]) total :  tensor([463.])
# 463 / 1343 correct :  tensor([444.]) wrong :  tensor([20.]) total :  tensor([464.])
# 464 / 1343 correct :  tensor([445.]) wrong :  tensor([20.]) total :  tensor([465.])
# 465 / 1343 correct :  tensor([446.]) wrong :  tensor([20.]) total :  tensor([466.])
# 466 / 1343 correct :  tensor([447.]) wrong :  tensor([20.]) total :  tensor([467.])
# 467 / 1343 correct :  tensor([448.]) wrong :  tensor([20.]) total :  tensor([468.])
# 468 / 1343 correct :  tensor([449.]) wrong :  tensor([20.]) total :  tensor([469.])
# 469 / 1343 correct :  tensor([450.]) wrong :  tensor([20.]) total :  tensor([470.])
# 470 / 1343 correct :  tensor([451.]) wrong :  tensor([20.]) total :  tensor([471.])
# 471 / 1343 correct :  tensor([452.]) wrong :  tensor([20.]) total :  tensor([472.])
# 472 / 1343 correct :  tensor([453.]) wrong :  tensor([20.]) total :  tensor([473.])
# 473 / 1343 correct :  tensor([454.]) wrong :  tensor([20.]) total :  tensor([474.])
# 474 / 1343 correct :  tensor([455.]) wrong :  tensor([20.]) total :  tensor([475.])
# 475 / 1343 correct :  tensor([456.]) wrong :  tensor([20.]) total :  tensor([476.])
# 476 / 1343 correct :  tensor([457.]) wrong :  tensor([20.]) total :  tensor([477.])
# 477 / 1343 correct :  tensor([458.]) wrong :  tensor([20.]) total :  tensor([478.])
# 478 / 1343 correct :  tensor([459.]) wrong :  tensor([20.]) total :  tensor([479.])
# 479 / 1343 correct :  tensor([460.]) wrong :  tensor([20.]) total :  tensor([480.])
# 480 / 1343 correct :  tensor([461.]) wrong :  tensor([20.]) total :  tensor([481.])
# 481 / 1343 correct :  tensor([462.]) wrong :  tensor([20.]) total :  tensor([482.])
# 482 / 1343 correct :  tensor([463.]) wrong :  tensor([20.]) total :  tensor([483.])
# 483 / 1343 correct :  tensor([464.]) wrong :  tensor([20.]) total :  tensor([484.])
# 484 / 1343 correct :  tensor([465.]) wrong :  tensor([20.]) total :  tensor([485.])
# 485 / 1343 correct :  tensor([466.]) wrong :  tensor([20.]) total :  tensor([486.])
# 486 / 1343 correct :  tensor([467.]) wrong :  tensor([20.]) total :  tensor([487.])
# 487 / 1343 correct :  tensor([468.]) wrong :  tensor([20.]) total :  tensor([488.])
# 488 / 1343 correct :  tensor([469.]) wrong :  tensor([20.]) total :  tensor([489.])
# 489 / 1343 correct :  tensor([470.]) wrong :  tensor([20.]) total :  tensor([490.])
# 490 / 1343 correct :  tensor([471.]) wrong :  tensor([20.]) total :  tensor([491.])
# 491 / 1343 correct :  tensor([472.]) wrong :  tensor([20.]) total :  tensor([492.])
# 492 / 1343 correct :  tensor([473.]) wrong :  tensor([20.]) total :  tensor([493.])
# 493 / 1343 correct :  tensor([474.]) wrong :  tensor([20.]) total :  tensor([494.])
# 494 / 1343 correct :  tensor([475.]) wrong :  tensor([20.]) total :  tensor([495.])
# 495 / 1343 correct :  tensor([476.]) wrong :  tensor([20.]) total :  tensor([496.])
# 496 / 1343 correct :  tensor([477.]) wrong :  tensor([20.]) total :  tensor([497.])
# 497 / 1343 correct :  tensor([478.]) wrong :  tensor([20.]) total :  tensor([498.])
# 498 / 1343 correct :  tensor([479.]) wrong :  tensor([20.]) total :  tensor([499.])
# 499 / 1343 correct :  tensor([480.]) wrong :  tensor([20.]) total :  tensor([500.])
# 500 / 1343 correct :  tensor([481.]) wrong :  tensor([20.]) total :  tensor([501.])
# 501 / 1343 correct :  tensor([482.]) wrong :  tensor([20.]) total :  tensor([502.])
# 502 / 1343 correct :  tensor([483.]) wrong :  tensor([20.]) total :  tensor([503.])
# 503 / 1343 correct :  tensor([484.]) wrong :  tensor([20.]) total :  tensor([504.])
# 504 / 1343 correct :  tensor([485.]) wrong :  tensor([20.]) total :  tensor([505.])
# 505 / 1343 correct :  tensor([486.]) wrong :  tensor([20.]) total :  tensor([506.])
# 506 / 1343 correct :  tensor([487.]) wrong :  tensor([20.]) total :  tensor([507.])
# 507 / 1343 correct :  tensor([488.]) wrong :  tensor([20.]) total :  tensor([508.])
# 508 / 1343 correct :  tensor([489.]) wrong :  tensor([20.]) total :  tensor([509.])
# 509 / 1343 correct :  tensor([490.]) wrong :  tensor([20.]) total :  tensor([510.])
# 510 / 1343 correct :  tensor([491.]) wrong :  tensor([20.]) total :  tensor([511.])
# 511 / 1343 correct :  tensor([492.]) wrong :  tensor([20.]) total :  tensor([512.])
# 512 / 1343 correct :  tensor([493.]) wrong :  tensor([20.]) total :  tensor([513.])
# 513 / 1343 correct :  tensor([494.]) wrong :  tensor([20.]) total :  tensor([514.])
# 514 / 1343 correct :  tensor([495.]) wrong :  tensor([20.]) total :  tensor([515.])
# 515 / 1343 correct :  tensor([496.]) wrong :  tensor([20.]) total :  tensor([516.])
# 516 / 1343 correct :  tensor([497.]) wrong :  tensor([20.]) total :  tensor([517.])
# 517 / 1343 correct :  tensor([498.]) wrong :  tensor([20.]) total :  tensor([518.])
# 518 / 1343 correct :  tensor([499.]) wrong :  tensor([20.]) total :  tensor([519.])
# 519 / 1343 correct :  tensor([500.]) wrong :  tensor([20.]) total :  tensor([520.])
# 520 / 1343 correct :  tensor([501.]) wrong :  tensor([20.]) total :  tensor([521.])
# 521 / 1343 correct :  tensor([502.]) wrong :  tensor([20.]) total :  tensor([522.])
# 522 / 1343 correct :  tensor([503.]) wrong :  tensor([20.]) total :  tensor([523.])
# 523 / 1343 correct :  tensor([504.]) wrong :  tensor([20.]) total :  tensor([524.])
# 524 / 1343 correct :  tensor([505.]) wrong :  tensor([20.]) total :  tensor([525.])
# 525 / 1343 correct :  tensor([506.]) wrong :  tensor([20.]) total :  tensor([526.])
# 526 / 1343 correct :  tensor([507.]) wrong :  tensor([20.]) total :  tensor([527.])
# 527 / 1343 correct :  tensor([508.]) wrong :  tensor([20.]) total :  tensor([528.])
# 528 / 1343 correct :  tensor([509.]) wrong :  tensor([20.]) total :  tensor([529.])
# 529 / 1343 correct :  tensor([510.]) wrong :  tensor([20.]) total :  tensor([530.])
# 530 / 1343 correct :  tensor([511.]) wrong :  tensor([20.]) total :  tensor([531.])
# 531 / 1343 correct :  tensor([512.]) wrong :  tensor([20.]) total :  tensor([532.])
# 532 / 1343 correct :  tensor([513.]) wrong :  tensor([20.]) total :  tensor([533.])
# 533 / 1343 correct :  tensor([514.]) wrong :  tensor([20.]) total :  tensor([534.])
# 534 / 1343 correct :  tensor([515.]) wrong :  tensor([20.]) total :  tensor([535.])
# 535 / 1343 correct :  tensor([516.]) wrong :  tensor([20.]) total :  tensor([536.])
# 536 / 1343 correct :  tensor([517.]) wrong :  tensor([20.]) total :  tensor([537.])
# 537 / 1343 correct :  tensor([518.]) wrong :  tensor([20.]) total :  tensor([538.])
# 538 / 1343 correct :  tensor([519.]) wrong :  tensor([20.]) total :  tensor([539.])
# 539 / 1343 correct :  tensor([520.]) wrong :  tensor([20.]) total :  tensor([540.])
# 540 / 1343 correct :  tensor([521.]) wrong :  tensor([20.]) total :  tensor([541.])
# 541 / 1343 correct :  tensor([522.]) wrong :  tensor([20.]) total :  tensor([542.])
# 542 / 1343 correct :  tensor([523.]) wrong :  tensor([20.]) total :  tensor([543.])
# 543 / 1343 correct :  tensor([524.]) wrong :  tensor([20.]) total :  tensor([544.])
# 544 / 1343 correct :  tensor([525.]) wrong :  tensor([20.]) total :  tensor([545.])
# 545 / 1343 correct :  tensor([526.]) wrong :  tensor([20.]) total :  tensor([546.])
# 546 / 1343 correct :  tensor([527.]) wrong :  tensor([20.]) total :  tensor([547.])
# 547 / 1343 correct :  tensor([528.]) wrong :  tensor([20.]) total :  tensor([548.])
# 548 / 1343 correct :  tensor([529.]) wrong :  tensor([20.]) total :  tensor([549.])
# 549 / 1343 correct :  tensor([530.]) wrong :  tensor([20.]) total :  tensor([550.])
# 550 / 1343 correct :  tensor([531.]) wrong :  tensor([20.]) total :  tensor([551.])
# 551 / 1343 correct :  tensor([532.]) wrong :  tensor([20.]) total :  tensor([552.])
# 552 / 1343 correct :  tensor([533.]) wrong :  tensor([20.]) total :  tensor([553.])
# 553 / 1343 correct :  tensor([534.]) wrong :  tensor([20.]) total :  tensor([554.])
# 554 / 1343 correct :  tensor([535.]) wrong :  tensor([20.]) total :  tensor([555.])
# 555 / 1343 correct :  tensor([536.]) wrong :  tensor([20.]) total :  tensor([556.])
# 556 / 1343 correct :  tensor([537.]) wrong :  tensor([20.]) total :  tensor([557.])
# 557 / 1343 correct :  tensor([538.]) wrong :  tensor([20.]) total :  tensor([558.])
# 558 / 1343 correct :  tensor([539.]) wrong :  tensor([20.]) total :  tensor([559.])
# 559 / 1343 correct :  tensor([540.]) wrong :  tensor([20.]) total :  tensor([560.])
# 560 / 1343 correct :  tensor([541.]) wrong :  tensor([20.]) total :  tensor([561.])
# 561 / 1343 correct :  tensor([542.]) wrong :  tensor([20.]) total :  tensor([562.])
# 562 / 1343 correct :  tensor([543.]) wrong :  tensor([20.]) total :  tensor([563.])
# 563 / 1343 correct :  tensor([544.]) wrong :  tensor([20.]) total :  tensor([564.])
# 564 / 1343 correct :  tensor([545.]) wrong :  tensor([20.]) total :  tensor([565.])
# 565 / 1343 correct :  tensor([546.]) wrong :  tensor([20.]) total :  tensor([566.])
# 566 / 1343 correct :  tensor([547.]) wrong :  tensor([20.]) total :  tensor([567.])
# 567 / 1343 correct :  tensor([548.]) wrong :  tensor([20.]) total :  tensor([568.])
# 568 / 1343 correct :  tensor([549.]) wrong :  tensor([20.]) total :  tensor([569.])
# 569 / 1343 correct :  tensor([550.]) wrong :  tensor([20.]) total :  tensor([570.])
# 570 / 1343 correct :  tensor([551.]) wrong :  tensor([20.]) total :  tensor([571.])
# 571 / 1343 correct :  tensor([552.]) wrong :  tensor([20.]) total :  tensor([572.])
# 572 / 1343 correct :  tensor([553.]) wrong :  tensor([20.]) total :  tensor([573.])
# 573 / 1343 correct :  tensor([554.]) wrong :  tensor([20.]) total :  tensor([574.])
# 574 / 1343 correct :  tensor([555.]) wrong :  tensor([20.]) total :  tensor([575.])
# 575 / 1343 correct :  tensor([556.]) wrong :  tensor([20.]) total :  tensor([576.])
# 576 / 1343 correct :  tensor([557.]) wrong :  tensor([20.]) total :  tensor([577.])
# 577 / 1343 correct :  tensor([558.]) wrong :  tensor([20.]) total :  tensor([578.])
# 578 / 1343 correct :  tensor([559.]) wrong :  tensor([20.]) total :  tensor([579.])
# ...
# 1160 / 1343 correct :  tensor([1123.]) wrong :  tensor([38.]) total :  tensor([1161.])
# 1161 / 1343 correct :  tensor([1124.]) wrong :  tensor([38.]) total :  tensor([1162.])
# 1162 / 1343 correct :  tensor([1125.]) wrong :  tensor([38.]) total :  tensor([1163.])
# 1163 / 1343 correct :  tensor([1126.]) wrong :  tensor([38.]) total :  tensor([1164.])
# 1164 / 1343 correct :  tensor([1127.]) wrong :  tensor([38.]) total :  tensor([1165.])
# 1165 / 1343 correct :  tensor([1127.]) wrong :  tensor([39.]) total :  tensor([1166.])
# 1166 / 1343 correct :  tensor([1128.]) wrong :  tensor([39.]) total :  tensor([1167.])
# 1167 / 1343 correct :  tensor([1129.]) wrong :  tensor([39.]) total :  tensor([1168.])
# 1168 / 1343 correct :  tensor([1130.]) wrong :  tensor([39.]) total :  tensor([1169.])
# 1169 / 1343 correct :  tensor([1130.]) wrong :  tensor([40.]) total :  tensor([1170.])
# 1170 / 1343 correct :  tensor([1131.]) wrong :  tensor([40.]) total :  tensor([1171.])
# 1171 / 1343 correct :  tensor([1132.]) wrong :  tensor([40.]) total :  tensor([1172.])
# 1172 / 1343 correct :  tensor([1133.]) wrong :  tensor([40.]) total :  tensor([1173.])
# 1173 / 1343 correct :  tensor([1134.]) wrong :  tensor([40.]) total :  tensor([1174.])
# 1174 / 1343 correct :  tensor([1135.]) wrong :  tensor([40.]) total :  tensor([1175.])
# 1175 / 1343 correct :  tensor([1136.]) wrong :  tensor([40.]) total :  tensor([1176.])
# 1176 / 1343 correct :  tensor([1137.]) wrong :  tensor([40.]) total :  tensor([1177.])
# 1177 / 1343 correct :  tensor([1138.]) wrong :  tensor([40.]) total :  tensor([1178.])
# 1178 / 1343 correct :  tensor([1139.]) wrong :  tensor([40.]) total :  tensor([1179.])
# 1179 / 1343 correct :  tensor([1140.]) wrong :  tensor([40.]) total :  tensor([1180.])
# 1180 / 1343 correct :  tensor([1141.]) wrong :  tensor([40.]) total :  tensor([1181.])
# 1181 / 1343 correct :  tensor([1142.]) wrong :  tensor([40.]) total :  tensor([1182.])
# 1182 / 1343 correct :  tensor([1143.]) wrong :  tensor([40.]) total :  tensor([1183.])
# 1183 / 1343 correct :  tensor([1144.]) wrong :  tensor([40.]) total :  tensor([1184.])
# 1184 / 1343 correct :  tensor([1144.]) wrong :  tensor([41.]) total :  tensor([1185.])
# 1185 / 1343 correct :  tensor([1145.]) wrong :  tensor([41.]) total :  tensor([1186.])
# 1186 / 1343 correct :  tensor([1146.]) wrong :  tensor([41.]) total :  tensor([1187.])
# 1187 / 1343 correct :  tensor([1147.]) wrong :  tensor([41.]) total :  tensor([1188.])
# 1188 / 1343 correct :  tensor([1148.]) wrong :  tensor([41.]) total :  tensor([1189.])
# 1189 / 1343 correct :  tensor([1149.]) wrong :  tensor([41.]) total :  tensor([1190.])
# 1190 / 1343 correct :  tensor([1150.]) wrong :  tensor([41.]) total :  tensor([1191.])
# 1191 / 1343 correct :  tensor([1151.]) wrong :  tensor([41.]) total :  tensor([1192.])
# 1192 / 1343 correct :  tensor([1152.]) wrong :  tensor([41.]) total :  tensor([1193.])
# 1193 / 1343 correct :  tensor([1153.]) wrong :  tensor([41.]) total :  tensor([1194.])
# 1194 / 1343 correct :  tensor([1154.]) wrong :  tensor([41.]) total :  tensor([1195.])
# 1195 / 1343 correct :  tensor([1155.]) wrong :  tensor([41.]) total :  tensor([1196.])
# 1196 / 1343 correct :  tensor([1156.]) wrong :  tensor([41.]) total :  tensor([1197.])
# 1197 / 1343 correct :  tensor([1157.]) wrong :  tensor([41.]) total :  tensor([1198.])
# 1198 / 1343 correct :  tensor([1158.]) wrong :  tensor([41.]) total :  tensor([1199.])
# 1199 / 1343 correct :  tensor([1159.]) wrong :  tensor([41.]) total :  tensor([1200.])
# 1200 / 1343 correct :  tensor([1160.]) wrong :  tensor([41.]) total :  tensor([1201.])
# 1201 / 1343 correct :  tensor([1161.]) wrong :  tensor([41.]) total :  tensor([1202.])
# 1202 / 1343 correct :  tensor([1162.]) wrong :  tensor([41.]) total :  tensor([1203.])
# 1203 / 1343 correct :  tensor([1163.]) wrong :  tensor([41.]) total :  tensor([1204.])
# 1204 / 1343 correct :  tensor([1164.]) wrong :  tensor([41.]) total :  tensor([1205.])
# 1205 / 1343 correct :  tensor([1165.]) wrong :  tensor([41.]) total :  tensor([1206.])
# 1206 / 1343 correct :  tensor([1166.]) wrong :  tensor([41.]) total :  tensor([1207.])
# 1207 / 1343 correct :  tensor([1167.]) wrong :  tensor([41.]) total :  tensor([1208.])
# 1208 / 1343 correct :  tensor([1168.]) wrong :  tensor([41.]) total :  tensor([1209.])
# 1209 / 1343 correct :  tensor([1169.]) wrong :  tensor([41.]) total :  tensor([1210.])
# 1210 / 1343 correct :  tensor([1170.]) wrong :  tensor([41.]) total :  tensor([1211.])
# 1211 / 1343 correct :  tensor([1171.]) wrong :  tensor([41.]) total :  tensor([1212.])
# 1212 / 1343 correct :  tensor([1172.]) wrong :  tensor([41.]) total :  tensor([1213.])
# 1213 / 1343 correct :  tensor([1173.]) wrong :  tensor([41.]) total :  tensor([1214.])
# 1214 / 1343 correct :  tensor([1174.]) wrong :  tensor([41.]) total :  tensor([1215.])
# 1215 / 1343 correct :  tensor([1175.]) wrong :  tensor([41.]) total :  tensor([1216.])
# 1216 / 1343 correct :  tensor([1176.]) wrong :  tensor([41.]) total :  tensor([1217.])
# 1217 / 1343 correct :  tensor([1177.]) wrong :  tensor([41.]) total :  tensor([1218.])
# 1218 / 1343 correct :  tensor([1178.]) wrong :  tensor([41.]) total :  tensor([1219.])
# 1219 / 1343 correct :  tensor([1179.]) wrong :  tensor([41.]) total :  tensor([1220.])
# 1220 / 1343 correct :  tensor([1180.]) wrong :  tensor([41.]) total :  tensor([1221.])
# 1221 / 1343 correct :  tensor([1181.]) wrong :  tensor([41.]) total :  tensor([1222.])
# 1222 / 1343 correct :  tensor([1182.]) wrong :  tensor([41.]) total :  tensor([1223.])
# 1223 / 1343 correct :  tensor([1183.]) wrong :  tensor([41.]) total :  tensor([1224.])
# 1224 / 1343 correct :  tensor([1184.]) wrong :  tensor([41.]) total :  tensor([1225.])
# 1225 / 1343 correct :  tensor([1185.]) wrong :  tensor([41.]) total :  tensor([1226.])
# 1226 / 1343 correct :  tensor([1186.]) wrong :  tensor([41.]) total :  tensor([1227.])
# 1227 / 1343 correct :  tensor([1187.]) wrong :  tensor([41.]) total :  tensor([1228.])
# 1228 / 1343 correct :  tensor([1188.]) wrong :  tensor([41.]) total :  tensor([1229.])
# 1229 / 1343 correct :  tensor([1189.]) wrong :  tensor([41.]) total :  tensor([1230.])
# 1230 / 1343 correct :  tensor([1190.]) wrong :  tensor([41.]) total :  tensor([1231.])
# 1231 / 1343 correct :  tensor([1191.]) wrong :  tensor([41.]) total :  tensor([1232.])
# 1232 / 1343 correct :  tensor([1192.]) wrong :  tensor([41.]) total :  tensor([1233.])
# 1233 / 1343 correct :  tensor([1193.]) wrong :  tensor([41.]) total :  tensor([1234.])
# 1234 / 1343 correct :  tensor([1194.]) wrong :  tensor([41.]) total :  tensor([1235.])
# 1235 / 1343 correct :  tensor([1195.]) wrong :  tensor([41.]) total :  tensor([1236.])
# 1236 / 1343 correct :  tensor([1196.]) wrong :  tensor([41.]) total :  tensor([1237.])
# 1237 / 1343 correct :  tensor([1197.]) wrong :  tensor([41.]) total :  tensor([1238.])
# 1238 / 1343 correct :  tensor([1198.]) wrong :  tensor([41.]) total :  tensor([1239.])
# 1239 / 1343 correct :  tensor([1199.]) wrong :  tensor([41.]) total :  tensor([1240.])
# 1240 / 1343 correct :  tensor([1200.]) wrong :  tensor([41.]) total :  tensor([1241.])
# 1241 / 1343 correct :  tensor([1201.]) wrong :  tensor([41.]) total :  tensor([1242.])
# 1242 / 1343 correct :  tensor([1202.]) wrong :  tensor([41.]) total :  tensor([1243.])
# 1243 / 1343 correct :  tensor([1203.]) wrong :  tensor([41.]) total :  tensor([1244.])
# 1244 / 1343 correct :  tensor([1204.]) wrong :  tensor([41.]) total :  tensor([1245.])
# 1245 / 1343 correct :  tensor([1205.]) wrong :  tensor([41.]) total :  tensor([1246.])
# 1246 / 1343 correct :  tensor([1206.]) wrong :  tensor([41.]) total :  tensor([1247.])
# 1247 / 1343 correct :  tensor([1207.]) wrong :  tensor([41.]) total :  tensor([1248.])
# 1248 / 1343 correct :  tensor([1208.]) wrong :  tensor([41.]) total :  tensor([1249.])
# 1249 / 1343 correct :  tensor([1209.]) wrong :  tensor([41.]) total :  tensor([1250.])
# 1250 / 1343 correct :  tensor([1210.]) wrong :  tensor([41.]) total :  tensor([1251.])
# 1251 / 1343 correct :  tensor([1211.]) wrong :  tensor([41.]) total :  tensor([1252.])
# 1252 / 1343 correct :  tensor([1212.]) wrong :  tensor([41.]) total :  tensor([1253.])
# 1253 / 1343 correct :  tensor([1213.]) wrong :  tensor([41.]) total :  tensor([1254.])
# 1254 / 1343 correct :  tensor([1214.]) wrong :  tensor([41.]) total :  tensor([1255.])
# 1255 / 1343 correct :  tensor([1215.]) wrong :  tensor([41.]) total :  tensor([1256.])
# 1256 / 1343 correct :  tensor([1216.]) wrong :  tensor([41.]) total :  tensor([1257.])
# 1257 / 1343 correct :  tensor([1217.]) wrong :  tensor([41.]) total :  tensor([1258.])
# 1258 / 1343 correct :  tensor([1218.]) wrong :  tensor([41.]) total :  tensor([1259.])
# 1259 / 1343 correct :  tensor([1219.]) wrong :  tensor([41.]) total :  tensor([1260.])
# 1260 / 1343 correct :  tensor([1220.]) wrong :  tensor([41.]) total :  tensor([1261.])
# 1261 / 1343 correct :  tensor([1221.]) wrong :  tensor([41.]) total :  tensor([1262.])
# 1262 / 1343 correct :  tensor([1222.]) wrong :  tensor([41.]) total :  tensor([1263.])
# 1263 / 1343 correct :  tensor([1223.]) wrong :  tensor([41.]) total :  tensor([1264.])
# 1264 / 1343 correct :  tensor([1224.]) wrong :  tensor([41.]) total :  tensor([1265.])
# 1265 / 1343 correct :  tensor([1225.]) wrong :  tensor([41.]) total :  tensor([1266.])
# 1266 / 1343 correct :  tensor([1226.]) wrong :  tensor([41.]) total :  tensor([1267.])
# 1267 / 1343 correct :  tensor([1227.]) wrong :  tensor([41.]) total :  tensor([1268.])
# 1268 / 1343 correct :  tensor([1228.]) wrong :  tensor([41.]) total :  tensor([1269.])
# 1269 / 1343 correct :  tensor([1229.]) wrong :  tensor([41.]) total :  tensor([1270.])
# 1270 / 1343 correct :  tensor([1230.]) wrong :  tensor([41.]) total :  tensor([1271.])
# 1271 / 1343 correct :  tensor([1231.]) wrong :  tensor([41.]) total :  tensor([1272.])
# 1272 / 1343 correct :  tensor([1232.]) wrong :  tensor([41.]) total :  tensor([1273.])
# 1273 / 1343 correct :  tensor([1233.]) wrong :  tensor([41.]) total :  tensor([1274.])
# 1274 / 1343 correct :  tensor([1234.]) wrong :  tensor([41.]) total :  tensor([1275.])
# 1275 / 1343 correct :  tensor([1235.]) wrong :  tensor([41.]) total :  tensor([1276.])
# 1276 / 1343 correct :  tensor([1236.]) wrong :  tensor([41.]) total :  tensor([1277.])
# 1277 / 1343 correct :  tensor([1237.]) wrong :  tensor([41.]) total :  tensor([1278.])
# 1278 / 1343 correct :  tensor([1238.]) wrong :  tensor([41.]) total :  tensor([1279.])
# 1279 / 1343 correct :  tensor([1239.]) wrong :  tensor([41.]) total :  tensor([1280.])
# 1280 / 1343 correct :  tensor([1240.]) wrong :  tensor([41.]) total :  tensor([1281.])
# 1281 / 1343 correct :  tensor([1241.]) wrong :  tensor([41.]) total :  tensor([1282.])
# 1282 / 1343 correct :  tensor([1242.]) wrong :  tensor([41.]) total :  tensor([1283.])
# 1283 / 1343 correct :  tensor([1243.]) wrong :  tensor([41.]) total :  tensor([1284.])
# 1284 / 1343 correct :  tensor([1244.]) wrong :  tensor([41.]) total :  tensor([1285.])
# 1285 / 1343 correct :  tensor([1245.]) wrong :  tensor([41.]) total :  tensor([1286.])
# 1286 / 1343 correct :  tensor([1246.]) wrong :  tensor([41.]) total :  tensor([1287.])
# 1287 / 1343 correct :  tensor([1247.]) wrong :  tensor([41.]) total :  tensor([1288.])
# 1288 / 1343 correct :  tensor([1248.]) wrong :  tensor([41.]) total :  tensor([1289.])
# 1289 / 1343 correct :  tensor([1249.]) wrong :  tensor([41.]) total :  tensor([1290.])
# 1290 / 1343 correct :  tensor([1250.]) wrong :  tensor([41.]) total :  tensor([1291.])
# 1291 / 1343 correct :  tensor([1251.]) wrong :  tensor([41.]) total :  tensor([1292.])
# 1292 / 1343 correct :  tensor([1252.]) wrong :  tensor([41.]) total :  tensor([1293.])
# 1293 / 1343 correct :  tensor([1253.]) wrong :  tensor([41.]) total :  tensor([1294.])
# 1294 / 1343 correct :  tensor([1254.]) wrong :  tensor([41.]) total :  tensor([1295.])
# 1295 / 1343 correct :  tensor([1255.]) wrong :  tensor([41.]) total :  tensor([1296.])
# 1296 / 1343 correct :  tensor([1256.]) wrong :  tensor([41.]) total :  tensor([1297.])
# 1297 / 1343 correct :  tensor([1257.]) wrong :  tensor([41.]) total :  tensor([1298.])
# 1298 / 1343 correct :  tensor([1258.]) wrong :  tensor([41.]) total :  tensor([1299.])
# 1299 / 1343 correct :  tensor([1259.]) wrong :  tensor([41.]) total :  tensor([1300.])
# 1300 / 1343 correct :  tensor([1260.]) wrong :  tensor([41.]) total :  tensor([1301.])
# 1301 / 1343 correct :  tensor([1261.]) wrong :  tensor([41.]) total :  tensor([1302.])
# 1302 / 1343 correct :  tensor([1262.]) wrong :  tensor([41.]) total :  tensor([1303.])
# 1303 / 1343 correct :  tensor([1263.]) wrong :  tensor([41.]) total :  tensor([1304.])
# 1304 / 1343 correct :  tensor([1264.]) wrong :  tensor([41.]) total :  tensor([1305.])
# 1305 / 1343 correct :  tensor([1265.]) wrong :  tensor([41.]) total :  tensor([1306.])
# 1306 / 1343 correct :  tensor([1266.]) wrong :  tensor([41.]) total :  tensor([1307.])
# 1307 / 1343 correct :  tensor([1267.]) wrong :  tensor([41.]) total :  tensor([1308.])
# 1308 / 1343 correct :  tensor([1268.]) wrong :  tensor([41.]) total :  tensor([1309.])
# 1309 / 1343 correct :  tensor([1269.]) wrong :  tensor([41.]) total :  tensor([1310.])
# 1310 / 1343 correct :  tensor([1270.]) wrong :  tensor([41.]) total :  tensor([1311.])
# 1311 / 1343 correct :  tensor([1271.]) wrong :  tensor([41.]) total :  tensor([1312.])
# 1312 / 1343 correct :  tensor([1272.]) wrong :  tensor([41.]) total :  tensor([1313.])
# 1313 / 1343 correct :  tensor([1273.]) wrong :  tensor([41.]) total :  tensor([1314.])
# 1314 / 1343 correct :  tensor([1274.]) wrong :  tensor([41.]) total :  tensor([1315.])
# 1315 / 1343 correct :  tensor([1275.]) wrong :  tensor([41.]) total :  tensor([1316.])
# 1316 / 1343 correct :  tensor([1276.]) wrong :  tensor([41.]) total :  tensor([1317.])
# 1317 / 1343 correct :  tensor([1277.]) wrong :  tensor([41.]) total :  tensor([1318.])
# 1318 / 1343 correct :  tensor([1278.]) wrong :  tensor([41.]) total :  tensor([1319.])
# 1319 / 1343 correct :  tensor([1279.]) wrong :  tensor([41.]) total :  tensor([1320.])
# 1320 / 1343 correct :  tensor([1280.]) wrong :  tensor([41.]) total :  tensor([1321.])
# 1321 / 1343 correct :  tensor([1281.]) wrong :  tensor([41.]) total :  tensor([1322.])
# 1322 / 1343 correct :  tensor([1282.]) wrong :  tensor([41.]) total :  tensor([1323.])
# 1323 / 1343 correct :  tensor([1283.]) wrong :  tensor([41.]) total :  tensor([1324.])
# 1324 / 1343 correct :  tensor([1284.]) wrong :  tensor([41.]) total :  tensor([1325.])
# 1325 / 1343 correct :  tensor([1285.]) wrong :  tensor([41.]) total :  tensor([1326.])
# 1326 / 1343 correct :  tensor([1286.]) wrong :  tensor([41.]) total :  tensor([1327.])
# 1327 / 1343 correct :  tensor([1287.]) wrong :  tensor([41.]) total :  tensor([1328.])
# 1328 / 1343 correct :  tensor([1288.]) wrong :  tensor([41.]) total :  tensor([1329.])
# 1329 / 1343 correct :  tensor([1289.]) wrong :  tensor([41.]) total :  tensor([1330.])
# 1330 / 1343 correct :  tensor([1290.]) wrong :  tensor([41.]) total :  tensor([1331.])
# 1331 / 1343 correct :  tensor([1291.]) wrong :  tensor([41.]) total :  tensor([1332.])
# 1332 / 1343 correct :  tensor([1292.]) wrong :  tensor([41.]) total :  tensor([1333.])
# 1333 / 1343 correct :  tensor([1293.]) wrong :  tensor([41.]) total :  tensor([1334.])
# 1334 / 1343 correct :  tensor([1294.]) wrong :  tensor([41.]) total :  tensor([1335.])
# 1335 / 1343 correct :  tensor([1295.]) wrong :  tensor([41.]) total :  tensor([1336.])
# 1336 / 1343 correct :  tensor([1296.]) wrong :  tensor([41.]) total :  tensor([1337.])
# 1337 / 1343 correct :  tensor([1297.]) wrong :  tensor([41.]) total :  tensor([1338.])
# 1338 / 1343 correct :  tensor([1298.]) wrong :  tensor([41.]) total :  tensor([1339.])
# 1339 / 1343 correct :  tensor([1299.]) wrong :  tensor([41.]) total :  tensor([1340.])
# 1340 / 1343 correct :  tensor([1300.]) wrong :  tensor([41.]) total :  tensor([1341.])
# 1341 / 1343 correct :  tensor([1301.]) wrong :  tensor([41.]) total :  tensor([1342.])
# 1342 / 1343 correct :  tensor([1302.]) wrong :  tensor([41.]) total :  tensor([1343.])
# Test Data Accuracy: [96.947136]%

# %%
tgtData_iter = iter(cityscape_testLoader)

encoder = EncoderModule()
domain_cls = DomainClassifier()
decoder = DecoderModule()

encoder.eval()
domain_cls.eval()
decoder.eval()

correct = torch.FloatTensor([0])
wrong = torch.FloatTensor([0])
total = torch.FloatTensor([0])

for i in range(500) :        #500

    if torch.cuda.is_available() :
        encoder = encoder.cuda()
        domain_cls = domain_cls.cuda()
        decoder = decoder.cuda()

    encoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_encoder_fda_once.pth"))
    domain_cls.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_domain_cls_once.pth"))

    tgt_data, tgt_label = next(tgtData_iter)
    tgt_cls_label = tgt_label['classification']

    if torch.cuda.is_available() :
        tgt_data, tgt_cls_label = tgt_data.cuda(), tgt_cls_label.cuda()

    tgt_feature, _ = encoder(tgt_data)
    output = domain_cls(tgt_feature.detach())

    values,idx = output.max(dim=1)
    correct += torch.sum(tgt_cls_label==idx).float().cpu().data
    wrong += torch.sum(tgt_cls_label!=idx).float().cpu().data
#     print('values : ', values.data, 'output : ', idx.data, 'idx : ', tgt_cls_label.data)
    
    total += tgt_cls_label.cpu().size(0)
    print(i, '/', str(500), 'correct : ', correct.data, 'wrong : ', wrong.data, 'total : ', total.data)
    
print("Test Data Accuracy: {}%".format(100*(correct/total).numpy()))
# Out:
# 0 / 500 correct :  tensor([1.]) wrong :  tensor([0.]) total :  tensor([1.])
# 1 / 500 correct :  tensor([2.]) wrong :  tensor([0.]) total :  tensor([2.])
# 2 / 500 correct :  tensor([2.]) wrong :  tensor([1.]) total :  tensor([3.])
# 3 / 500 correct :  tensor([3.]) wrong :  tensor([1.]) total :  tensor([4.])
# 4 / 500 correct :  tensor([4.]) wrong :  tensor([1.]) total :  tensor([5.])
# 5 / 500 correct :  tensor([5.]) wrong :  tensor([1.]) total :  tensor([6.])
# 6 / 500 correct :  tensor([6.]) wrong :  tensor([1.]) total :  tensor([7.])
# 7 / 500 correct :  tensor([7.]) wrong :  tensor([1.]) total :  tensor([8.])
# 8 / 500 correct :  tensor([8.]) wrong :  tensor([1.]) total :  tensor([9.])
# 9 / 500 correct :  tensor([9.]) wrong :  tensor([1.]) total :  tensor([10.])
# 10 / 500 correct :  tensor([10.]) wrong :  tensor([1.]) total :  tensor([11.])
# 11 / 500 correct :  tensor([11.]) wrong :  tensor([1.]) total :  tensor([12.])
# 12 / 500 correct :  tensor([12.]) wrong :  tensor([1.]) total :  tensor([13.])
# 13 / 500 correct :  tensor([13.]) wrong :  tensor([1.]) total :  tensor([14.])
# 14 / 500 correct :  tensor([14.]) wrong :  tensor([1.]) total :  tensor([15.])
# 15 / 500 correct :  tensor([15.]) wrong :  tensor([1.]) total :  tensor([16.])
# 16 / 500 correct :  tensor([16.]) wrong :  tensor([1.]) total :  tensor([17.])
# 17 / 500 correct :  tensor([17.]) wrong :  tensor([1.]) total :  tensor([18.])
# 18 / 500 correct :  tensor([18.]) wrong :  tensor([1.]) total :  tensor([19.])
# 19 / 500 correct :  tensor([19.]) wrong :  tensor([1.]) total :  tensor([20.])
# 20 / 500 correct :  tensor([20.]) wrong :  tensor([1.]) total :  tensor([21.])
# 21 / 500 correct :  tensor([21.]) wrong :  tensor([1.]) total :  tensor([22.])
# 22 / 500 correct :  tensor([22.]) wrong :  tensor([1.]) total :  tensor([23.])
# 23 / 500 correct :  tensor([23.]) wrong :  tensor([1.]) total :  tensor([24.])
# 24 / 500 correct :  tensor([24.]) wrong :  tensor([1.]) total :  tensor([25.])
# 25 / 500 correct :  tensor([25.]) wrong :  tensor([1.]) total :  tensor([26.])
# 26 / 500 correct :  tensor([26.]) wrong :  tensor([1.]) total :  tensor([27.])
# 27 / 500 correct :  tensor([27.]) wrong :  tensor([1.]) total :  tensor([28.])
# 28 / 500 correct :  tensor([28.]) wrong :  tensor([1.]) total :  tensor([29.])
# 29 / 500 correct :  tensor([29.]) wrong :  tensor([1.]) total :  tensor([30.])
# 30 / 500 correct :  tensor([30.]) wrong :  tensor([1.]) total :  tensor([31.])
# 31 / 500 correct :  tensor([31.]) wrong :  tensor([1.]) total :  tensor([32.])
# 32 / 500 correct :  tensor([32.]) wrong :  tensor([1.]) total :  tensor([33.])
# 33 / 500 correct :  tensor([33.]) wrong :  tensor([1.]) total :  tensor([34.])
# 34 / 500 correct :  tensor([34.]) wrong :  tensor([1.]) total :  tensor([35.])
# 35 / 500 correct :  tensor([35.]) wrong :  tensor([1.]) total :  tensor([36.])
# 36 / 500 correct :  tensor([36.]) wrong :  tensor([1.]) total :  tensor([37.])
# 37 / 500 correct :  tensor([37.]) wrong :  tensor([1.]) total :  tensor([38.])
# 38 / 500 correct :  tensor([38.]) wrong :  tensor([1.]) total :  tensor([39.])
# 39 / 500 correct :  tensor([39.]) wrong :  tensor([1.]) total :  tensor([40.])
# 40 / 500 correct :  tensor([40.]) wrong :  tensor([1.]) total :  tensor([41.])
# 41 / 500 correct :  tensor([41.]) wrong :  tensor([1.]) total :  tensor([42.])
# 42 / 500 correct :  tensor([42.]) wrong :  tensor([1.]) total :  tensor([43.])
# 43 / 500 correct :  tensor([43.]) wrong :  tensor([1.]) total :  tensor([44.])
# 44 / 500 correct :  tensor([44.]) wrong :  tensor([1.]) total :  tensor([45.])
# 45 / 500 correct :  tensor([45.]) wrong :  tensor([1.]) total :  tensor([46.])
# 46 / 500 correct :  tensor([46.]) wrong :  tensor([1.]) total :  tensor([47.])
# 47 / 500 correct :  tensor([47.]) wrong :  tensor([1.]) total :  tensor([48.])
# 48 / 500 correct :  tensor([48.]) wrong :  tensor([1.]) total :  tensor([49.])
# 49 / 500 correct :  tensor([49.]) wrong :  tensor([1.]) total :  tensor([50.])
# 50 / 500 correct :  tensor([50.]) wrong :  tensor([1.]) total :  tensor([51.])
# 51 / 500 correct :  tensor([51.]) wrong :  tensor([1.]) total :  tensor([52.])
# 52 / 500 correct :  tensor([52.]) wrong :  tensor([1.]) total :  tensor([53.])
# 53 / 500 correct :  tensor([53.]) wrong :  tensor([1.]) total :  tensor([54.])
# 54 / 500 correct :  tensor([54.]) wrong :  tensor([1.]) total :  tensor([55.])
# 55 / 500 correct :  tensor([54.]) wrong :  tensor([2.]) total :  tensor([56.])
# 56 / 500 correct :  tensor([55.]) wrong :  tensor([2.]) total :  tensor([57.])
# 57 / 500 correct :  tensor([56.]) wrong :  tensor([2.]) total :  tensor([58.])
# 58 / 500 correct :  tensor([57.]) wrong :  tensor([2.]) total :  tensor([59.])
# 59 / 500 correct :  tensor([58.]) wrong :  tensor([2.]) total :  tensor([60.])
# 60 / 500 correct :  tensor([59.]) wrong :  tensor([2.]) total :  tensor([61.])
# 61 / 500 correct :  tensor([60.]) wrong :  tensor([2.]) total :  tensor([62.])
# 62 / 500 correct :  tensor([61.]) wrong :  tensor([2.]) total :  tensor([63.])
# 63 / 500 correct :  tensor([62.]) wrong :  tensor([2.]) total :  tensor([64.])
# 64 / 500 correct :  tensor([63.]) wrong :  tensor([2.]) total :  tensor([65.])
# 65 / 500 correct :  tensor([64.]) wrong :  tensor([2.]) total :  tensor([66.])
# 66 / 500 correct :  tensor([65.]) wrong :  tensor([2.]) total :  tensor([67.])
# 67 / 500 correct :  tensor([66.]) wrong :  tensor([2.]) total :  tensor([68.])
# 68 / 500 correct :  tensor([67.]) wrong :  tensor([2.]) total :  tensor([69.])
# 69 / 500 correct :  tensor([68.]) wrong :  tensor([2.]) total :  tensor([70.])
# 70 / 500 correct :  tensor([69.]) wrong :  tensor([2.]) total :  tensor([71.])
# 71 / 500 correct :  tensor([70.]) wrong :  tensor([2.]) total :  tensor([72.])
# 72 / 500 correct :  tensor([71.]) wrong :  tensor([2.]) total :  tensor([73.])
# 73 / 500 correct :  tensor([72.]) wrong :  tensor([2.]) total :  tensor([74.])
# 74 / 500 correct :  tensor([73.]) wrong :  tensor([2.]) total :  tensor([75.])
# 75 / 500 correct :  tensor([74.]) wrong :  tensor([2.]) total :  tensor([76.])
# 76 / 500 correct :  tensor([75.]) wrong :  tensor([2.]) total :  tensor([77.])
# 77 / 500 correct :  tensor([76.]) wrong :  tensor([2.]) total :  tensor([78.])
# 78 / 500 correct :  tensor([77.]) wrong :  tensor([2.]) total :  tensor([79.])
# 79 / 500 correct :  tensor([78.]) wrong :  tensor([2.]) total :  tensor([80.])
# 80 / 500 correct :  tensor([79.]) wrong :  tensor([2.]) total :  tensor([81.])
# 81 / 500 correct :  tensor([80.]) wrong :  tensor([2.]) total :  tensor([82.])
# 82 / 500 correct :  tensor([81.]) wrong :  tensor([2.]) total :  tensor([83.])
# 83 / 500 correct :  tensor([82.]) wrong :  tensor([2.]) total :  tensor([84.])
# 84 / 500 correct :  tensor([83.]) wrong :  tensor([2.]) total :  tensor([85.])
# 85 / 500 correct :  tensor([84.]) wrong :  tensor([2.]) total :  tensor([86.])
# 86 / 500 correct :  tensor([85.]) wrong :  tensor([2.]) total :  tensor([87.])
# 87 / 500 correct :  tensor([86.]) wrong :  tensor([2.]) total :  tensor([88.])
# 88 / 500 correct :  tensor([87.]) wrong :  tensor([2.]) total :  tensor([89.])
# 89 / 500 correct :  tensor([88.]) wrong :  tensor([2.]) total :  tensor([90.])
# 90 / 500 correct :  tensor([89.]) wrong :  tensor([2.]) total :  tensor([91.])
# 91 / 500 correct :  tensor([90.]) wrong :  tensor([2.]) total :  tensor([92.])
# 92 / 500 correct :  tensor([91.]) wrong :  tensor([2.]) total :  tensor([93.])
# 93 / 500 correct :  tensor([92.]) wrong :  tensor([2.]) total :  tensor([94.])
# 94 / 500 correct :  tensor([93.]) wrong :  tensor([2.]) total :  tensor([95.])
# 95 / 500 correct :  tensor([94.]) wrong :  tensor([2.]) total :  tensor([96.])
# 96 / 500 correct :  tensor([95.]) wrong :  tensor([2.]) total :  tensor([97.])
# 97 / 500 correct :  tensor([96.]) wrong :  tensor([2.]) total :  tensor([98.])
# 98 / 500 correct :  tensor([97.]) wrong :  tensor([2.]) total :  tensor([99.])
# 99 / 500 correct :  tensor([98.]) wrong :  tensor([2.]) total :  tensor([100.])
# 100 / 500 correct :  tensor([99.]) wrong :  tensor([2.]) total :  tensor([101.])
# 101 / 500 correct :  tensor([100.]) wrong :  tensor([2.]) total :  tensor([102.])
# 102 / 500 correct :  tensor([101.]) wrong :  tensor([2.]) total :  tensor([103.])
# 103 / 500 correct :  tensor([102.]) wrong :  tensor([2.]) total :  tensor([104.])
# 104 / 500 correct :  tensor([103.]) wrong :  tensor([2.]) total :  tensor([105.])
# 105 / 500 correct :  tensor([104.]) wrong :  tensor([2.]) total :  tensor([106.])
# 106 / 500 correct :  tensor([105.]) wrong :  tensor([2.]) total :  tensor([107.])
# 107 / 500 correct :  tensor([106.]) wrong :  tensor([2.]) total :  tensor([108.])
# 108 / 500 correct :  tensor([107.]) wrong :  tensor([2.]) total :  tensor([109.])
# 109 / 500 correct :  tensor([108.]) wrong :  tensor([2.]) total :  tensor([110.])
# 110 / 500 correct :  tensor([109.]) wrong :  tensor([2.]) total :  tensor([111.])
# 111 / 500 correct :  tensor([110.]) wrong :  tensor([2.]) total :  tensor([112.])
# 112 / 500 correct :  tensor([111.]) wrong :  tensor([2.]) total :  tensor([113.])
# 113 / 500 correct :  tensor([112.]) wrong :  tensor([2.]) total :  tensor([114.])
# 114 / 500 correct :  tensor([113.]) wrong :  tensor([2.]) total :  tensor([115.])
# 115 / 500 correct :  tensor([114.]) wrong :  tensor([2.]) total :  tensor([116.])
# 116 / 500 correct :  tensor([115.]) wrong :  tensor([2.]) total :  tensor([117.])
# 117 / 500 correct :  tensor([115.]) wrong :  tensor([3.]) total :  tensor([118.])
# 118 / 500 correct :  tensor([116.]) wrong :  tensor([3.]) total :  tensor([119.])
# 119 / 500 correct :  tensor([117.]) wrong :  tensor([3.]) total :  tensor([120.])
# 120 / 500 correct :  tensor([118.]) wrong :  tensor([3.]) total :  tensor([121.])
# 121 / 500 correct :  tensor([119.]) wrong :  tensor([3.]) total :  tensor([122.])
# 122 / 500 correct :  tensor([120.]) wrong :  tensor([3.]) total :  tensor([123.])
# 123 / 500 correct :  tensor([121.]) wrong :  tensor([3.]) total :  tensor([124.])
# 124 / 500 correct :  tensor([122.]) wrong :  tensor([3.]) total :  tensor([125.])
# 125 / 500 correct :  tensor([123.]) wrong :  tensor([3.]) total :  tensor([126.])
# 126 / 500 correct :  tensor([124.]) wrong :  tensor([3.]) total :  tensor([127.])
# 127 / 500 correct :  tensor([125.]) wrong :  tensor([3.]) total :  tensor([128.])
# 128 / 500 correct :  tensor([126.]) wrong :  tensor([3.]) total :  tensor([129.])
# 129 / 500 correct :  tensor([127.]) wrong :  tensor([3.]) total :  tensor([130.])
# 130 / 500 correct :  tensor([128.]) wrong :  tensor([3.]) total :  tensor([131.])
# 131 / 500 correct :  tensor([129.]) wrong :  tensor([3.]) total :  tensor([132.])
# 132 / 500 correct :  tensor([130.]) wrong :  tensor([3.]) total :  tensor([133.])
# 133 / 500 correct :  tensor([131.]) wrong :  tensor([3.]) total :  tensor([134.])
# 134 / 500 correct :  tensor([132.]) wrong :  tensor([3.]) total :  tensor([135.])
# 135 / 500 correct :  tensor([133.]) wrong :  tensor([3.]) total :  tensor([136.])
# 136 / 500 correct :  tensor([133.]) wrong :  tensor([4.]) total :  tensor([137.])
# 137 / 500 correct :  tensor([134.]) wrong :  tensor([4.]) total :  tensor([138.])
# 138 / 500 correct :  tensor([135.]) wrong :  tensor([4.]) total :  tensor([139.])
# 139 / 500 correct :  tensor([136.]) wrong :  tensor([4.]) total :  tensor([140.])
# 140 / 500 correct :  tensor([137.]) wrong :  tensor([4.]) total :  tensor([141.])
# 141 / 500 correct :  tensor([138.]) wrong :  tensor([4.]) total :  tensor([142.])
# 142 / 500 correct :  tensor([139.]) wrong :  tensor([4.]) total :  tensor([143.])
# 143 / 500 correct :  tensor([140.]) wrong :  tensor([4.]) total :  tensor([144.])
# 144 / 500 correct :  tensor([141.]) wrong :  tensor([4.]) total :  tensor([145.])
# 145 / 500 correct :  tensor([142.]) wrong :  tensor([4.]) total :  tensor([146.])
# 146 / 500 correct :  tensor([143.]) wrong :  tensor([4.]) total :  tensor([147.])
# 147 / 500 correct :  tensor([144.]) wrong :  tensor([4.]) total :  tensor([148.])
# 148 / 500 correct :  tensor([145.]) wrong :  tensor([4.]) total :  tensor([149.])
# 149 / 500 correct :  tensor([146.]) wrong :  tensor([4.]) total :  tensor([150.])
# 150 / 500 correct :  tensor([147.]) wrong :  tensor([4.]) total :  tensor([151.])
# 151 / 500 correct :  tensor([148.]) wrong :  tensor([4.]) total :  tensor([152.])
# 152 / 500 correct :  tensor([149.]) wrong :  tensor([4.]) total :  tensor([153.])
# 153 / 500 correct :  tensor([150.]) wrong :  tensor([4.]) total :  tensor([154.])
# 154 / 500 correct :  tensor([151.]) wrong :  tensor([4.]) total :  tensor([155.])
# 155 / 500 correct :  tensor([152.]) wrong :  tensor([4.]) total :  tensor([156.])
# 156 / 500 correct :  tensor([153.]) wrong :  tensor([4.]) total :  tensor([157.])
# 157 / 500 correct :  tensor([154.]) wrong :  tensor([4.]) total :  tensor([158.])
# 158 / 500 correct :  tensor([155.]) wrong :  tensor([4.]) total :  tensor([159.])
# 159 / 500 correct :  tensor([156.]) wrong :  tensor([4.]) total :  tensor([160.])
# 160 / 500 correct :  tensor([157.]) wrong :  tensor([4.]) total :  tensor([161.])
# 161 / 500 correct :  tensor([158.]) wrong :  tensor([4.]) total :  tensor([162.])
# 162 / 500 correct :  tensor([159.]) wrong :  tensor([4.]) total :  tensor([163.])
# 163 / 500 correct :  tensor([160.]) wrong :  tensor([4.]) total :  tensor([164.])
# 164 / 500 correct :  tensor([161.]) wrong :  tensor([4.]) total :  tensor([165.])
# 165 / 500 correct :  tensor([162.]) wrong :  tensor([4.]) total :  tensor([166.])
# 166 / 500 correct :  tensor([163.]) wrong :  tensor([4.]) total :  tensor([167.])
# 167 / 500 correct :  tensor([164.]) wrong :  tensor([4.]) total :  tensor([168.])
# 168 / 500 correct :  tensor([165.]) wrong :  tensor([4.]) total :  tensor([169.])
# 169 / 500 correct :  tensor([166.]) wrong :  tensor([4.]) total :  tensor([170.])
# 170 / 500 correct :  tensor([167.]) wrong :  tensor([4.]) total :  tensor([171.])
# 171 / 500 correct :  tensor([168.]) wrong :  tensor([4.]) total :  tensor([172.])
# 172 / 500 correct :  tensor([169.]) wrong :  tensor([4.]) total :  tensor([173.])
# 173 / 500 correct :  tensor([170.]) wrong :  tensor([4.]) total :  tensor([174.])
# 174 / 500 correct :  tensor([171.]) wrong :  tensor([4.]) total :  tensor([175.])
# 175 / 500 correct :  tensor([172.]) wrong :  tensor([4.]) total :  tensor([176.])
# 176 / 500 correct :  tensor([173.]) wrong :  tensor([4.]) total :  tensor([177.])
# 177 / 500 correct :  tensor([174.]) wrong :  tensor([4.]) total :  tensor([178.])
# 178 / 500 correct :  tensor([175.]) wrong :  tensor([4.]) total :  tensor([179.])
# 179 / 500 correct :  tensor([176.]) wrong :  tensor([4.]) total :  tensor([180.])
# 180 / 500 correct :  tensor([177.]) wrong :  tensor([4.]) total :  tensor([181.])
# 181 / 500 correct :  tensor([178.]) wrong :  tensor([4.]) total :  tensor([182.])
# 182 / 500 correct :  tensor([179.]) wrong :  tensor([4.]) total :  tensor([183.])
# 183 / 500 correct :  tensor([180.]) wrong :  tensor([4.]) total :  tensor([184.])
# 184 / 500 correct :  tensor([181.]) wrong :  tensor([4.]) total :  tensor([185.])
# 185 / 500 correct :  tensor([182.]) wrong :  tensor([4.]) total :  tensor([186.])
# 186 / 500 correct :  tensor([183.]) wrong :  tensor([4.]) total :  tensor([187.])
# 187 / 500 correct :  tensor([184.]) wrong :  tensor([4.]) total :  tensor([188.])
# 188 / 500 correct :  tensor([185.]) wrong :  tensor([4.]) total :  tensor([189.])
# 189 / 500 correct :  tensor([186.]) wrong :  tensor([4.]) total :  tensor([190.])
# 190 / 500 correct :  tensor([187.]) wrong :  tensor([4.]) total :  tensor([191.])
# 191 / 500 correct :  tensor([188.]) wrong :  tensor([4.]) total :  tensor([192.])
# 192 / 500 correct :  tensor([189.]) wrong :  tensor([4.]) total :  tensor([193.])
# 193 / 500 correct :  tensor([190.]) wrong :  tensor([4.]) total :  tensor([194.])
# 194 / 500 correct :  tensor([191.]) wrong :  tensor([4.]) total :  tensor([195.])
# 195 / 500 correct :  tensor([192.]) wrong :  tensor([4.]) total :  tensor([196.])
# 196 / 500 correct :  tensor([193.]) wrong :  tensor([4.]) total :  tensor([197.])
# 197 / 500 correct :  tensor([194.]) wrong :  tensor([4.]) total :  tensor([198.])
# 198 / 500 correct :  tensor([195.]) wrong :  tensor([4.]) total :  tensor([199.])
# 199 / 500 correct :  tensor([196.]) wrong :  tensor([4.]) total :  tensor([200.])
# 200 / 500 correct :  tensor([197.]) wrong :  tensor([4.]) total :  tensor([201.])
# 201 / 500 correct :  tensor([198.]) wrong :  tensor([4.]) total :  tensor([202.])
# 202 / 500 correct :  tensor([199.]) wrong :  tensor([4.]) total :  tensor([203.])
# 203 / 500 correct :  tensor([200.]) wrong :  tensor([4.]) total :  tensor([204.])
# 204 / 500 correct :  tensor([201.]) wrong :  tensor([4.]) total :  tensor([205.])
# 205 / 500 correct :  tensor([202.]) wrong :  tensor([4.]) total :  tensor([206.])
# 206 / 500 correct :  tensor([203.]) wrong :  tensor([4.]) total :  tensor([207.])
# 207 / 500 correct :  tensor([204.]) wrong :  tensor([4.]) total :  tensor([208.])
# 208 / 500 correct :  tensor([205.]) wrong :  tensor([4.]) total :  tensor([209.])
# 209 / 500 correct :  tensor([206.]) wrong :  tensor([4.]) total :  tensor([210.])
# 210 / 500 correct :  tensor([207.]) wrong :  tensor([4.]) total :  tensor([211.])
# 211 / 500 correct :  tensor([208.]) wrong :  tensor([4.]) total :  tensor([212.])
# 212 / 500 correct :  tensor([209.]) wrong :  tensor([4.]) total :  tensor([213.])
# 213 / 500 correct :  tensor([209.]) wrong :  tensor([5.]) total :  tensor([214.])
# 214 / 500 correct :  tensor([210.]) wrong :  tensor([5.]) total :  tensor([215.])
# 215 / 500 correct :  tensor([211.]) wrong :  tensor([5.]) total :  tensor([216.])
# 216 / 500 correct :  tensor([212.]) wrong :  tensor([5.]) total :  tensor([217.])
# 217 / 500 correct :  tensor([213.]) wrong :  tensor([5.]) total :  tensor([218.])
# 218 / 500 correct :  tensor([214.]) wrong :  tensor([5.]) total :  tensor([219.])
# 219 / 500 correct :  tensor([215.]) wrong :  tensor([5.]) total :  tensor([220.])
# 220 / 500 correct :  tensor([216.]) wrong :  tensor([5.]) total :  tensor([221.])
# 221 / 500 correct :  tensor([217.]) wrong :  tensor([5.]) total :  tensor([222.])
# 222 / 500 correct :  tensor([218.]) wrong :  tensor([5.]) total :  tensor([223.])
# 223 / 500 correct :  tensor([219.]) wrong :  tensor([5.]) total :  tensor([224.])
# 224 / 500 correct :  tensor([220.]) wrong :  tensor([5.]) total :  tensor([225.])
# 225 / 500 correct :  tensor([221.]) wrong :  tensor([5.]) total :  tensor([226.])
# 226 / 500 correct :  tensor([222.]) wrong :  tensor([5.]) total :  tensor([227.])
# 227 / 500 correct :  tensor([223.]) wrong :  tensor([5.]) total :  tensor([228.])
# 228 / 500 correct :  tensor([224.]) wrong :  tensor([5.]) total :  tensor([229.])
# 229 / 500 correct :  tensor([225.]) wrong :  tensor([5.]) total :  tensor([230.])
# 230 / 500 correct :  tensor([226.]) wrong :  tensor([5.]) total :  tensor([231.])
# 231 / 500 correct :  tensor([227.]) wrong :  tensor([5.]) total :  tensor([232.])
# 232 / 500 correct :  tensor([228.]) wrong :  tensor([5.]) total :  tensor([233.])
# 233 / 500 correct :  tensor([229.]) wrong :  tensor([5.]) total :  tensor([234.])
# 234 / 500 correct :  tensor([230.]) wrong :  tensor([5.]) total :  tensor([235.])
# 235 / 500 correct :  tensor([231.]) wrong :  tensor([5.]) total :  tensor([236.])
# 236 / 500 correct :  tensor([232.]) wrong :  tensor([5.]) total :  tensor([237.])
# 237 / 500 correct :  tensor([233.]) wrong :  tensor([5.]) total :  tensor([238.])
# 238 / 500 correct :  tensor([234.]) wrong :  tensor([5.]) total :  tensor([239.])
# 239 / 500 correct :  tensor([235.]) wrong :  tensor([5.]) total :  tensor([240.])
# 240 / 500 correct :  tensor([236.]) wrong :  tensor([5.]) total :  tensor([241.])
# 241 / 500 correct :  tensor([237.]) wrong :  tensor([5.]) total :  tensor([242.])
# 242 / 500 correct :  tensor([238.]) wrong :  tensor([5.]) total :  tensor([243.])
# 243 / 500 correct :  tensor([239.]) wrong :  tensor([5.]) total :  tensor([244.])
# 244 / 500 correct :  tensor([240.]) wrong :  tensor([5.]) total :  tensor([245.])
# 245 / 500 correct :  tensor([241.]) wrong :  tensor([5.]) total :  tensor([246.])
# 246 / 500 correct :  tensor([242.]) wrong :  tensor([5.]) total :  tensor([247.])
# 247 / 500 correct :  tensor([243.]) wrong :  tensor([5.]) total :  tensor([248.])
# 248 / 500 correct :  tensor([244.]) wrong :  tensor([5.]) total :  tensor([249.])
# 249 / 500 correct :  tensor([245.]) wrong :  tensor([5.]) total :  tensor([250.])
# 250 / 500 correct :  tensor([246.]) wrong :  tensor([5.]) total :  tensor([251.])
# 251 / 500 correct :  tensor([247.]) wrong :  tensor([5.]) total :  tensor([252.])
# 252 / 500 correct :  tensor([248.]) wrong :  tensor([5.]) total :  tensor([253.])
# 253 / 500 correct :  tensor([249.]) wrong :  tensor([5.]) total :  tensor([254.])
# 254 / 500 correct :  tensor([250.]) wrong :  tensor([5.]) total :  tensor([255.])
# 255 / 500 correct :  tensor([251.]) wrong :  tensor([5.]) total :  tensor([256.])
# 256 / 500 correct :  tensor([252.]) wrong :  tensor([5.]) total :  tensor([257.])
# 257 / 500 correct :  tensor([253.]) wrong :  tensor([5.]) total :  tensor([258.])
# 258 / 500 correct :  tensor([254.]) wrong :  tensor([5.]) total :  tensor([259.])
# 259 / 500 correct :  tensor([255.]) wrong :  tensor([5.]) total :  tensor([260.])
# 260 / 500 correct :  tensor([256.]) wrong :  tensor([5.]) total :  tensor([261.])
# 261 / 500 correct :  tensor([257.]) wrong :  tensor([5.]) total :  tensor([262.])
# 262 / 500 correct :  tensor([258.]) wrong :  tensor([5.]) total :  tensor([263.])
# 263 / 500 correct :  tensor([259.]) wrong :  tensor([5.]) total :  tensor([264.])
# 264 / 500 correct :  tensor([260.]) wrong :  tensor([5.]) total :  tensor([265.])
# 265 / 500 correct :  tensor([261.]) wrong :  tensor([5.]) total :  tensor([266.])
# 266 / 500 correct :  tensor([262.]) wrong :  tensor([5.]) total :  tensor([267.])
# 267 / 500 correct :  tensor([263.]) wrong :  tensor([5.]) total :  tensor([268.])
# 268 / 500 correct :  tensor([264.]) wrong :  tensor([5.]) total :  tensor([269.])
# 269 / 500 correct :  tensor([265.]) wrong :  tensor([5.]) total :  tensor([270.])
# 270 / 500 correct :  tensor([266.]) wrong :  tensor([5.]) total :  tensor([271.])
# 271 / 500 correct :  tensor([267.]) wrong :  tensor([5.]) total :  tensor([272.])
# 272 / 500 correct :  tensor([268.]) wrong :  tensor([5.]) total :  tensor([273.])
# 273 / 500 correct :  tensor([269.]) wrong :  tensor([5.]) total :  tensor([274.])
# 274 / 500 correct :  tensor([270.]) wrong :  tensor([5.]) total :  tensor([275.])
# 275 / 500 correct :  tensor([271.]) wrong :  tensor([5.]) total :  tensor([276.])
# 276 / 500 correct :  tensor([272.]) wrong :  tensor([5.]) total :  tensor([277.])
# 277 / 500 correct :  tensor([273.]) wrong :  tensor([5.]) total :  tensor([278.])
# 278 / 500 correct :  tensor([274.]) wrong :  tensor([5.]) total :  tensor([279.])
# 279 / 500 correct :  tensor([275.]) wrong :  tensor([5.]) total :  tensor([280.])
# 280 / 500 correct :  tensor([276.]) wrong :  tensor([5.]) total :  tensor([281.])
# 281 / 500 correct :  tensor([277.]) wrong :  tensor([5.]) total :  tensor([282.])
# 282 / 500 correct :  tensor([278.]) wrong :  tensor([5.]) total :  tensor([283.])
# 283 / 500 correct :  tensor([279.]) wrong :  tensor([5.]) total :  tensor([284.])
# 284 / 500 correct :  tensor([280.]) wrong :  tensor([5.]) total :  tensor([285.])
# 285 / 500 correct :  tensor([281.]) wrong :  tensor([5.]) total :  tensor([286.])
# 286 / 500 correct :  tensor([282.]) wrong :  tensor([5.]) total :  tensor([287.])
# 287 / 500 correct :  tensor([283.]) wrong :  tensor([5.]) total :  tensor([288.])
# 288 / 500 correct :  tensor([284.]) wrong :  tensor([5.]) total :  tensor([289.])
# 289 / 500 correct :  tensor([285.]) wrong :  tensor([5.]) total :  tensor([290.])
# 290 / 500 correct :  tensor([286.]) wrong :  tensor([5.]) total :  tensor([291.])
# 291 / 500 correct :  tensor([287.]) wrong :  tensor([5.]) total :  tensor([292.])
# 292 / 500 correct :  tensor([287.]) wrong :  tensor([6.]) total :  tensor([293.])
# 293 / 500 correct :  tensor([288.]) wrong :  tensor([6.]) total :  tensor([294.])
# 294 / 500 correct :  tensor([289.]) wrong :  tensor([6.]) total :  tensor([295.])
# 295 / 500 correct :  tensor([290.]) wrong :  tensor([6.]) total :  tensor([296.])
# 296 / 500 correct :  tensor([291.]) wrong :  tensor([6.]) total :  tensor([297.])
# 297 / 500 correct :  tensor([292.]) wrong :  tensor([6.]) total :  tensor([298.])
# 298 / 500 correct :  tensor([293.]) wrong :  tensor([6.]) total :  tensor([299.])
# 299 / 500 correct :  tensor([294.]) wrong :  tensor([6.]) total :  tensor([300.])
# 300 / 500 correct :  tensor([295.]) wrong :  tensor([6.]) total :  tensor([301.])
# 301 / 500 correct :  tensor([296.]) wrong :  tensor([6.]) total :  tensor([302.])
# 302 / 500 correct :  tensor([297.]) wrong :  tensor([6.]) total :  tensor([303.])
# 303 / 500 correct :  tensor([298.]) wrong :  tensor([6.]) total :  tensor([304.])
# 304 / 500 correct :  tensor([299.]) wrong :  tensor([6.]) total :  tensor([305.])
# 305 / 500 correct :  tensor([300.]) wrong :  tensor([6.]) total :  tensor([306.])
# 306 / 500 correct :  tensor([301.]) wrong :  tensor([6.]) total :  tensor([307.])
# 307 / 500 correct :  tensor([302.]) wrong :  tensor([6.]) total :  tensor([308.])
# 308 / 500 correct :  tensor([303.]) wrong :  tensor([6.]) total :  tensor([309.])
# 309 / 500 correct :  tensor([304.]) wrong :  tensor([6.]) total :  tensor([310.])
# 310 / 500 correct :  tensor([305.]) wrong :  tensor([6.]) total :  tensor([311.])
# 311 / 500 correct :  tensor([306.]) wrong :  tensor([6.]) total :  tensor([312.])
# 312 / 500 correct :  tensor([306.]) wrong :  tensor([7.]) total :  tensor([313.])
# 313 / 500 correct :  tensor([307.]) wrong :  tensor([7.]) total :  tensor([314.])
# 314 / 500 correct :  tensor([308.]) wrong :  tensor([7.]) total :  tensor([315.])
# 315 / 500 correct :  tensor([309.]) wrong :  tensor([7.]) total :  tensor([316.])
# 316 / 500 correct :  tensor([310.]) wrong :  tensor([7.]) total :  tensor([317.])
# 317 / 500 correct :  tensor([311.]) wrong :  tensor([7.]) total :  tensor([318.])
# 318 / 500 correct :  tensor([312.]) wrong :  tensor([7.]) total :  tensor([319.])
# 319 / 500 correct :  tensor([313.]) wrong :  tensor([7.]) total :  tensor([320.])
# 320 / 500 correct :  tensor([314.]) wrong :  tensor([7.]) total :  tensor([321.])
# 321 / 500 correct :  tensor([315.]) wrong :  tensor([7.]) total :  tensor([322.])
# 322 / 500 correct :  tensor([316.]) wrong :  tensor([7.]) total :  tensor([323.])
# 323 / 500 correct :  tensor([317.]) wrong :  tensor([7.]) total :  tensor([324.])
# 324 / 500 correct :  tensor([318.]) wrong :  tensor([7.]) total :  tensor([325.])
# 325 / 500 correct :  tensor([319.]) wrong :  tensor([7.]) total :  tensor([326.])
# 326 / 500 correct :  tensor([320.]) wrong :  tensor([7.]) total :  tensor([327.])
# 327 / 500 correct :  tensor([321.]) wrong :  tensor([7.]) total :  tensor([328.])
# 328 / 500 correct :  tensor([322.]) wrong :  tensor([7.]) total :  tensor([329.])
# 329 / 500 correct :  tensor([323.]) wrong :  tensor([7.]) total :  tensor([330.])
# 330 / 500 correct :  tensor([324.]) wrong :  tensor([7.]) total :  tensor([331.])
# 331 / 500 correct :  tensor([325.]) wrong :  tensor([7.]) total :  tensor([332.])
# 332 / 500 correct :  tensor([326.]) wrong :  tensor([7.]) total :  tensor([333.])
# 333 / 500 correct :  tensor([327.]) wrong :  tensor([7.]) total :  tensor([334.])
# 334 / 500 correct :  tensor([328.]) wrong :  tensor([7.]) total :  tensor([335.])
# 335 / 500 correct :  tensor([329.]) wrong :  tensor([7.]) total :  tensor([336.])
# 336 / 500 correct :  tensor([330.]) wrong :  tensor([7.]) total :  tensor([337.])
# 337 / 500 correct :  tensor([331.]) wrong :  tensor([7.]) total :  tensor([338.])
# 338 / 500 correct :  tensor([332.]) wrong :  tensor([7.]) total :  tensor([339.])
# 339 / 500 correct :  tensor([333.]) wrong :  tensor([7.]) total :  tensor([340.])
# 340 / 500 correct :  tensor([334.]) wrong :  tensor([7.]) total :  tensor([341.])
# 341 / 500 correct :  tensor([335.]) wrong :  tensor([7.]) total :  tensor([342.])
# 342 / 500 correct :  tensor([336.]) wrong :  tensor([7.]) total :  tensor([343.])
# 343 / 500 correct :  tensor([337.]) wrong :  tensor([7.]) total :  tensor([344.])
# 344 / 500 correct :  tensor([338.]) wrong :  tensor([7.]) total :  tensor([345.])
# 345 / 500 correct :  tensor([339.]) wrong :  tensor([7.]) total :  tensor([346.])
# 346 / 500 correct :  tensor([340.]) wrong :  tensor([7.]) total :  tensor([347.])
# 347 / 500 correct :  tensor([341.]) wrong :  tensor([7.]) total :  tensor([348.])
# 348 / 500 correct :  tensor([342.]) wrong :  tensor([7.]) total :  tensor([349.])
# 349 / 500 correct :  tensor([343.]) wrong :  tensor([7.]) total :  tensor([350.])
# 350 / 500 correct :  tensor([344.]) wrong :  tensor([7.]) total :  tensor([351.])
# 351 / 500 correct :  tensor([345.]) wrong :  tensor([7.]) total :  tensor([352.])
# 352 / 500 correct :  tensor([346.]) wrong :  tensor([7.]) total :  tensor([353.])
# 353 / 500 correct :  tensor([347.]) wrong :  tensor([7.]) total :  tensor([354.])
# 354 / 500 correct :  tensor([348.]) wrong :  tensor([7.]) total :  tensor([355.])
# 355 / 500 correct :  tensor([349.]) wrong :  tensor([7.]) total :  tensor([356.])
# 356 / 500 correct :  tensor([350.]) wrong :  tensor([7.]) total :  tensor([357.])
# 357 / 500 correct :  tensor([351.]) wrong :  tensor([7.]) total :  tensor([358.])
# 358 / 500 correct :  tensor([352.]) wrong :  tensor([7.]) total :  tensor([359.])
# 359 / 500 correct :  tensor([353.]) wrong :  tensor([7.]) total :  tensor([360.])
# 360 / 500 correct :  tensor([354.]) wrong :  tensor([7.]) total :  tensor([361.])
# 361 / 500 correct :  tensor([355.]) wrong :  tensor([7.]) total :  tensor([362.])
# 362 / 500 correct :  tensor([356.]) wrong :  tensor([7.]) total :  tensor([363.])
# 363 / 500 correct :  tensor([357.]) wrong :  tensor([7.]) total :  tensor([364.])
# 364 / 500 correct :  tensor([358.]) wrong :  tensor([7.]) total :  tensor([365.])
# 365 / 500 correct :  tensor([359.]) wrong :  tensor([7.]) total :  tensor([366.])
# 366 / 500 correct :  tensor([360.]) wrong :  tensor([7.]) total :  tensor([367.])
# 367 / 500 correct :  tensor([361.]) wrong :  tensor([7.]) total :  tensor([368.])
# 368 / 500 correct :  tensor([362.]) wrong :  tensor([7.]) total :  tensor([369.])
# 369 / 500 correct :  tensor([363.]) wrong :  tensor([7.]) total :  tensor([370.])
# 370 / 500 correct :  tensor([364.]) wrong :  tensor([7.]) total :  tensor([371.])
# 371 / 500 correct :  tensor([365.]) wrong :  tensor([7.]) total :  tensor([372.])
# 372 / 500 correct :  tensor([366.]) wrong :  tensor([7.]) total :  tensor([373.])
# 373 / 500 correct :  tensor([367.]) wrong :  tensor([7.]) total :  tensor([374.])
# 374 / 500 correct :  tensor([368.]) wrong :  tensor([7.]) total :  tensor([375.])
# 375 / 500 correct :  tensor([369.]) wrong :  tensor([7.]) total :  tensor([376.])
# 376 / 500 correct :  tensor([370.]) wrong :  tensor([7.]) total :  tensor([377.])
# 377 / 500 correct :  tensor([371.]) wrong :  tensor([7.]) total :  tensor([378.])
# 378 / 500 correct :  tensor([372.]) wrong :  tensor([7.]) total :  tensor([379.])
# 379 / 500 correct :  tensor([373.]) wrong :  tensor([7.]) total :  tensor([380.])
# 380 / 500 correct :  tensor([374.]) wrong :  tensor([7.]) total :  tensor([381.])
# 381 / 500 correct :  tensor([375.]) wrong :  tensor([7.]) total :  tensor([382.])
# 382 / 500 correct :  tensor([376.]) wrong :  tensor([7.]) total :  tensor([383.])
# 383 / 500 correct :  tensor([377.]) wrong :  tensor([7.]) total :  tensor([384.])
# 384 / 500 correct :  tensor([378.]) wrong :  tensor([7.]) total :  tensor([385.])
# 385 / 500 correct :  tensor([379.]) wrong :  tensor([7.]) total :  tensor([386.])
# 386 / 500 correct :  tensor([380.]) wrong :  tensor([7.]) total :  tensor([387.])
# 387 / 500 correct :  tensor([381.]) wrong :  tensor([7.]) total :  tensor([388.])
# 388 / 500 correct :  tensor([382.]) wrong :  tensor([7.]) total :  tensor([389.])
# 389 / 500 correct :  tensor([383.]) wrong :  tensor([7.]) total :  tensor([390.])
# 390 / 500 correct :  tensor([384.]) wrong :  tensor([7.]) total :  tensor([391.])
# 391 / 500 correct :  tensor([385.]) wrong :  tensor([7.]) total :  tensor([392.])
# 392 / 500 correct :  tensor([386.]) wrong :  tensor([7.]) total :  tensor([393.])
# 393 / 500 correct :  tensor([387.]) wrong :  tensor([7.]) total :  tensor([394.])
# 394 / 500 correct :  tensor([388.]) wrong :  tensor([7.]) total :  tensor([395.])
# 395 / 500 correct :  tensor([389.]) wrong :  tensor([7.]) total :  tensor([396.])
# 396 / 500 correct :  tensor([390.]) wrong :  tensor([7.]) total :  tensor([397.])
# 397 / 500 correct :  tensor([391.]) wrong :  tensor([7.]) total :  tensor([398.])
# 398 / 500 correct :  tensor([392.]) wrong :  tensor([7.]) total :  tensor([399.])
# 399 / 500 correct :  tensor([393.]) wrong :  tensor([7.]) total :  tensor([400.])
# 400 / 500 correct :  tensor([394.]) wrong :  tensor([7.]) total :  tensor([401.])
# 401 / 500 correct :  tensor([395.]) wrong :  tensor([7.]) total :  tensor([402.])
# 402 / 500 correct :  tensor([396.]) wrong :  tensor([7.]) total :  tensor([403.])
# 403 / 500 correct :  tensor([397.]) wrong :  tensor([7.]) total :  tensor([404.])
# 404 / 500 correct :  tensor([398.]) wrong :  tensor([7.]) total :  tensor([405.])
# 405 / 500 correct :  tensor([399.]) wrong :  tensor([7.]) total :  tensor([406.])
# 406 / 500 correct :  tensor([400.]) wrong :  tensor([7.]) total :  tensor([407.])
# 407 / 500 correct :  tensor([401.]) wrong :  tensor([7.]) total :  tensor([408.])
# 408 / 500 correct :  tensor([402.]) wrong :  tensor([7.]) total :  tensor([409.])
# 409 / 500 correct :  tensor([403.]) wrong :  tensor([7.]) total :  tensor([410.])
# 410 / 500 correct :  tensor([404.]) wrong :  tensor([7.]) total :  tensor([411.])
# 411 / 500 correct :  tensor([405.]) wrong :  tensor([7.]) total :  tensor([412.])
# 412 / 500 correct :  tensor([406.]) wrong :  tensor([7.]) total :  tensor([413.])
# 413 / 500 correct :  tensor([407.]) wrong :  tensor([7.]) total :  tensor([414.])
# 414 / 500 correct :  tensor([408.]) wrong :  tensor([7.]) total :  tensor([415.])
# 415 / 500 correct :  tensor([409.]) wrong :  tensor([7.]) total :  tensor([416.])
# 416 / 500 correct :  tensor([410.]) wrong :  tensor([7.]) total :  tensor([417.])
# 417 / 500 correct :  tensor([411.]) wrong :  tensor([7.]) total :  tensor([418.])
# 418 / 500 correct :  tensor([412.]) wrong :  tensor([7.]) total :  tensor([419.])
# 419 / 500 correct :  tensor([412.]) wrong :  tensor([8.]) total :  tensor([420.])
# 420 / 500 correct :  tensor([413.]) wrong :  tensor([8.]) total :  tensor([421.])
# 421 / 500 correct :  tensor([414.]) wrong :  tensor([8.]) total :  tensor([422.])
# 422 / 500 correct :  tensor([415.]) wrong :  tensor([8.]) total :  tensor([423.])
# 423 / 500 correct :  tensor([416.]) wrong :  tensor([8.]) total :  tensor([424.])
# 424 / 500 correct :  tensor([417.]) wrong :  tensor([8.]) total :  tensor([425.])
# 425 / 500 correct :  tensor([418.]) wrong :  tensor([8.]) total :  tensor([426.])
# 426 / 500 correct :  tensor([419.]) wrong :  tensor([8.]) total :  tensor([427.])
# 427 / 500 correct :  tensor([420.]) wrong :  tensor([8.]) total :  tensor([428.])
# 428 / 500 correct :  tensor([421.]) wrong :  tensor([8.]) total :  tensor([429.])
# 429 / 500 correct :  tensor([422.]) wrong :  tensor([8.]) total :  tensor([430.])
# 430 / 500 correct :  tensor([423.]) wrong :  tensor([8.]) total :  tensor([431.])
# 431 / 500 correct :  tensor([424.]) wrong :  tensor([8.]) total :  tensor([432.])
# 432 / 500 correct :  tensor([425.]) wrong :  tensor([8.]) total :  tensor([433.])
# 433 / 500 correct :  tensor([426.]) wrong :  tensor([8.]) total :  tensor([434.])
# 434 / 500 correct :  tensor([427.]) wrong :  tensor([8.]) total :  tensor([435.])
# 435 / 500 correct :  tensor([427.]) wrong :  tensor([9.]) total :  tensor([436.])
# 436 / 500 correct :  tensor([427.]) wrong :  tensor([10.]) total :  tensor([437.])
# 437 / 500 correct :  tensor([428.]) wrong :  tensor([10.]) total :  tensor([438.])
# 438 / 500 correct :  tensor([429.]) wrong :  tensor([10.]) total :  tensor([439.])
# 439 / 500 correct :  tensor([430.]) wrong :  tensor([10.]) total :  tensor([440.])
# 440 / 500 correct :  tensor([431.]) wrong :  tensor([10.]) total :  tensor([441.])
# 441 / 500 correct :  tensor([432.]) wrong :  tensor([10.]) total :  tensor([442.])
# 442 / 500 correct :  tensor([432.]) wrong :  tensor([11.]) total :  tensor([443.])
# 443 / 500 correct :  tensor([433.]) wrong :  tensor([11.]) total :  tensor([444.])
# 444 / 500 correct :  tensor([434.]) wrong :  tensor([11.]) total :  tensor([445.])
# 445 / 500 correct :  tensor([435.]) wrong :  tensor([11.]) total :  tensor([446.])
# 446 / 500 correct :  tensor([436.]) wrong :  tensor([11.]) total :  tensor([447.])
# 447 / 500 correct :  tensor([437.]) wrong :  tensor([11.]) total :  tensor([448.])
# 448 / 500 correct :  tensor([438.]) wrong :  tensor([11.]) total :  tensor([449.])
# 449 / 500 correct :  tensor([438.]) wrong :  tensor([12.]) total :  tensor([450.])
# 450 / 500 correct :  tensor([439.]) wrong :  tensor([12.]) total :  tensor([451.])
# 451 / 500 correct :  tensor([439.]) wrong :  tensor([13.]) total :  tensor([452.])
# 452 / 500 correct :  tensor([440.]) wrong :  tensor([13.]) total :  tensor([453.])
# 453 / 500 correct :  tensor([441.]) wrong :  tensor([13.]) total :  tensor([454.])
# 454 / 500 correct :  tensor([442.]) wrong :  tensor([13.]) total :  tensor([455.])
# 455 / 500 correct :  tensor([443.]) wrong :  tensor([13.]) total :  tensor([456.])
# 456 / 500 correct :  tensor([444.]) wrong :  tensor([13.]) total :  tensor([457.])
# 457 / 500 correct :  tensor([445.]) wrong :  tensor([13.]) total :  tensor([458.])
# 458 / 500 correct :  tensor([446.]) wrong :  tensor([13.]) total :  tensor([459.])
# 459 / 500 correct :  tensor([447.]) wrong :  tensor([13.]) total :  tensor([460.])
# 460 / 500 correct :  tensor([448.]) wrong :  tensor([13.]) total :  tensor([461.])
# 461 / 500 correct :  tensor([449.]) wrong :  tensor([13.]) total :  tensor([462.])
# 462 / 500 correct :  tensor([450.]) wrong :  tensor([13.]) total :  tensor([463.])
# 463 / 500 correct :  tensor([451.]) wrong :  tensor([13.]) total :  tensor([464.])
# 464 / 500 correct :  tensor([452.]) wrong :  tensor([13.]) total :  tensor([465.])
# 465 / 500 correct :  tensor([453.]) wrong :  tensor([13.]) total :  tensor([466.])
# 466 / 500 correct :  tensor([454.]) wrong :  tensor([13.]) total :  tensor([467.])
# 467 / 500 correct :  tensor([455.]) wrong :  tensor([13.]) total :  tensor([468.])
# 468 / 500 correct :  tensor([456.]) wrong :  tensor([13.]) total :  tensor([469.])
# 469 / 500 correct :  tensor([457.]) wrong :  tensor([13.]) total :  tensor([470.])
# 470 / 500 correct :  tensor([458.]) wrong :  tensor([13.]) total :  tensor([471.])
# 471 / 500 correct :  tensor([459.]) wrong :  tensor([13.]) total :  tensor([472.])
# 472 / 500 correct :  tensor([460.]) wrong :  tensor([13.]) total :  tensor([473.])
# 473 / 500 correct :  tensor([461.]) wrong :  tensor([13.]) total :  tensor([474.])
# 474 / 500 correct :  tensor([462.]) wrong :  tensor([13.]) total :  tensor([475.])
# 475 / 500 correct :  tensor([463.]) wrong :  tensor([13.]) total :  tensor([476.])
# 476 / 500 correct :  tensor([464.]) wrong :  tensor([13.]) total :  tensor([477.])
# 477 / 500 correct :  tensor([465.]) wrong :  tensor([13.]) total :  tensor([478.])
# 478 / 500 correct :  tensor([466.]) wrong :  tensor([13.]) total :  tensor([479.])
# 479 / 500 correct :  tensor([466.]) wrong :  tensor([14.]) total :  tensor([480.])
# 480 / 500 correct :  tensor([467.]) wrong :  tensor([14.]) total :  tensor([481.])
# 481 / 500 correct :  tensor([467.]) wrong :  tensor([15.]) total :  tensor([482.])
# 482 / 500 correct :  tensor([468.]) wrong :  tensor([15.]) total :  tensor([483.])
# 483 / 500 correct :  tensor([469.]) wrong :  tensor([15.]) total :  tensor([484.])
# 484 / 500 correct :  tensor([470.]) wrong :  tensor([15.]) total :  tensor([485.])
# 485 / 500 correct :  tensor([471.]) wrong :  tensor([15.]) total :  tensor([486.])
# 486 / 500 correct :  tensor([472.]) wrong :  tensor([15.]) total :  tensor([487.])
# 487 / 500 correct :  tensor([473.]) wrong :  tensor([15.]) total :  tensor([488.])
# 488 / 500 correct :  tensor([473.]) wrong :  tensor([16.]) total :  tensor([489.])
# 489 / 500 correct :  tensor([474.]) wrong :  tensor([16.]) total :  tensor([490.])
# 490 / 500 correct :  tensor([474.]) wrong :  tensor([17.]) total :  tensor([491.])
# 491 / 500 correct :  tensor([475.]) wrong :  tensor([17.]) total :  tensor([492.])
# 492 / 500 correct :  tensor([476.]) wrong :  tensor([17.]) total :  tensor([493.])
# 493 / 500 correct :  tensor([477.]) wrong :  tensor([17.]) total :  tensor([494.])
# 494 / 500 correct :  tensor([478.]) wrong :  tensor([17.]) total :  tensor([495.])
# 495 / 500 correct :  tensor([478.]) wrong :  tensor([18.]) total :  tensor([496.])
# 496 / 500 correct :  tensor([479.]) wrong :  tensor([18.]) total :  tensor([497.])
# 497 / 500 correct :  tensor([480.]) wrong :  tensor([18.]) total :  tensor([498.])
# 498 / 500 correct :  tensor([481.]) wrong :  tensor([18.]) total :  tensor([499.])
# 499 / 500 correct :  tensor([482.]) wrong :  tensor([18.]) total :  tensor([500.])
# Test Data Accuracy: [96.4]%

# %%
criterion = nn.CrossEntropyLoss(ignore_index=19, reduction='mean')

def test_synthia() :
    encoder = EncoderModule()
    decoder = DecoderModule()

    encoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_encoder_fda_once.pth"))
    decoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_decoder_fda_once.pth"))

    encoder.eval()
    decoder.eval()

    intersection_meter = AverageMeter()
    union_meter = AverageMeter()
    target_meter = AverageMeter()

    if torch.cuda.is_available() :
        encoder = encoder.cuda()
        decoder = decoder.cuda()

    src_seg_loss = 0

    for batch_idx, (src_data, src_target) in enumerate(synthia_testLoader) :
        print(batch_idx)
        src_seg_target = src_target['segmentation']

        src_data, src_seg_target = src_data.to(device),  src_seg_target.to(device)

        # segmentation : encoder & decoder
        feature, sc = encoder(src_data)
        result = decoder(feature, sc)

        src_seg_loss += criterion(result, src_seg_target).item()

        intersection, union, segmentation_target = intersectionAndUnion(output=result.cpu(), target=src_seg_target.cpu(), K=19, ignore_idx=19)
        intersection_meter.update(intersection), union_meter.update(union), target_meter.update(segmentation_target)
        accuracy = sum(intersection_meter.val) / (sum(target_meter.val) + 1e-10)

    src_seg_loss /= len(synthia_testLoader.dataset)
         
    iou_class = intersection_meter.sum / (union_meter.sum + 1e-10)
    accuracy_class = intersection_meter.sum / (target_meter.sum + 1e-10)
    mIOU = np.mean(iou_class)
    mAcc = np.mean(accuracy_class)
    allAcc = sum(intersection_meter.sum) / (sum(target_meter.sum) + 1e-10)

    print('Test : mIOU {:.6f} | mACC {:.6f}% | ACC {:.6f}% ' .format( mIOU, mAcc, allAcc))

test_synthia()

# %%
criterion = nn.CrossEntropyLoss(ignore_index=19, reduction='mean')

def test_cityscape() :
    encoder = EncoderModule()
    decoder = DecoderModule()

    encoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_encoder_fda_once.pth"))
    decoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_decoder_fda_once.pth"))

    encoder.eval()
    decoder.eval()

    intersection_meter = AverageMeter()
    union_meter = AverageMeter()
    target_meter = AverageMeter()

    if torch.cuda.is_available() :
        encoder = encoder.cuda()
        decoder = decoder.cuda()

    seg_loss = 0

    for batch_idx, (tgt_data, tgt_target) in enumerate(cityscape_testLoader) :
        print(batch_idx)
        tgt_seg_target = tgt_target['segmentation']

        tgt_data, tgt_seg_target = tgt_data.to(device),  tgt_seg_target.to(device)

        # segmentation : encoder & decoder
        feature, sc = encoder(tgt_data)
        result = decoder(feature, sc)

        seg_loss += criterion(result, tgt_seg_target).item()

        intersection, union, segmentation_target = intersectionAndUnion(output=result.cpu(), target=tgt_seg_target.cpu(), K=19, ignore_idx=19)
        intersection_meter.update(intersection), union_meter.update(union), target_meter.update(segmentation_target)
        accuracy = sum(intersection_meter.val) / (sum(target_meter.val) + 1e-10)

    seg_loss /= len(cityscape_testLoader.dataset)

    iou_class = intersection_meter.sum / (union_meter.sum + 1e-10)
    accuracy_class = intersection_meter.sum / (target_meter.sum + 1e-10)
    mIOU = np.mean(iou_class)
    mAcc = np.mean(accuracy_class)
    allAcc = sum(intersection_meter.sum) / (sum(target_meter.sum) + 1e-10)

    print('Test : mIOU {:.6f} | mACC {:.6f}% | ACC {:.6f}% ' .format( mIOU, mAcc, allAcc))

test_cityscape()

# %%
def trainOnce(start, max_epoch) :
    
    srcData_iter = iter(synthia_trainLoader)
    tgtData_iter = iter(cityscape_trainLoader)
    
    encoder = EncoderModule()
    decoder = DecoderModule()
    domain_cls = DomainClassifier()

    conf_optim = optim.Adam(encoder.parameters(), lr=0.00001)
    seg_optim = optim.SGD(list(encoder.parameters())+list(decoder.parameters()), lr=0.1, weight_decay=0.001, momentum=0.9)
    criterion_seg = nn.CrossEntropyLoss(ignore_index=19, reduction='mean')
    cls_optim = optim.Adam(domain_cls.parameters(), lr=0.00001)
    
    encoder.train()
    decoder.train()
    domain_cls.train()
    
    intersection_meter = AverageMeter()
    union_meter = AverageMeter()
    target_meter = AverageMeter()
    
    # if torch.cuda.is_available() :
    #     encoder = encoder.cuda()
    #     decoder = decoder.cuda()
    #     domain_cls = domain_cls.cuda()
    
    conf = 0.
    cls = 0.
        
    for epoch in range(start, max_epoch) :
        
        if epoch>0 :
            encoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_encoder_fda_once_2.pth"))
            decoder.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_decoder_fda_once_2.pth"))
            domain_cls.load_state_dict(torch.load("gdrive/My Drive/Colab Notebooks/uda_domain_cls_once_2.pth"))

        if torch.cuda.is_available() :
            encoder = encoder.cuda()
            decoder = decoder.cuda()
            domain_cls = domain_cls.cuda()

        seg_optim.zero_grad()
        conf_optim.zero_grad()
        cls_optim.zero_grad()
        
        #get data and label
        try :
            src_data, src_label = next(srcData_iter)
        except StopIteration :
            srcData_iter = iter(synthia_trainLoader)
            src_data, src_label = next(srcData_iter)
            
        try :
            tgt_data, tgt_label = next(tgtData_iter)
        except StopIteration :
            tgtData_iter = iter(cityscape_trainLoader)
            tgt_data, tgt_label = next(tgtData_iter)
            
        src_cls_label, src_seg_label = src_label['classification'], src_label['segmentation']
        tgt_cls_label = tgt_label['classification']
        
        #FDA
        src_data = FDA(src_data[0], tgt_data[0], 0.09)
        src_data = src_data.unsqueeze(0).float()
        
        #data to GPU
        if torch.cuda.is_available() :
            src_data, src_cls_label, src_seg_label = src_data.cuda(), src_cls_label.cuda(), src_seg_label.cuda()
            tgt_data, tgt_cls_label = tgt_data.cuda(), tgt_cls_label.cuda()
        
        #train segmentation
        src_feature, shortcut = encoder(src_data)
        result = decoder(src_feature, shortcut)
        
        loss_seg = criterion_seg(result, src_seg_label)
        loss_seg.backward(retain_graph=True)
        seg_optim.step()
        
        intersection, union, segmentation_target = intersectionAndUnion(output=result.cpu(), target=src_seg_label.cpu(), K=19, ignore_idx=19)
        intersection_meter.update(intersection), union_meter.update(union), target_meter.update(segmentation_target)
        accuracy = sum(intersection_meter.val) / (sum(target_meter.val) + 1e-10)
        
        #train classification
        src_feature, _ = encoder(src_data)
        tgt_feature, _ = encoder(tgt_data)
        
        cls_src_loss = F.cross_entropy(domain_cls(src_feature.detach()), src_cls_label)
        cls_tgt_loss = F.cross_entropy(domain_cls(tgt_feature.detach()), tgt_cls_label)
        cls_loss = 0.5 * (cls_src_loss + cls_tgt_loss)
        cls_loss.backward()
        cls_optim.step()
        
        cls += cls_loss.data
        
        #train confusion
        src_feature, _ = encoder(src_data)
        tgt_feature, _ = encoder(tgt_data)
        
        output_src_domain_cls = F.softmax(domain_cls(src_feature.detach()), dim=1)
        output_tgt_domain_cls = F.softmax(domain_cls(tgt_feature.detach()), dim=1)
        
        uni_distribution = torch.FloatTensor(output_src_domain_cls.size()).uniform_(0,1)
        if torch.cuda.is_available() :
            uni_distribution = uni_distribution.cuda()
        
        conf_src_loss = -0.5 * (torch.sum(uni_distribution*torch.log(output_src_domain_cls)))/float(output_src_domain_cls.size(0))
        conf_tgt_loss = -0.5 * (torch.sum(uni_distribution*torch.log(output_tgt_domain_cls)))/float(output_tgt_domain_cls.size(0))
        conf_loss = 0.5 * (conf_src_loss + conf_tgt_loss)
        
        conf_loss.backward()
        conf_optim.step()
        
        conf += conf_loss.data
        
        #print and reset iou score
        if epoch % 100 == 0 :
            iou_class = intersection_meter.sum / (union_meter.sum + 1e-10)
            accuracy_class = intersection_meter.sum / (target_meter.sum + 1e-10)
            mIOU = np.mean(iou_class)
            mAcc = np.mean(accuracy_class)
            allAcc = sum(intersection_meter.sum) / (sum(target_meter.sum) + 1e-10)
            
            print('Train Epoch[{}/{} ({:.0f}%)]\tmIOU : {:.6f}\tConfusion Loss : {:.6f}\tClassification Loss : {:.6f}'.format(
                    epoch*len(src_data), max_epoch, 100.*epoch/max_epoch, mIOU, conf/100., cls/100.))
            conf = 0.
            cls = 0.
            
            intersection_meter.reset()
            union_meter.reset()
            target_meter.reset()

        torch.save(encoder.cpu().state_dict(), "gdrive/My Drive/Colab Notebooks/uda_encoder_fda_once_2.pth")
        torch.save(decoder.cpu().state_dict(), "gdrive/My Drive/Colab Notebooks/uda_decoder_fda_once_2.pth")        
        torch.save(domain_cls.cpu().state_dict(), "gdrive/My Drive/Colab Notebooks/uda_domain_cls_once_2.pth")

trainOnce(0, 150000)
# Out:
# Train Epoch[0/150000 (0%)]	mIOU : 0.043009	Confusion Loss : 0.006164	Classification Loss : 0.005942
# Train Epoch[100/150000 (0%)]	mIOU : 0.104885	Confusion Loss : 0.387767	Classification Loss : 0.723926
# Train Epoch[200/150000 (0%)]	mIOU : 0.117997	Confusion Loss : 0.420735	Classification Loss : 0.612965
# Train Epoch[300/150000 (0%)]	mIOU : 0.127734	Confusion Loss : 0.470031	Classification Loss : 0.586769
# Train Epoch[400/150000 (0%)]	mIOU : 0.132500	Confusion Loss : 0.420351	Classification Loss : 0.578335
# Train Epoch[500/150000 (0%)]	mIOU : 0.137947	Confusion Loss : 0.528566	Classification Loss : 0.416932
# Train Epoch[600/150000 (0%)]	mIOU : 0.142365	Confusion Loss : 0.592423	Classification Loss : 0.645151
# Train Epoch[700/150000 (0%)]	mIOU : 0.143883	Confusion Loss : 0.500386	Classification Loss : 0.493050
# Train Epoch[800/150000 (1%)]	mIOU : 0.148908	Confusion Loss : 0.522164	Classification Loss : 0.526943
# Train Epoch[900/150000 (1%)]	mIOU : 0.149038	Confusion Loss : 0.501522	Classification Loss : 0.533568
# Train Epoch[14200/150000 (9%)]	mIOU : 0.198851	Confusion Loss : 1.033017	Classification Loss : 0.286520
# Train Epoch[14300/150000 (10%)]	mIOU : 0.206075	Confusion Loss : 0.946842	Classification Loss : 0.210151
# Train Epoch[14400/150000 (10%)]	mIOU : 0.200725	Confusion Loss : 0.945681	Classification Loss : 0.191449
# Train Epoch[14500/150000 (10%)]	mIOU : 0.206113	Confusion Loss : 1.129414	Classification Loss : 0.203478
# Train Epoch[14600/150000 (10%)]	mIOU : 0.212992	Confusion Loss : 1.023833	Classification Loss : 0.277062
# Train Epoch[14700/150000 (10%)]	mIOU : 0.196290	Confusion Loss : 1.003631	Classification Loss : 0.319890
# Train Epoch[14800/150000 (10%)]	mIOU : 0.201179	Confusion Loss : 0.961418	Classification Loss : 0.161204
# Train Epoch[14900/150000 (10%)]	mIOU : 0.199351	Confusion Loss : 0.885956	Classification Loss : 0.287486
# Train Epoch[15000/150000 (10%)]	mIOU : 0.209613	Confusion Loss : 0.799005	Classification Loss : 0.307251
# Train Epoch[15100/150000 (10%)]	mIOU : 0.180210	Confusion Loss : 0.840217	Classification Loss : 0.237471
# Train Epoch[15200/150000 (10%)]	mIOU : 0.199274	Confusion Loss : 1.041340	Classification Loss : 0.308715
# Train Epoch[15300/150000 (10%)]	mIOU : 0.203114	Confusion Loss : 0.940189	Classification Loss : 0.196200
# Train Epoch[15400/150000 (10%)]	mIOU : 0.198228	Confusion Loss : 1.049272	Classification Loss : 0.311356
# Train Epoch[15500/150000 (10%)]	mIOU : 0.214430	Confusion Loss : 0.960035	Classification Loss : 0.175242
# Train Epoch[15600/150000 (10%)]	mIOU : 0.201519	Confusion Loss : 1.003095	Classification Loss : 0.251577
# Train Epoch[15700/150000 (10%)]	mIOU : 0.199730	Confusion Loss : 0.883457	Classification Loss : 0.251438
# Train Epoch[15800/150000 (11%)]	mIOU : 0.199976	Confusion Loss : 0.953027	Classification Loss : 0.252609
# Train Epoch[15900/150000 (11%)]	mIOU : 0.208699	Confusion Loss : 0.811783	Classification Loss : 0.189931
# Train Epoch[16000/150000 (11%)]	mIOU : 0.208768	Confusion Loss : 0.786960	Classification Loss : 0.210430
# Train Epoch[16100/150000 (11%)]	mIOU : 0.208516	Confusion Loss : 0.969246	Classification Loss : 0.184993
# Train Epoch[16200/150000 (11%)]	mIOU : 0.209806	Confusion Loss : 0.812323	Classification Loss : 0.327129
# Train Epoch[16300/150000 (11%)]	mIOU : 0.206434	Confusion Loss : 0.997269	Classification Loss : 0.181355
# Train Epoch[16400/150000 (11%)]	mIOU : 0.207419	Confusion Loss : 0.926630	Classification Loss : 0.187733
# Train Epoch[16500/150000 (11%)]	mIOU : 0.204601	Confusion Loss : 0.880220	Classification Loss : 0.180193
# Train Epoch[16600/150000 (11%)]	mIOU : 0.204632	Confusion Loss : 0.985736	Classification Loss : 0.166433
# Train Epoch[16700/150000 (11%)]	mIOU : 0.203116	Confusion Loss : 0.909192	Classification Loss : 0.192557
# Train Epoch[30000/150000 (20%)]	mIOU : 0.214381	Confusion Loss : 1.063759	Classification Loss : 0.123831
# Train Epoch[30100/150000 (20%)]	mIOU : 0.212256	Confusion Loss : 1.242815	Classification Loss : 0.163877
# Train Epoch[30200/150000 (20%)]	mIOU : 0.210467	Confusion Loss : 1.039741	Classification Loss : 0.200837
# Train Epoch[30300/150000 (20%)]	mIOU : 0.202024	Confusion Loss : 0.890781	Classification Loss : 0.194676
# Train Epoch[30400/150000 (20%)]	mIOU : 0.221471	Confusion Loss : 1.143746	Classification Loss : 0.205189
# Train Epoch[30500/150000 (20%)]	mIOU : 0.213279	Confusion Loss : 1.056223	Classification Loss : 0.160857
# Train Epoch[30600/150000 (20%)]	mIOU : 0.220683	Confusion Loss : 1.107839	Classification Loss : 0.217393
# Train Epoch[30700/150000 (20%)]	mIOU : 0.203988	Confusion Loss : 1.098820	Classification Loss : 0.265575
# Train Epoch[30800/150000 (21%)]	mIOU : 0.206989	Confusion Loss : 0.933225	Classification Loss : 0.272337
# Train Epoch[30900/150000 (21%)]	mIOU : 0.208651	Confusion Loss : 1.053541	Classification Loss : 0.193438
# Train Epoch[31000/150000 (21%)]	mIOU : 0.211691	Confusion Loss : 1.120008	Classification Loss : 0.146356
# Train Epoch[31100/150000 (21%)]	mIOU : 0.215591	Confusion Loss : 1.035123	Classification Loss : 0.230340
# Train Epoch[31200/150000 (21%)]	mIOU : 0.203979	Confusion Loss : 0.999138	Classification Loss : 0.192229
# Train Epoch[31300/150000 (21%)]	mIOU : 0.207203	Confusion Loss : 0.972124	Classification Loss : 0.209981
# Train Epoch[31400/150000 (21%)]	mIOU : 0.207968	Confusion Loss : 1.157621	Classification Loss : 0.150148
# Train Epoch[31500/150000 (21%)]	mIOU : 0.225595	Confusion Loss : 0.977403	Classification Loss : 0.230426
# Train Epoch[31600/150000 (21%)]	mIOU : 0.212707	Confusion Loss : 1.015105	Classification Loss : 0.238211
# Train Epoch[31700/150000 (21%)]	mIOU : 0.194379	Confusion Loss : 0.990690	Classification Loss : 0.211273
# Train Epoch[31800/150000 (21%)]	mIOU : 0.204293	Confusion Loss : 1.083440	Classification Loss : 0.191461
# Train Epoch[31900/150000 (21%)]	mIOU : 0.205637	Confusion Loss : 0.896675	Classification Loss : 0.263930
# Train Epoch[32000/150000 (21%)]	mIOU : 0.200542	Confusion Loss : 0.942234	Classification Loss : 0.179944
# Train Epoch[32100/150000 (21%)]	mIOU : 0.210027	Confusion Loss : 1.012836	Classification Loss : 0.224987
# Train Epoch[32200/150000 (21%)]	mIOU : 0.214899	Confusion Loss : 0.976382	Classification Loss : 0.191802
# Train Epoch[32300/150000 (22%)]	mIOU : 0.213612	Confusion Loss : 0.907885	Classification Loss : 0.196055
# Train Epoch[32400/150000 (22%)]	mIOU : 0.217313	Confusion Loss : 1.088840	Classification Loss : 0.249516
# Train Epoch[32500/150000 (22%)]	mIOU : 0.214531	Confusion Loss : 0.902311	Classification Loss : 0.230227
# Train Epoch[32600/150000 (22%)]	mIOU : 0.184421	Confusion Loss : 0.962571	Classification Loss : 0.262154
# Train Epoch[32700/150000 (22%)]	mIOU : 0.200943	Confusion Loss : 1.067937	Classification Loss : 0.219117
# Train Epoch[32800/150000 (22%)]	mIOU : 0.208654	Confusion Loss : 0.963114	Classification Loss : 0.212934
# Train Epoch[32900/150000 (22%)]	mIOU : 0.213016	Confusion Loss : 0.972429	Classification Loss : 0.200914
# Train Epoch[33000/150000 (22%)]	mIOU : 0.202066	Confusion Loss : 1.192838	Classification Loss : 0.144791
# Train Epoch[33100/150000 (22%)]	mIOU : 0.212410	Confusion Loss : 1.060100	Classification Loss : 0.312961
# Train Epoch[33200/150000 (22%)]	mIOU : 0.199311	Confusion Loss : 0.960004	Classification Loss : 0.216959
# Train Epoch[33300/150000 (22%)]	mIOU : 0.209778	Confusion Loss : 1.288451	Classification Loss : 0.160871
# Train Epoch[33400/150000 (22%)]	mIOU : 0.214199	Confusion Loss : 1.050503	Classification Loss : 0.220167
# Train Epoch[33500/150000 (22%)]	mIOU : 0.214120	Confusion Loss : 1.122034	Classification Loss : 0.289318
# Train Epoch[33600/150000 (22%)]	mIOU : 0.215176	Confusion Loss : 0.963145	Classification Loss : 0.190721
# Train Epoch[33700/150000 (22%)]	mIOU : 0.202632	Confusion Loss : 1.108884	Classification Loss : 0.183741
# Train Epoch[33800/150000 (23%)]	mIOU : 0.210085	Confusion Loss : 0.997225	Classification Loss : 0.197036
# Train Epoch[33900/150000 (23%)]	mIOU : 0.201412	Confusion Loss : 1.079857	Classification Loss : 0.250050
# Train Epoch[34000/150000 (23%)]	mIOU : 0.209330	Confusion Loss : 0.966593	Classification Loss : 0.221632
# Train Epoch[34100/150000 (23%)]	mIOU : 0.217845	Confusion Loss : 1.066173	Classification Loss : 0.278867
# Train Epoch[34200/150000 (23%)]	mIOU : 0.219396	Confusion Loss : 1.113119	Classification Loss : 0.124940
# Train Epoch[34300/150000 (23%)]	mIOU : 0.210104	Confusion Loss : 1.022634	Classification Loss : 0.226242
# Train Epoch[34400/150000 (23%)]	mIOU : 0.224139	Confusion Loss : 1.169361	Classification Loss : 0.270161
# Train Epoch[34500/150000 (23%)]	mIOU : 0.227945	Confusion Loss : 1.245859	Classification Loss : 0.180921
# Train Epoch[34600/150000 (23%)]	mIOU : 0.210424	Confusion Loss : 1.022124	Classification Loss : 0.166109
# Train Epoch[34700/150000 (23%)]	mIOU : 0.211575	Confusion Loss : 1.174271	Classification Loss : 0.187952
# Train Epoch[34800/150000 (23%)]	mIOU : 0.187783	Confusion Loss : 1.048952	Classification Loss : 0.236128
# Train Epoch[34900/150000 (23%)]	mIOU : 0.204364	Confusion Loss : 1.145008	Classification Loss : 0.137867
# Train Epoch[35000/150000 (23%)]	mIOU : 0.213127	Confusion Loss : 0.962393	Classification Loss : 0.231583
# Train Epoch[35100/150000 (23%)]	mIOU : 0.209253	Confusion Loss : 1.001581	Classification Loss : 0.199883
# Train Epoch[35200/150000 (23%)]	mIOU : 0.193936	Confusion Loss : 1.088634	Classification Loss : 0.251898
